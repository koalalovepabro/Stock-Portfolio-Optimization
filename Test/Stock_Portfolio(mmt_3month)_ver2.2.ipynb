# %% [markdown]
# <a href="https://colab.research.google.com/github/koalalovepabro/Stock-Portfolio-Optimization/blob/main/Test/Stock_Portfolio(mmt_3month)_ver2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **📈 종목선택 방법**
# - 모멘텀 3개월
# - 최근에 가장 많이 오른 종목 매수한 후 일정 기간을 보유한 후 파는 전략
# - 60 영업일(3개월) 수익률 순위 보여줌

# %% [markdown]
# # **📊 포트폴리오 최적화 방법**
# 1. **Max Sharpe Ratio** : 샤프비율이 최대가 되도록 포트폴리오 최적화
#     => 수익률과 변동성을 모두 고려
# 2. **✔ Efficient Risk**   : 주어진 변동성 ( target_volatility ) 보다 낮은 범위 내에서 수익률 (Return)이 최대가 되도록 포트폴리오 최적화
#     => 높은 이익을 추구하기 보다는, 비교적 위험이 낮은 투자를 원하는 투자자에게 추천
# 3. **Efficient Return** : 주어진 리스크 ( target_return )을 만족시키는 선에서 변동성(volatility)를 최소가 되도록 포트폴리오 최적화
#     => 높은 위험을 감수하더라도, 높은 이익을 추구하는 투자 성향을 가진 투자자에게 추천

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
# !pip install -q install finance-datareader

# %%
# !pip install pykrx
# Out:
# Collecting pykrx
#   Downloading pykrx-1.0.18-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.2 MB/s
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.1.5)
# Collecting deprecated
#   Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pykrx) (2.23.0)
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 9.0 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datetime->pykrx) (2018.9)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 24.5 MB/s
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated->pykrx) (1.12.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pykrx) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pykrx) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (2021.5.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zope.interface->datetime->pykrx) (57.2.0)
# Installing collected packages: zope.interface, deprecated, datetime, pykrx
# Successfully installed datetime-4.3 deprecated-1.2.12 pykrx-1.0.18 zope.interface-5.4.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import FinanceDataReader as fdr
from pykrx import stock
import datetime

# %%
# 오늘 KOSPI&KOSDAQ 종목 전체 불러오기
today = datetime.datetime.today().strftime("%Y%m%d")
kospi = stock.get_market_fundamental_by_ticker(today, market='KOSPI').index
kosdaq = stock.get_market_fundamental_by_ticker(today, market='KOSDAQ').index
stocks = kospi.append(kosdaq)
stocks
# Out:
# Index(['095570', '006840', '027410', '282330', '138930', '001460', '001465',
#        '001040', '079160', '00104K',
#        ...
#        '065510', '243070', '084110', '263920', '145020', '024060', '010240',
#        '189980', '037440', '238490'],
#       dtype='object', name='티커', length=2391)

# %% [markdown]
# # 종목이름과 종목 코드

# %%
###########추가#############
kospi_temp = fdr.StockListing('KOSPI')[['Symbol', 'Name']]
kosdaq_temp = fdr.StockListing('KOSDAQ')[['Symbol', 'Name']]
code_name_dict = pd.concat([kospi_temp,kosdaq_temp])
code_name_dict = code_name_dict.set_index('Symbol').to_dict().get('Name')
code_name_dict
# Out:
# {'095570': 'AJ네트웍스',
#  '006840': 'AK홀딩스',
#  '152100': 'ARIRANG 200',
#  '295820': 'ARIRANG 200동일가중',
#  '253150': 'ARIRANG 200선물레버리지',
#  '253160': 'ARIRANG 200선물인버스2X',
#  '395750': 'ARIRANG ESG가치주액티브',
#  '395760': 'ARIRANG ESG성장주액티브',
#  '278420': 'ARIRANG ESG우수기업',
#  '292750': 'ARIRANG KRX300',
#  '309210': 'ARIRANG KRX300헬스케어',
#  '333940': 'ARIRANG KS로우볼가중TR',
#  '333950': 'ARIRANG KS로우사이즈가중TR',
#  '333960': 'ARIRANG KS모멘텀가중TR',
#  '333970': 'ARIRANG KS밸류가중TR',
#  '333980': 'ARIRANG KS퀄리티가중TR',
#  '269530': 'ARIRANG S&P글로벌인프라',
#  '251590': 'ARIRANG 고배당저변동50',
#  '161510': 'ARIRANG 고배당주',
#  '251600': 'ARIRANG 고배당주채권혼합',
#  '289670': 'ARIRANG 국채선물10년',
#  '298340': 'ARIRANG 국채선물3년',
#  '189400': 'ARIRANG 글로벌MSCI(합성 H)',
#  '278620': 'ARIRANG 단기채권액티브',
#  '269540': 'ARIRANG 미국S&P500(H)',
#  '287180': 'ARIRANG 미국나스닥기술주',
#  '213630': 'ARIRANG 미국다우존스고배당주(합성 H)',
#  '332610': 'ARIRANG 미국단기우량회사채',
#  '332620': 'ARIRANG 미국장기우량회사채',
#  '195970': 'ARIRANG 선진국MSCI(합성 H)',
#  '238670': 'ARIRANG 스마트베타Quality채권혼합',
#  '195980': 'ARIRANG 신흥국MSCI(합성 H)',
#  '373530': 'ARIRANG 신흥국MSCI인버스(합성 H)',
#  '256450': 'ARIRANG 심천차이넥스트(합성)',
#  '239660': 'ARIRANG 우량회사채50 1년',
#  '280920': 'ARIRANG 주도업종',
#  '266550': 'ARIRANG 중형주저변동50',
#  '301400': 'ARIRANG 코스닥150',
#  '301410': 'ARIRANG 코스닥150선물인버스',
#  '227830': 'ARIRANG 코스피',
#  '122090': 'ARIRANG 코스피50',
#  '328370': 'ARIRANG 코스피TR',
#  '301440': 'ARIRANG 코스피중형주',
#  '376250': 'ARIRANG 탄소효율그린뉴딜',
#  '027410': 'BGF',
#  '282330': 'BGF리테일',
#  '138930': 'BNK금융지주',
#  '001460': 'BYC',
#  '001465': 'BYC우',
#  '001040': 'CJ',
#  '079160': 'CJ CGV',
#  '00104K': 'CJ4우(전환)',
#  '000120': 'CJ대한통운',
#  '011150': 'CJ씨푸드',
#  '011155': 'CJ씨푸드1우',
#  '001045': 'CJ우',
#  '097950': 'CJ제일제당',
#  '097955': 'CJ제일제당 우',
#  '000590': 'CS홀딩스',
#  '012030': 'DB',
#  '016610': 'DB금융투자',
#  '005830': 'DB손해보험',
#  '000990': 'DB하이텍',
#  '000995': 'DB하이텍1우',
#  '139130': 'DGB금융지주',
#  '001530': 'DI동일',
#  '000210': 'DL',
#  '001880': 'DL건설',
#  '000215': 'DL우',
#  '375500': 'DL이앤씨',
#  '37550K': 'DL이앤씨우',
#  '004840': 'DRB동일',
#  '155660': 'DSR',
#  '069730': 'DSR제강',
#  '017940': 'E1',
#  '365550': 'ESR켄달스퀘어리츠',
#  '383220': 'F&F',
#  '007700': 'F&F홀딩스',
#  '285690': 'FOCUS ESG리더스',
#  '292730': 'FOCUS KRX300',
#  '73501BB4': 'GB국민참여정책형뉴딜A',
#  '73502BB4': 'GB국민참여정책형뉴딜C',
#  '73503BB4': 'GB국민참여정책형뉴딜I',
#  '73501BA2': 'GB중소성장기업A',
#  '73502BA2': 'GB중소성장기업C',
#  '73503BA2': 'GB중소성장기업I',
#  '114090': 'GKL',
#  '078930': 'GS',
#  '006360': 'GS건설',
#  '001250': 'GS글로벌',
#  '007070': 'GS리테일',
#  '078935': 'GS우',
#  '293180': 'HANARO 200',
#  '332930': 'HANARO 200TR',
#  '304780': 'HANARO 200선물레버리지',
#  '306520': 'HANARO 200선물인버스',
#  '395290': 'HANARO Fn K-POP&미디어',
#  '395280': 'HANARO Fn K-게임',
#  '368190': 'HANARO Fn K-뉴딜디지털플러스',
#  '395270': 'HANARO Fn K-반도체',
#  '367740': 'HANARO Fn5G산업',
#  '381560': 'HANARO Fn전기&수소차',
#  '381570': 'HANARO Fn친환경에너지',
#  '346000': 'HANARO KAP초장기국고채',
#  '304760': 'HANARO KRX300',
#  '332940': 'HANARO MSCI Korea TR',
#  '322400': 'HANARO e커머스',
#  '322410': 'HANARO 고배당',
#  '354350': 'HANARO 글로벌럭셔리S&P(합성)',
#  '314700': 'HANARO 농업융복합산업',
#  '390950': 'HANARO 단기채권액티브',
#  '304770': 'HANARO 코스닥150',
#  '306530': 'HANARO 코스닥150선물레버리지',
#  '375760': 'HANARO 탄소효율그린뉴딜',
#  '012630': 'HDC',
#  '039570': 'HDC아이콘트롤스',
#  '089470': 'HDC현대EP',
#  '294870': 'HDC현대산업개발',
#  '391670': 'HK 베스트일레븐액티브',
#  '391680': 'HK 하이볼액티브',
#  '011200': 'HMM',
#  '082740': 'HSD엔진',
#  '75801BB4': 'IBK 국민참여정책형뉴딜 혼합자산 A',
#  '75802BB4': 'IBK 국민참여정책형뉴딜 혼합자산 C',
#  '003560': 'IHQ',
#  '175330': 'JB금융지주',
#  '234080': 'JW생명과학',
#  '001060': 'JW중외제약',
#  '001067': 'JW중외제약2우B',
#  '001065': 'JW중외제약우',
#  '096760': 'JW홀딩스',
#  '580011': 'KB FnGuide 언택트 ETN',
#  '580013': 'KB KRX ESG Eco ETN',
#  '580012': 'KB KRX300 ETN',
#  '580010': 'KB Wise 분할매매 ETN',
#  '580016': 'KB 레버리지 S&P 500 선물 ETN(H)',
#  '580022': 'KB 레버리지 금 선물 ETN(H)',
#  '580015': 'KB 레버리지 나스닥 100 ETN',
#  '580018': 'KB 레버리지 항셍테크 선물 ETN(H)',
#  '71901B96': 'KB 와이즈 스타 부동산 자 2 A',
#  '71902B96': 'KB 와이즈 스타 부동산 자 2 C-F',
#  '71903B96': 'KB 와이즈 스타 부동산 자 2 C-I',
#  '580017': 'KB 인버스 2X S&P 500 선물 ETN',
#  '580023': 'KB 인버스 2X 금 선물 ETN(H)',
#  '580014': 'KB 인버스 2X 나스닥 100 ETN',
#  '580019': 'KB 인버스 2X 항셍테크 선물 ETN',
#  '580021': 'KB 인버스 천연가스 선물 ETN',
#  '580020': 'KB 천연가스 선물 ETN(H)',
#  '58FG44': 'KBFG44KOSPI200콜',
#  '58FG45': 'KBFG45KOSPI200콜',
#  '58FG46': 'KBFG46KOSPI200콜',
#  '58FG47': 'KBFG47KOSPI200콜',
#  '58FG48': 'KBFG48KOSPI200콜',
#  '58FG49': 'KBFG49KOSPI200콜',
#  '58FG50': 'KBFG50KOSPI200콜',
#  '58FG51': 'KBFG51KOSPI200콜',
#  '58FG52': 'KBFG52KOSPI200콜',
#  '58FG53': 'KBFG53KOSPI200콜',
#  '58FG54': 'KBFG54KOSPI200풋',
#  '58FG55': 'KBFG55KOSPI200풋',
#  '58FG56': 'KBFG56KOSPI200풋',
#  '58FG57': 'KBFG57KOSPI200풋',
#  '58FG58': 'KBFG58KOSPI200풋',
#  '58FG59': 'KBFG59KOSPI200풋',
#  '58FG60': 'KBFG60KOSPI200풋',
#  '58FG61': 'KBFG61KOSPI200풋',
#  '58FG62': 'KBFG62KOSPI200풋',
#  '58FG63': 'KBFG63KOSPI200풋',
#  '58FH85': 'KBFH85삼성전자콜',
#  '58FH86': 'KBFH86현대차콜',
#  '58G170': 'KBG170엘지전자콜',
#  '58G171': 'KBG171LG화학콜',
#  '58G172': 'KBG172SK하이닉콜',
#  '58G173': 'KBG173삼성SDI콜',
#  '58G174': 'KBG174삼성전자콜',
#  '58G175': 'KBG175삼성전자콜',
#  '58G176': 'KBG176삼성전자풋',
#  '58G177': 'KBG177셀트리온콜',
#  '58G178': 'KBG178신한지주콜',
#  '58G179': 'KBG179카카오콜',
#  '58G180': 'KBG180하나금융콜',
#  '58G181': 'KBG181현대차콜',
#  '58G182': 'KBG182현대차콜',
#  '58G183': 'KBG183엘지전자콜',
#  '58G184': 'KBG184LG화학콜',
#  '58G185': 'KBG185SK하이닉콜',
#  '58G186': 'KBG186삼성SDI콜',
#  '58G187': 'KBG187삼성전자콜',
#  '58G188': 'KBG188삼성전자콜',
#  '58G189': 'KBG189셀트리온콜',
#  '58G190': 'KBG190카카오콜',
#  '58G191': 'KBG191현대차콜',
#  '58G192': 'KBG192LG화학콜',
#  '58G193': 'KBG193SK하이닉콜',
#  '58G194': 'KBG194삼성전자콜',
#  '58G195': 'KBG195현대차콜',
#  '58G196': 'KBG196삼성전자콜',
#  '58G325': 'KBG325KOSPI200콜',
#  '58G326': 'KBG326KOSPI200콜',
#  '58G327': 'KBG327KOSPI200콜',
#  '58G328': 'KBG328KOSPI200콜',
#  '58G329': 'KBG329KOSPI200콜',
#  '58G330': 'KBG330KOSPI200콜',
#  '58G331': 'KBG331KOSPI200콜',
#  '58G332': 'KBG332KOSPI200콜',
#  '58G333': 'KBG333KOSPI200콜',
#  '58G334': 'KBG334KOSPI200콜',
#  '58G335': 'KBG335KOSPI200콜',
#  '58G336': 'KBG336KOSPI200콜',
#  '58G337': 'KBG337KOSPI200콜',
#  '58G338': 'KBG338KOSPI200콜',
#  '58G340': 'KBG340엘지전자콜',
#  '58G343': 'KBG343LG화학콜',
#  '58G346': 'KBG346네이버콜',
#  '58G347': 'KBG347네이버풋',
#  '58G353': 'KBG353SK텔레콤콜',
#  '58G355': 'KBG355SK하이닉콜',
#  '58G356': 'KBG356SK하이닉콜',
#  '58G359': 'KBG359기아풋',
#  '58G371': 'KBG371삼성중콜',
#  '58G374': 'KBG374하나금융콜',
#  '58G378': 'KBG378모비스콜',
#  '58G379': 'KBG379현대차콜',
#  '58G382': 'KBG382POSCO콜',
#  '58G385': 'KBG385삼성전자콜',
#  '58G386': 'KBG386삼성전자콜',
#  '58G387': 'KBG387삼성전자콜',
#  '58G388': 'KBG388삼성전자콜',
#  '58G395': 'KBG395신한지주풋',
#  '58G397': 'KBG397한국전력콜',
#  '58G417': 'KBG417KOSPI200콜',
#  '58G418': 'KBG418KOSPI200콜',
#  '58G419': 'KBG419KOSPI200콜',
#  '58G420': 'KBG420KOSPI200콜',
#  '58G421': 'KBG421KOSPI200콜',
#  '58G422': 'KBG422KOSPI200콜',
#  '58G423': 'KBG423KOSPI200콜',
#  '58G424': 'KBG424KOSPI200콜',
#  '58G425': 'KBG425KOSPI200콜',
#  '58G426': 'KBG426KOSPI200콜',
#  '58G427': 'KBG427KOSPI200콜',
#  '58G428': 'KBG428KOSPI200콜',
#  '58G429': 'KBG429KOSPI200콜',
#  '58G430': 'KBG430KOSPI200콜',
#  '58G431': 'KBG431KOSPI200콜',
#  '58G432': 'KBG432KOSPI200콜',
#  '58G433': 'KBG433KOSPI200콜',
#  '58G434': 'KBG434KOSPI200콜',
#  '58G435': 'KBG435KOSPI200콜',
#  '58G436': 'KBG436KOSPI200콜',
#  '58G437': 'KBG437KOSPI200콜',
#  '58G438': 'KBG438KOSPI200콜',
#  '58G439': 'KBG439KOSPI200콜',
#  '58G440': 'KBG440KOSPI200콜',
#  '58G441': 'KBG441KOSPI200콜',
#  '58G442': 'KBG442KOSPI200콜',
#  '58G538': 'KBG538LG생건콜',
#  '58G540': 'KBG540LG화학콜',
#  '58G541': 'KBG541네이버콜',
#  '58G542': 'KBG542네이버콜',
#  '58G543': 'KBG543네이버풋',
#  '58G544': 'KBG544POSCO콜',
#  '58G545': 'KBG545SK이노콜',
#  '58G546': 'KBG546SK케미칼콜',
#  '58G547': 'KBG547SK텔레콤콜',
#  '58G548': 'KBG548SK하이닉콜',
#  '58G549': 'KBG549기아콜',
#  '58G550': 'KBG550기아콜',
#  '58G551': 'KBG551넷마블콜',
#  '58G552': 'KBG552녹십자콜',
#  '58G553': 'KBG553대웅콜',
#  '58G554': 'KBG554두산중공콜',
#  '58G555': 'KBG555두산퓨얼콜',
#  '58G557': 'KBG557롯데케미콜',
#  '58G558': 'KBG558만도콜',
#  '58G559': 'KBG559하이브콜',
#  '58G560': 'KBG560삼성SDI콜',
#  '58G561': 'KBG561삼성물산콜',
#  '58G562': 'KBG562삼성바이콜',
#  '58G563': 'KBG563삼성전기콜',
#  '58G564': 'KBG564삼성전자콜',
#  '58G565': 'KBG565삼성전자콜',
#  '58G566': 'KBG566삼성전자콜',
#  '58G567': 'KBG567셀트리온콜',
#  '58G568': 'KBG568셀트리온콜',
#  '58G569': 'KBG569셀트리온콜',
#  '58G570': 'KBG570셀트헬스콜',
#  '58G571': 'KBG571셀트헬스콜',
#  '58G572': 'KBG572신한지주콜',
#  '58G573': 'KBG573아모레콜',
#  '58G574': 'KBG574SK바이오콜',
#  '58G575': 'KBG575NC소프트콜',
#  '58G576': 'KBG576포스코케콜',
#  '58G577': 'KBG577하나금융콜',
#  '58G578': 'KBG578한국전력콜',
#  '58G579': 'KBG579모비스콜',
#  '58G580': 'KBG580현대차콜',
#  '58G581': 'KBG581현대차콜',
#  '58G582': 'KBG582엘지전자콜',
#  '58G583': 'KBG583LG화학콜',
#  '58G584': 'KBG584네이버콜',
#  '58G585': 'KBG585네이버콜',
#  '58G586': 'KBG586POSCO콜',
#  '58G587': 'KBG587SK텔레콤콜',
#  '58G588': 'KBG588SK하이닉콜',
#  '58G589': 'KBG589기아콜',
#  '58G590': 'KBG590기아풋',
#  '58G591': 'KBG591롯데케미콜',
#  '58G592': 'KBG592롯데케미콜',
#  '58G593': 'KBG593삼성SDI콜',
#  '58G594': 'KBG594삼성바이콜',
#  '58G595': 'KBG595삼성생명콜',
#  '58G596': 'KBG596삼성전자콜',
#  '58G597': 'KBG597삼성전자콜',
#  '58G598': 'KBG598삼성전자풋',
#  '58G599': 'KBG599삼성중콜',
#  '58G600': 'KBG600셀트리온콜',
#  '58G601': 'KBG601셀트리온콜',
#  '58G602': 'KBG602셀트헬스콜',
#  '58G603': 'KBG603아모레콜',
#  '58G604': 'KBG604하나금융콜',
#  '58G605': 'KBG605모비스콜',
#  '58G606': 'KBG606현대차콜',
#  '58G607': 'KBG607엘지전자콜',
#  '58G608': 'KBG608LG화학콜',
#  '58G609': 'KBG609네이버콜',
#  '58G610': 'KBG610네이버풋',
#  '58G611': 'KBG611POSCO콜',
#  '58G612': 'KBG612SK텔레콤콜',
#  '58G613': 'KBG613SK하이닉콜',
#  '58G614': 'KBG614기아콜',
#  '58G615': 'KBG615롯데케미콜',
#  '58G616': 'KBG616삼성전자콜',
#  '58G617': 'KBG617삼성전자콜',
#  '58G618': 'KBG618삼성전자풋',
#  '58G619': 'KBG619셀트리온콜',
#  '58G620': 'KBG620셀트헬스콜',
#  '58G621': 'KBG621신한지주콜',
#  '58G622': 'KBG622하나금융콜',
#  '58G623': 'KBG623현대차콜',
#  '58G624': 'KBG624LG화학콜',
#  '58G625': 'KBG625네이버콜',
#  '58G626': 'KBG626POSCO콜',
#  '58G627': 'KBG627SK하이닉콜',
#  '58G628': 'KBG628기아콜',
#  '58G629': 'KBG629롯데케미콜',
#  '58G630': 'KBG630삼성전자콜',
#  '58G631': 'KBG631셀트리온콜',
#  '58G632': 'KBG632셀트헬스콜',
#  '58G633': 'KBG633현대차콜',
#  '58G634': 'KBG634롯데케미콜',
#  '58G635': 'KBG635삼성전자콜',
#  '58G636': 'KBG636삼성전자콜',
#  '58G637': 'KBG637셀트리온콜',
#  '58G638': 'KBG638삼성전자콜',
#  '58G639': 'KBG639삼성전자콜',
#  '58G640': 'KBG640삼성전자콜',
#  '58G641': 'KBG641삼성중콜',
#  '58G681': 'KBG681KOSPI200콜',
#  '58G682': 'KBG682KOSPI200콜',
#  '58G683': 'KBG683KOSPI200콜',
#  '58G684': 'KBG684KOSPI200콜',
#  '58G685': 'KBG685KOSPI200콜',
#  '58G686': 'KBG686KOSPI200콜',
#  '58G687': 'KBG687KOSPI200콜',
#  '58G688': 'KBG688KOSPI200콜',
#  '58G689': 'KBG689KOSPI200콜',
#  '58G690': 'KBG690KOSPI200콜',
#  '58G691': 'KBG691KOSPI200콜',
#  '58G692': 'KBG692KOSPI200콜',
#  '58G693': 'KBG693KOSPI200콜',
#  '58G694': 'KBG694KOSPI200콜',
#  '58G695': 'KBG695KOSPI200콜',
#  '58G696': 'KBG696KOSPI200콜',
#  '58G697': 'KBG697KOSPI200콜',
#  '58G698': 'KBG698KOSPI200콜',
#  '58G699': 'KBG699KOSPI200콜',
#  '58G700': 'KBG700KOSPI200콜',
#  '58G701': 'KBG701KOSPI200콜',
#  '58G702': 'KBG702KOSPI200콜',
#  '58G703': 'KBG703KOSPI200콜',
#  '58G704': 'KBG704KOSPI200콜',
#  '58G705': 'KBG705KOSPI200콜',
#  '58G706': 'KBG706KOSPI200풋',
#  '58G707': 'KBG707KOSPI200풋',
#  '58G708': 'KBG708KOSPI200풋',
#  '58G709': 'KBG709KOSPI200풋',
#  '58G710': 'KBG710KOSPI200풋',
#  '58G711': 'KBG711KOSPI200풋',
#  '58G712': 'KBG712KOSPI200풋',
#  '58G713': 'KBG713KOSPI200풋',
#  '58G714': 'KBG714KOSPI200풋',
#  '58G715': 'KBG715KOSPI200풋',
#  '58G716': 'KBG716KOSPI200콜',
#  '58G717': 'KBG717KOSPI200콜',
#  '58G718': 'KBG718KOSPI200콜',
#  '58G719': 'KBG719KOSPI200콜',
#  '58G720': 'KBG720KOSPI200콜',
#  '58G721': 'KBG721KOSPI200콜',
#  '58G722': 'KBG722KOSPI200콜',
#  '58G723': 'KBG723KOSPI200콜',
#  '58G724': 'KBG724KOSPI200콜',
#  '58G725': 'KBG725KOSPI200콜',
#  '58G726': 'KBG726케이티지콜',
#  '58G727': 'KBG727케이티지콜',
#  '58G728': 'KBG728케이티지풋',
#  '58G729': 'KBG729엘지디스콜',
#  '58G730': 'KBG730엘지디스콜',
#  '58G731': 'KBG731엘지디스풋',
#  '58G732': 'KBG732LG생건콜',
#  '58G733': 'KBG733LG이노텍콜',
#  '58G734': 'KBG734LG이노텍콜',
#  '58G735': 'KBG735LG이노텍풋',
#  '58G736': 'KBG736엘지전자콜',
#  '58G738': 'KBG738엘지전자풋',
#  '58G739': 'KBG739LG화학콜',
#  '58G740': 'KBG740LG화학콜',
#  '58G741': 'KBG741LG화학풋',
#  '58G742': 'KBG742네이버콜',
#  '58G743': 'KBG743네이버풋',
#  '58G744': 'KBG744POSCO콜',
#  '58G745': 'KBG745POSCO콜',
#  '58G746': 'KBG746POSCO풋',
#  '58G748': 'KBG748SK콜',
#  '58G749': 'KBG749SK풋',
#  '58G750': 'KBG750SK텔레콤콜',
#  '58G752': 'KBG752SK텔레콤풋',
#  '58G753': 'KBG753SK하이닉콜',
#  '58G755': 'KBG755S-OIL콜',
#  '58G756': 'KBG756S-OIL풋',
#  '58G757': 'KBG757금호석유콜',
#  '58G758': 'KBG758금호석유콜',
#  '58G759': 'KBG759금호석유풋',
#  '58G760': 'KBG760기아콜',
#  '58G761': 'KBG761기아콜',
#  '58G762': 'KBG762기아풋',
#  '58G763': 'KBG763만도콜',
#  '58G764': 'KBG764만도콜',
#  '58G765': 'KBG765만도풋',
#  '58G766': 'KBG766삼성SDI콜',
#  '58G767': 'KBG767삼성물산콜',
#  '58G768': 'KBG768삼성물산풋',
#  '58G770': 'KBG770삼성전기콜',
#  '58G771': 'KBG771삼성전기콜',
#  '58G772': 'KBG772삼성전자콜',
#  '58G773': 'KBG773삼성전자콜',
#  '58G774': 'KBG774삼성전자풋',
#  '58G775': 'KBG775삼성중콜',
#  '58G776': 'KBG776삼성중콜',
#  '58G778': 'KBG778셀트리온콜',
#  '58G779': 'KBG779셀트리온콜',
#  '58G780': 'KBG780셀트리온풋',
#  '58G781': 'KBG781셀트제약콜',
#  '58G782': 'KBG782셀트제약콜',
#  '58G783': 'KBG783셀트제약풋',
#  '58G784': 'KBG784셀트헬스콜',
#  '58G785': 'KBG785신한지주콜',
#  '58G786': 'KBG786신한지주콜',
#  '58G787': 'KBG787신한지주풋',
#  '58G788': 'KBG788이마트콜',
#  '58G789': 'KBG789하나금융콜',
#  '58G790': 'KBG790하나금융콜',
#  '58G791': 'KBG791하나금융풋',
#  '58G792': 'KBG792한국조선콜',
#  '58G793': 'KBG793한국조선콜',
#  '58G794': 'KBG794한국조선풋',
#  '58G795': 'KBG795한화솔루콜',
#  '58G796': 'KBG796한화솔루콜',
#  '58G797': 'KBG797한화솔루풋',
#  '58G798': 'KBG798글로비스콜',
#  '58G799': 'KBG799글로비스콜',
#  '58G800': 'KBG800글로비스풋',
#  '58G801': 'KBG801모비스콜',
#  '58G802': 'KBG802모비스콜',
#  '58G803': 'KBG803모비스풋',
#  '58G804': 'KBG804현대차풋',
#  '58G805': 'KBG805호텔신라콜',
#  '58G806': 'KBG806호텔신라콜',
#  '58G807': 'KBG807호텔신라풋',
#  '58G808': 'KBG808케이티지콜',
#  '58G809': 'KBG809LG이노텍콜',
#  '58G810': 'KBG810엘지전자콜',
#  '58G811': 'KBG811LG화학콜',
#  '58G812': 'KBG812LG화학풋',
#  '58G813': 'KBG813네이버콜',
#  '58G814': 'KBG814POSCO콜',
#  '58G815': 'KBG815SK콜',
#  '58G816': 'KBG816SK이노콜',
#  '58G817': 'KBG817SK텔레콤콜',
#  '58G818': 'KBG818SK텔레콤콜',
#  '58G820': 'KBG820금호석유콜',
#  '58G821': 'KBG821기아콜',
#  '58G822': 'KBG822만도콜',
#  '58G823': 'KBG823삼성SDI콜',
#  '58G824': 'KBG824삼성전자콜',
#  '58G825': 'KBG825삼성중콜',
#  '58G826': 'KBG826셀트리온콜',
#  '58G827': 'KBG827셀트제약콜',
#  '58G828': 'KBG828셀트제약콜',
#  '58G829': 'KBG829신한지주콜',
#  '58G830': 'KBG830이마트콜',
#  '58G831': 'KBG831하나금융콜',
#  '58G832': 'KBG832한국조선콜',
#  '58G833': 'KBG833글로비스콜',
#  '58G834': 'KBG834모비스콜',
#  '58G835': 'KBG835현대차콜',
#  '58G836': 'KBG836호텔신라콜',
#  '58G837': 'KBG837케이티지콜',
#  '58G838': 'KBG838엘지디스콜',
#  '58G839': 'KBG839LG생건콜',
#  '58G840': 'KBG840엘지전자콜',
#  '58G841': 'KBG841LG화학콜',
#  '58G842': 'KBG842네이버콜',
#  '58G843': 'KBG843POSCO콜',
#  '58G844': 'KBG844POSCO콜',
#  '58G845': 'KBG845SK텔레콤콜',
#  '58G846': 'KBG846SK텔레콤풋',
#  '58G847': 'KBG847SK하이닉콜',
#  '58G848': 'KBG848SK하이닉풋',
#  '58G849': 'KBG849S-OIL콜',
#  '58G850': 'KBG850기아콜',
#  '58G851': 'KBG851삼성SDI콜',
#  '58G852': 'KBG852셀트리온콜',
#  '58G853': 'KBG853이마트콜',
#  '58G854': 'KBG854한국조선콜',
#  '58G855': 'KBG855현대차콜',
#  '58G856': 'KBG856케이티지콜',
#  '58G857': 'KBG857엘지전자콜',
#  '58G858': 'KBG858POSCO콜',
#  '58G859': 'KBG859SK텔레콤콜',
#  '58G860': 'KBG860기아콜',
#  '58G861': 'KBG861셀트리온콜',
#  '58G862': 'KBG862한화솔루콜',
#  '58G863': 'KBG863삼성전자콜',
#  '58G864': 'KBG864KOSPI200풋',
#  '58G865': 'KBG865KOSPI200풋',
#  '58G866': 'KBG866KOSPI200풋',
#  '58G867': 'KBG867KOSPI200풋',
#  '58G868': 'KBG868KOSPI200풋',
#  '58G869': 'KBG869KOSPI200풋',
#  '58G870': 'KBG870KOSPI200풋',
#  '58G871': 'KBG871KOSPI200풋',
#  '58G872': 'KBG872KOSPI200풋',
#  '58G873': 'KBG873KOSPI200풋',
#  '58G874': 'KBG874KOSPI200풋',
#  '58G875': 'KBG875KOSPI200풋',
#  '58G876': 'KBG876KOSPI200풋',
#  '58G877': 'KBG877KOSPI200풋',
#  '58G878': 'KBG878KOSPI200풋',
#  '58G879': 'KBG879KOSPI200풋',
#  '58G880': 'KBG880KOSPI200풋',
#  '58G881': 'KBG881KOSPI200풋',
#  '58G882': 'KBG882KOSPI200풋',
#  '58G883': 'KBG883KOSPI200풋',
#  '58G884': 'KBG884KOSPI200풋',
#  '58G885': 'KBG885KOSPI200풋',
#  '58G886': 'KBG886KOSPI200콜',
#  '58G887': 'KBG887KOSPI200콜',
#  '58G888': 'KBG888KOSPI200콜',
#  '58G889': 'KBG889KOSPI200콜',
#  '58G890': 'KBG890KOSPI200콜',
#  '58G891': 'KBG891KOSPI200콜',
#  '58G892': 'KBG892KOSPI200콜',
#  '58G893': 'KBG893KOSPI200콜',
#  '58G894': 'KBG894KOSPI200콜',
#  '58G895': 'KBG895KOSPI200풋',
#  '58G896': 'KBG896KOSPI200풋',
#  '58G897': 'KBG897KOSPI200풋',
#  '58G898': 'KBG898KOSPI200풋',
#  '58G899': 'KBG899KOSPI200풋',
#  '58G900': 'KBG900KOSPI200풋',
#  '58G901': 'KBG901KOSPI200풋',
#  '58G902': 'KBG902KOSPI200풋',
#  '58G903': 'KBG903KOSPI200풋',
#  '58G904': 'KBG904KOSPI200풋',
#  '58G905': 'KBG905KOSPI200풋',
#  '58G906': 'KBG906KOSPI200풋',
#  '58G907': 'KBG907KOSPI200풋',
#  '58G908': 'KBG908KOSPI200풋',
#  '58G909': 'KBG909KOSPI200풋',
#  '58G910': 'KBG910KOSPI200콜',
#  '58G911': 'KBG911KOSPI200콜',
#  '58G912': 'KBG912KOSPI200콜',
#  '58G913': 'KBG913KOSPI200콜',
#  '58G914': 'KBG914KOSPI200콜',
#  '58G915': 'KBG915KOSPI200콜',
#  '58G916': 'KBG916KOSPI200콜',
#  '58G917': 'KBG917KOSPI200콜',
#  '58G918': 'KBG918KOSPI200콜',
#  '58G919': 'KBG919KOSPI200콜',
#  '58G920': 'KBG920KOSPI200풋',
#  '58G921': 'KBG921KOSPI200풋',
#  '58G922': 'KBG922KOSPI200풋',
#  '58G923': 'KBG923KOSPI200풋',
#  '58G924': 'KBG924KOSPI200풋',
#  '58G925': 'KBG925KOSPI200풋',
#  '58G926': 'KBG926KOSPI200풋',
#  '58G927': 'KBG927KOSPI200풋',
#  '58G928': 'KBG928KOSPI200풋',
#  '58G929': 'KBG929KOSPI200풋',
#  '58G930': 'KBG930KOSPI200콜',
#  '58G931': 'KBG931KOSPI200콜',
#  '58G932': 'KBG932KOSPI200콜',
#  '58G933': 'KBG933KOSPI200콜',
#  '58G934': 'KBG934KOSPI200콜',
#  '58G935': 'KBG935KOSPI200풋',
#  '58G936': 'KBG936KOSPI200풋',
#  '58G937': 'KBG937KOSPI200풋',
#  '58G938': 'KBG938KOSPI200풋',
#  '58G939': 'KBG939KOSPI200풋',
#  '58G940': 'KBG940KOSPI200콜',
#  '58G941': 'KBG941KOSPI200콜',
#  '58G942': 'KBG942KOSPI200콜',
#  '58G943': 'KBG943KOSPI200콜',
#  '58G944': 'KBG944KOSPI200콜',
#  '58G945': 'KBG945KOSPI200풋',
#  '58G946': 'KBG946KOSPI200풋',
#  '58G947': 'KBG947KOSPI200풋',
#  '58G948': 'KBG948KOSPI200풋',
#  '58G949': 'KBG949KOSPI200풋',
#  '58G952': 'KBG952엘지디스콜',
#  '58G953': 'KBG953엘지디스콜',
#  '58G954': 'KBG954LG생건콜',
#  '58G956': 'KBG956LG화학콜',
#  '58G957': 'KBG957LG화학콜',
#  '58G958': 'KBG958네이버콜',
#  '58G960': 'KBG960네이버풋',
#  '58G961': 'KBG961POSCO콜',
#  '58G962': 'KBG962POSCO콜',
#  '58G963': 'KBG963POSCO콜',
#  '58G964': 'KBG964POSCO풋',
#  '58G965': 'KBG965SK이노콜',
#  '58G966': 'KBG966SK케미칼콜',
#  '58G967': 'KBG967SK텔레콤콜',
#  '58G968': 'KBG968SK텔레콤콜',
#  '58G970': 'KBG970SK하이닉콜',
#  '58G971': 'KBG971SK하이닉풋',
#  '58G972': 'KBG972S-OIL콜',
#  '58G973': 'KBG973S-OIL콜',
#  '58G974': 'KBG974S-OIL풋',
#  '58G975': 'KBG975금호석유콜',
#  '58G976': 'KBG976기아콜',
#  '58G977': 'KBG977기아풋',
#  '58G978': 'KBG978넷마블콜',
#  '58G979': 'KBG979녹십자콜',
#  '58G981': 'KBG981롯데케미콜',
#  '58G982': 'KBG982만도콜',
#  '58G983': 'KBG983삼성SDI콜',
#  '58G985': 'KBG985삼성물산콜',
#  '58G986': 'KBG986삼성바이콜',
#  '58G987': 'KBG987삼성바이콜',
#  '58G988': 'KBG988삼성바이풋',
#  '58G989': 'KBG989삼성SDS콜',
#  '58G990': 'KBG990삼성SDS콜',
#  '58G992': 'KBG992삼성전기콜',
#  '58G993': 'KBG993삼성전자콜',
#  '58G994': 'KBG994삼성전자콜',
#  '58G995': 'KBG995삼성전자풋',
#  '58G996': 'KBG996셀트리온콜',
#  '58G997': 'KBG997셀트리온콜',
#  '58G998': 'KBG998셀트리온풋',
#  '58G999': 'KBG999셀트헬스콜',
#  '58GA00': 'KBGA00셀트헬스풋',
#  '58GA01': 'KBGA01신한지주콜',
#  '58GA02': 'KBGA02신한지주콜',
#  '58GA03': 'KBGA03신한지주풋',
#  '58GA04': 'KBGA04아모레콜',
#  '58GA05': 'KBGA05아모레콜',
#  '58GA06': 'KBGA06아모레풋',
#  '58GA08': 'KBGA08NC소프트콜',
#  '58GA09': 'KBGA09NC소프트콜',
#  '58GA10': 'KBGA10NC소프트풋',
#  '58GA11': 'KBGA11이마트콜',
#  '58GA12': 'KBGA12카카오콜',
#  '58GA14': 'KBGA14카카오풋',
#  '58GA15': 'KBGA15포스코케콜',
#  '58GA16': 'KBGA16하나금융콜',
#  '58GA17': 'KBGA17하나금융콜',
#  '58GA18': 'KBGA18하나금융풋',
#  '58GA19': 'KBGA19하이브콜',
#  '58GA20': 'KBGA20하이브콜',
#  '58GA21': 'KBGA21한국전력콜',
#  '58GA22': 'KBGA22한국조선콜',
#  '58GA23': 'KBGA23한국조선콜',
#  '58GA24': 'KBGA24한국조선풋',
#  '58GA25': 'KBGA25한화솔루콜',
#  '58GA26': 'KBGA26글로비스콜',
#  '58GA27': 'KBGA27모비스콜',
#  '58GA28': 'KBGA28모비스풋',
#  '58GA29': 'KBGA29현대차콜',
#  '58GA30': 'KBGA30현대차풋',
#  '58GA31': 'KBGA31호텔신라콜',
#  '58GA32': 'KBGA32호텔신라콜',
#  '58GA33': 'KBGA33호텔신라풋',
#  '58GA34': 'KBGA34케이티지풋',
#  '58GA35': 'KBGA35케이티지콜',
#  '58GA36': 'KBGA36엘지디스콜',
#  '58GA39': 'KBGA39네이버콜',
#  '58GA40': 'KBGA40네이버콜',
#  '58GA41': 'KBGA41POSCO콜',
#  '58GA42': 'KBGA42POSCO콜',
#  '58GA43': 'KBGA43SK이노콜',
#  '58GA44': 'KBGA44SK케미칼콜',
#  '58GA45': 'KBGA45SK텔레콤콜',
#  '58GA46': 'KBGA46SK텔레콤콜',
#  '58GA47': 'KBGA47SK하이닉콜',
#  '58GA48': 'KBGA48S-OIL콜',
#  '58GA49': 'KBGA49금호석유콜',
#  '58GA50': 'KBGA50기아콜',
#  '58GA51': 'KBGA51두산퓨얼콜',
#  '58GA52': 'KBGA52롯데케미풋',
#  '58GA53': 'KBGA53롯데케미콜',
#  '58GA54': 'KBGA54만도콜',
#  '58GA55': 'KBGA55삼성SDI콜',
#  '58GA56': 'KBGA56삼성물산콜',
#  '58GA57': 'KBGA57삼성바이콜',
#  '58GA58': 'KBGA58삼성전기콜',
#  '58GA59': 'KBGA59삼성전자콜',
#  '58GA60': 'KBGA60삼성전자콜',
#  '58GA61': 'KBGA61셀트리온콜',
#  '58GA62': 'KBGA62셀트리온콜',
#  '58GA63': 'KBGA63셀트제약콜',
#  '58GA64': 'KBGA64셀트헬스콜',
#  '58GA65': 'KBGA65신한지주콜',
#  '58GA66': 'KBGA66아모레콜',
#  '58GA67': 'KBGA67아모레콜',
#  '58GA68': 'KBGA68NC소프트콜',
#  '58GA69': 'KBGA69NC소프트콜',
#  '58GA70': 'KBGA70카카오콜',
#  '58GA71': 'KBGA71하나금융콜',
#  '58GA72': 'KBGA72하이브콜',
#  '58GA73': 'KBGA73하이브콜',
#  '58GA74': 'KBGA74한국전력콜',
#  '58GA75': 'KBGA75한국조선콜',
#  '58GA76': 'KBGA76한화솔루콜',
#  '58GA77': 'KBGA77글로비스콜',
#  '58GA78': 'KBGA78모비스콜',
#  '58GA79': 'KBGA79현대차콜',
#  '58GA80': 'KBGA80호텔신라콜',
#  '58GA81': 'KBGA81엘지디스콜',
#  '58GA82': 'KBGA82LG화학콜',
#  '58GA83': 'KBGA83네이버콜',
#  '58GA84': 'KBGA84POSCO콜',
#  '58GA85': 'KBGA85SK텔레콤콜',
#  '58GA86': 'KBGA86SK텔레콤풋',
#  '58GA87': 'KBGA87SK하이닉콜',
#  '58GA88': 'KBGA88삼성SDI콜',
#  '58GA89': 'KBGA89삼성바이콜',
#  '58GA90': 'KBGA90삼성전자콜',
#  '58GA91': 'KBGA91삼성전자콜',
#  '58GA92': 'KBGA92셀트리온콜',
#  '58GA93': 'KBGA93셀트리온풋',
#  '58GA95': 'KBGA95신한지주콜',
#  '58GA96': 'KBGA96아모레콜',
#  '58GA97': 'KBGA97NC소프트콜',
#  '58GA98': 'KBGA98카카오콜',
#  '58GA99': 'KBGA99하나금융콜',
#  '58GB00': 'KBGB00모비스콜',
#  '58GB01': 'KBGB01현대차콜',
#  '58GB02': 'KBGB02케이티지콜',
#  '58GB03': 'KBGB03엘지디스콜',
#  '58GB04': 'KBGB04엘지전자콜',
#  '58GB05': 'KBGB05LG화학콜',
#  '58GB06': 'KBGB06POSCO콜',
#  '58GB07': 'KBGB07SK텔레콤콜',
#  '58GB08': 'KBGB08SK하이닉콜',
#  '58GB09': 'KBGB09삼성SDI콜',
#  '58GB10': 'KBGB10삼성SDS콜',
#  '58GB11': 'KBGB11삼성전자콜',
#  '58GB12': 'KBGB12삼성전자풋',
#  '58GB13': 'KBGB13신한지주콜',
#  '58GB14': 'KBGB14하나금융콜',
#  '58GB15': 'KBGB15SK하이닉콜',
#  '58GB16': 'KBGB16삼성전자콜',
#  '58GB17': 'KBGB17셀트리온콜',
#  '58GB18': 'KBGB18삼성전자콜',
#  '58GB19': 'KBGB19삼성전자풋',
#  '58GB20': 'KBGB20KOSPI200풋',
#  '58GB21': 'KBGB21KOSPI200풋',
#  '58GB22': 'KBGB22KOSPI200풋',
#  '58GB23': 'KBGB23KOSPI200풋',
#  '58GB24': 'KBGB24KOSPI200풋',
#  '58GB25': 'KBGB25KOSPI200풋',
#  '58GB26': 'KBGB26KOSPI200풋',
#  '58GB27': 'KBGB27KOSPI200풋',
#  '58GB28': 'KBGB28KOSPI200풋',
#  '58GB29': 'KBGB29KOSPI200풋',
#  '58GB30': 'KBGB30KOSPI200풋',
#  '58GB31': 'KBGB31KOSPI200풋',
#  '58GB32': 'KBGB32KOSPI200풋',
#  '58GB33': 'KBGB33KOSPI200풋',
#  '58GB34': 'KBGB34KOSPI200풋',
#  '58GB35': 'KBGB35KOSPI200콜',
#  '58GB36': 'KBGB36KOSPI200콜',
#  '58GB37': 'KBGB37KOSPI200콜',
#  '58GB38': 'KBGB38KOSPI200콜',
#  '58GB39': 'KBGB39KOSPI200콜',
#  '58GB40': 'KBGB40KOSPI200콜',
#  '58GB41': 'KBGB41KOSPI200콜',
#  '58GB42': 'KBGB42KOSPI200콜',
#  '58GB43': 'KBGB43KOSPI200콜',
#  '58GB44': 'KBGB44KOSPI200콜',
#  '58GB45': 'KBGB45KOSPI200콜',
#  '58GB46': 'KBGB46KOSPI200콜',
#  '58GB47': 'KBGB47KOSPI200콜',
#  '58GB48': 'KBGB48KOSPI200콜',
#  '58GB49': 'KBGB49KOSPI200콜',
#  '58GB50': 'KBGB50KOSPI200풋',
#  '58GB51': 'KBGB51KOSPI200풋',
#  '58GB52': 'KBGB52KOSPI200풋',
#  '58GB53': 'KBGB53KOSPI200풋',
#  '58GB54': 'KBGB54KOSPI200풋',
#  '58GB55': 'KBGB55KOSPI200풋',
#  '58GB56': 'KBGB56KOSPI200풋',
#  '58GB57': 'KBGB57KOSPI200풋',
#  '58GB58': 'KBGB58KOSPI200풋',
#  '58GB59': 'KBGB59KOSPI200풋',
#  '58GB60': 'KBGB60KOSPI200풋',
#  '58GB61': 'KBGB61KOSPI200풋',
#  '58GB62': 'KBGB62KOSPI200풋',
#  '58GB63': 'KBGB63KOSPI200풋',
#  '58GB64': 'KBGB64KOSPI200풋',
#  '58GB65': 'KBGB65KOSPI200콜',
#  '58GB66': 'KBGB66KOSPI200콜',
#  '58GB67': 'KBGB67KOSPI200콜',
#  '58GB68': 'KBGB68KOSPI200콜',
#  '58GB69': 'KBGB69KOSPI200콜',
#  '58GB70': 'KBGB70KOSPI200콜',
#  '58GB71': 'KBGB71KOSPI200콜',
#  '58GB72': 'KBGB72KOSPI200콜',
#  '58GB73': 'KBGB73KOSPI200콜',
#  '58GB74': 'KBGB74KOSPI200콜',
#  '58GB75': 'KBGB75KOSPI200콜',
#  '58GB76': 'KBGB76KOSPI200콜',
#  '58GB77': 'KBGB77KOSPI200콜',
#  '58GB78': 'KBGB78KOSPI200콜',
#  '58GB79': 'KBGB79KOSPI200콜',
#  '58GB80': 'KBGB80KOSPI200콜',
#  '58GB81': 'KBGB81KOSPI200콜',
#  '58GB82': 'KBGB82KOSPI200콜',
#  '58GB83': 'KBGB83KOSPI200콜',
#  '58GB84': 'KBGB84KOSPI200콜',
#  '58GB85': 'KBGB85엘지디스콜',
#  '58GB86': 'KBGB86엘지디스풋',
#  '58GB87': 'KBGB87LG이노텍콜',
#  '58GB88': 'KBGB88엘지전자풋',
#  '58GB89': 'KBGB89LG화학콜',
#  '58GB90': 'KBGB90네이버콜',
#  '58GB91': 'KBGB91POSCO콜',
#  '58GB92': 'KBGB92POSCO풋',
#  '58GB93': 'KBGB93SK콜',
#  '58GB94': 'KBGB94SK이노콜',
#  '58GB97': 'KBGB97S-OIL콜',
#  '58GB98': 'KBGB98S-OIL콜',
#  '58GB99': 'KBGB99S-OIL풋',
#  '58GC00': 'KBGC00금호석유콜',
#  '58GC01': 'KBGC01기아콜',
#  '58GC02': 'KBGC02기아풋',
#  '58GC03': 'KBGC03넷마블콜',
#  '58GC04': 'KBGC04넷마블풋',
#  '58GC05': 'KBGC05녹십자콜',
#  '58GC06': 'KBGC06롯데케미콜',
#  '58GC07': 'KBGC07롯데케미풋',
#  '58GC08': 'KBGC08만도콜',
#  '58GC09': 'KBGC09삼성SDI콜',
#  '58GC11': 'KBGC11삼성물산콜',
#  '58GC12': 'KBGC12삼성바이콜',
#  '58GC13': 'KBGC13삼성전자콜',
#  '58GC14': 'KBGC14삼성전자콜',
#  '58GC15': 'KBGC15삼성전자콜',
#  '58GC16': 'KBGC16삼성전자풋',
#  '58GC18': 'KBGC18셀트헬스콜',
#  '58GC20': 'KBGC20신한지주풋',
#  '58GC22': 'KBGC22NC소프트콜',
#  '58GC23': 'KBGC23카카오콜',
#  '58GC24': 'KBGC24포스코케콜',
#  '58GC25': 'KBGC25하나금융콜',
#  '58GC26': 'KBGC26하나금융콜',
#  '58GC27': 'KBGC27하나금융풋',
#  '58GC28': 'KBGC28한국전력풋',
#  '58GC29': 'KBGC29한국조선콜',
#  '58GC30': 'KBGC30한국항공콜',
#  '58GC31': 'KBGC31한화솔루콜',
#  '58GC32': 'KBGC32모비스콜',
#  '58GC33': 'KBGC33현대제철콜',
#  '58GC34': 'KBGC34현대제철콜',
#  '58GC35': 'KBGC35현대제철풋',
#  '58GC36': 'KBGC36현대차콜',
#  '58GC37': 'KBGC37현대차풋',
#  '58GC38': 'KBGC38호텔신라콜',
#  '58GC39': 'KBGC39호텔신라풋',
#  '58GC40': 'KBGC40LG생건콜',
#  '58GC41': 'KBGC41LG이노텍콜',
#  '58GC42': 'KBGC42LG화학콜',
#  '58GC43': 'KBGC43LG화학풋',
#  '58GC44': 'KBGC44네이버콜',
#  '58GC45': 'KBGC45POSCO콜',
#  '58GC46': 'KBGC46SK콜',
#  '58GC47': 'KBGC47SK하이닉콜',
#  '58GC48': 'KBGC48S-OIL콜',
#  '58GC49': 'KBGC49금호석유콜',
#  '58GC50': 'KBGC50넷마블콜',
#  '58GC52': 'KBGC52두산퓨얼콜',
#  '58GC53': 'KBGC53롯데케미콜',
#  '58GC54': 'KBGC54만도콜',
#  '58GC55': 'KBGC55삼성물산콜',
#  '58GC56': 'KBGC56삼성SDS콜',
#  '58GC57': 'KBGC57삼성전기콜',
#  '58GC58': 'KBGC58삼성전자콜',
#  '58GC59': 'KBGC59셀트헬스풋',
#  '58GC60': 'KBGC60신한지주콜',
#  '58GC61': 'KBGC61이마트콜',
#  '58GC62': 'KBGC62카카오풋',
#  '58GC64': 'KBGC64하이브콜',
#  '58GC65': 'KBGC65한국전력콜',
#  '58GC66': 'KBGC66한국조선콜',
#  '58GC67': 'KBGC67한화솔루콜',
#  '58GC68': 'KBGC68글로비스콜',
#  '58GC69': 'KBGC69모비스콜',
#  '58GC70': 'KBGC70현대제철콜',
#  '58GC71': 'KBGC71호텔신라콜',
#  '58GC72': 'KBGC72엘지디스콜',
#  '58GC73': 'KBGC73엘지전자콜',
#  '58GC74': 'KBGC74LG화학콜',
#  '58GC76': 'KBGC76POSCO콜',
#  '58GC77': 'KBGC77SK콜',
#  '58GC78': 'KBGC78SK이노콜',
#  '58GC80': 'KBGC80SK하이닉콜',
#  '58GC81': 'KBGC81SK하이닉콜',
#  '58GC82': 'KBGC82기아콜',
#  '58GC84': 'KBGC84롯데케미콜',
#  '58GC85': 'KBGC85삼성SDI콜',
#  '58GC86': 'KBGC86삼성물산콜',
#  '58GC87': 'KBGC87삼성바이콜',
#  '58GC88': 'KBGC88삼성전기콜',
#  '58GC89': 'KBGC89삼성전자풋',
#  '58GC90': 'KBGC90셀트리온콜',
#  '58GC91': 'KBGC91셀트제약콜',
#  '58GC92': 'KBGC92셀트헬스콜',
#  '58GC93': 'KBGC93아모레콜',
#  '58GC94': 'KBGC94NC소프트콜',
#  '58GC95': 'KBGC95이마트콜',
#  '58GC96': 'KBGC96카카오콜',
#  '58GC98': 'KBGC98하나금융콜',
#  '58GC99': 'KBGC99글로비스콜',
#  '58GD00': 'KBGD00모비스콜',
#  '58GD01': 'KBGD01현대차콜',
#  '58GD02': 'KBGD02현대차콜',
#  '58GD03': 'KBGD03호텔신라콜',
#  '58GD04': 'KBGD04엘지전자콜',
#  '58GD05': 'KBGD05LG화학콜',
#  '58GD06': 'KBGD06네이버콜',
#  '58GD07': 'KBGD07POSCO콜',
#  '58GD09': 'KBGD09SK하이닉콜',
#  '58GD10': 'KBGD10기아콜',
#  '58GD12': 'KBGD12롯데케미콜',
#  '58GD13': 'KBGD13삼성SDI콜',
#  '58GD14': 'KBGD14삼성바이콜',
#  '58GD15': 'KBGD15삼성전자콜',
#  '58GD16': 'KBGD16셀트리온콜',
#  '58GD17': 'KBGD17신한지주콜',
#  '58GD18': 'KBGD18아모레콜',
#  '58GD19': 'KBGD19한국항공콜',
#  '58GD20': 'KBGD20모비스콜',
#  '58GD21': 'KBGD21현대차콜',
#  '58GD22': 'KBGD22엘지디스콜',
#  '58GD23': 'KBGD23SK하이닉콜',
#  '58GD24': 'KBGD24기아콜',
#  '58GD25': 'KBGD25삼성물산콜',
#  '58GD26': 'KBGD26삼성전자콜',
#  '58GD27': 'KBGD27셀트리온콜',
#  '58GD28': 'KBGD28NC소프트콜',
#  '58GD29': 'KBGD29하나금융콜',
#  '58GD30': 'KBGD30현대차콜',
#  '58GD31': 'KBGD31삼성전자콜',
#  '58GD32': 'KBGD32카카오콜',
#  '58GD33': 'KBGD33하나금융콜',
#  '58GD34': 'KBGD34한국전력콜',
#  '58GD35': 'KBGD35KOSPI200콜',
#  '58GD36': 'KBGD36KOSPI200콜',
#  '58GD37': 'KBGD37KOSPI200콜',
#  '58GD38': 'KBGD38KOSPI200콜',
#  '58GD39': 'KBGD39KOSPI200콜',
#  '58GD40': 'KBGD40KOSPI200콜',
#  '58GD41': 'KBGD41KOSPI200콜',
#  '58GD42': 'KBGD42KOSPI200콜',
#  '58GD43': 'KBGD43KOSPI200콜',
#  '58GD44': 'KBGD44KOSPI200콜',
#  '58GD45': 'KBGD45KOSPI200콜',
#  '58GD46': 'KBGD46KOSPI200콜',
#  '58GD47': 'KBGD47KOSPI200콜',
#  '58GD48': 'KBGD48KOSPI200콜',
#  '58GD49': 'KBGD49KOSPI200콜',
#  '58GD50': 'KBGD50KOSPI200콜',
#  '58GD51': 'KBGD51KOSPI200콜',
#  '58GD52': 'KBGD52KOSPI200풋',
#  '58GD53': 'KBGD53KOSPI200풋',
#  '58GD54': 'KBGD54KOSPI200풋',
#  '58GD55': 'KBGD55KOSPI200풋',
#  '58GD56': 'KBGD56KOSPI200풋',
#  ...}

# %% [markdown]
# ## 3개월 모멘텀

# %%
def momentum_3months(stocks): # 종목 list넣으면, 모멘텀 순위 있는 데이터프레임 출력
    df = pd.DataFrame()
    for s in stocks:
      df[s] = fdr.DataReader( s, '2021-01-01')['Close']
    
    # 60 영업일 수익률
    return_df = df.pct_change(60)
    return_df
    
    # 오늘 날짜
    today = datetime.datetime.today().strftime("%Y-%m-%d")
    
    # index는 종목 코드이고 모멘텀 데이터 있는 데이터 프레임으로 만들기
    s = return_df.loc[today]
    momentum_df = pd.DataFrame(s)
    momentum_df.columns = ["모멘텀"]
    
    momentum_df['순위'] = momentum_df['모멘텀'].rank(ascending=False)
    momentum_df = momentum_df.sort_values(by='순위')
    return momentum_df # 모멘텀

# %%
momentum_3months_rank = momentum_3months(stocks)

# %%
momentum_3months_rank
# Out:
#              모멘텀   순위
# 136510  4.555556  1.0
# 065440  2.842900  2.0
# 007390  2.336735  3.0
# 102460  2.189873  4.0
# 291230  1.989933  5.0
# ...          ...  ...
# 303530       NaN  NaN
# 276730       NaN  NaN
# 363250       NaN  NaN
# 365270       NaN  NaN
# 377400       NaN  NaN
#
# [2391 rows x 2 columns]

# %%
momentum_3months_rank.head(30)
# Out:
#              모멘텀    순위
# 136510  4.555556   1.0
# 065440  2.842900   2.0
# 007390  2.336735   3.0
# 102460  2.189873   4.0
# 291230  1.989933   5.0
# 130660  1.828185   6.0
# 151860  1.799708   7.0
# 011000  1.762943   8.0
# 043100  1.712585   9.0
# 069640  1.668213  10.0
# 196700  1.660714  11.0
# 024740  1.580952  12.0
# 185490  1.567793  13.0
# 003925  1.546358  14.0
# 215090  1.475248  15.0
# 189860  1.419006  16.0
# 049480  1.410596  17.0
# 048550  1.317784  18.0
# 001440  1.309735  19.0
# 289220  1.225150  20.0
# 006660  1.196970  21.0
# 002410  1.196841  22.0
# 104620  1.118980  23.0
# 016920  1.105263  24.0
# 189330  1.096812  25.0
# 041510  1.085667  26.0
# 205500  1.081433  27.0
# 090150  1.080023  28.0
# 171090  1.064516  29.0
# 011700  1.056561  30.0

# %%
momentum_3months_rank.tail(30)
# Out:
#              모멘텀      순위
# 101390 -0.430464  2362.0
# 004835 -0.436404  2363.0
# 139670 -0.459510  2364.0
# 032860 -0.477966  2365.0
# 156100 -0.495620  2366.0
# 064510 -0.506726  2367.0
# 007700 -0.577778  2368.0
# 221610 -0.631858  2369.0
# 383220       NaN     NaN
# 383800       NaN     NaN
# 38380K       NaN     NaN
# 361610       NaN     NaN
# 137310       NaN     NaN
# 380440       NaN     NaN
# 380320       NaN     NaN
# 377630       NaN     NaN
# 361670       NaN     NaN
# 252990       NaN     NaN
# 352480       NaN     NaN
# 357580       NaN     NaN
# 187660       NaN     NaN
# 357230       NaN     NaN
# 383310       NaN     NaN
# 376190       NaN     NaN
# 352910       NaN     NaN
# 303530       NaN     NaN
# 276730       NaN     NaN
# 363250       NaN     NaN
# 365270       NaN     NaN
# 377400       NaN     NaN

# %%
momentum_3months_rank.to_csv("momentum_3months_rank.csv")

# %% [markdown]
# ## 미리 csv 파일로 저장해 둔 모멘텀 3개월 결과 불러오기

# %%
momentum_3months_rank = pd.read_csv('momentum_3months_rank.csv')
momentum_3months_rank
# Out:
#      Unnamed: 0       모멘텀   순위
# 0        136510  4.555556  1.0
# 1        065440  2.842900  2.0
# 2        007390  2.336735  3.0
# 3        102460  2.189873  4.0
# 4        291230  1.989933  5.0
# ...         ...       ...  ...
# 2386     303530       NaN  NaN
# 2387     276730       NaN  NaN
# 2388     363250       NaN  NaN
# 2389     365270       NaN  NaN
# 2390     377400       NaN  NaN
#
# [2391 rows x 3 columns]

# %%
momentum_3months_rank.index = momentum_3months_rank['Unnamed: 0']
momentum_3months_rank
# Out:
#            Unnamed: 0       모멘텀   순위
# Unnamed: 0
# 136510         136510  4.555556  1.0
# 065440         065440  2.842900  2.0
# 007390         007390  2.336735  3.0
# 102460         102460  2.189873  4.0
# 291230         291230  1.989933  5.0
# ...               ...       ...  ...
# 303530         303530       NaN  NaN
# 276730         276730       NaN  NaN
# 363250         363250       NaN  NaN
# 365270         365270       NaN  NaN
# 377400         377400       NaN  NaN
#
# [2391 rows x 3 columns]

# %%
momentum_3months_rank = momentum_3months_rank.drop('Unnamed: 0', axis=1)
momentum_3months_rank
# Out:
#                  모멘텀   순위
# Unnamed: 0
# 136510      4.555556  1.0
# 065440      2.842900  2.0
# 007390      2.336735  3.0
# 102460      2.189873  4.0
# 291230      1.989933  5.0
# ...              ...  ...
# 303530           NaN  NaN
# 276730           NaN  NaN
# 363250           NaN  NaN
# 365270           NaN  NaN
# 377400           NaN  NaN
#
# [2391 rows x 2 columns]

# %% [markdown]
# ### 모멘텀 3개월 종목 저장

# %%
import requests

# %%
assets = np.array(momentum_3months_rank.index[:30])
assets
# Out:
# array(['136510', '065440', '007390', '102460', '291230', '130660',
#        '151860', '011000', '043100', '069640', '196700', '024740',
#        '185490', '003925', '215090', '189860', '049480', '048550',
#        '001440', '289220', '006660', '002410', '104620', '016920',
#        '189330', '041510', '205500', '090150', '171090', '011700'],
#       dtype=object)

# %%
len(assets)
# Out:
# 30

# %% [markdown]
# ### 3년치 주가 데이터 가져오기

# %%
# 종목별 종가 가져오기
from datetime import datetime

#시작일
start_date = '2018-07-19'

# today = datetime.today().strftime('%Y-%m-%d')
end_date = '2021-07-19'

# 각 주식의 일별 종가 데이터를 저장할 데이터 프레임을 생성
#Create a dataframe to store the adjusted close price of the stocks
df = pd.DataFrame()

# FinanceDataReader로 각 종목의 종가데이터 불러오기
for stock in assets:
  df[stock] = fdr.DataReader(stock, start_date, end_date)['Close']
df
# Out:
#             136510  065440  007390  102460  ...  205500  090150  171090  011700
# Date                                        ...
# 2018-07-19   10550    1597    8097   20695  ...    6060    1954    9899    2590
# 2018-07-20   10500    1656    7381   20695  ...    5990    1926    9866    2520
# 2018-07-23   10450    1585    6273   19616  ...    5870    1860    9665    2250
# 2018-07-24   10900    1614    6541   19420  ...    5890    1883    9665    2300
# 2018-07-25   10850    1568    6025   19028  ...    5860    1801    9498    2285
# ...            ...     ...     ...     ...  ...     ...     ...     ...     ...
# 2021-07-13   39100    6060   29200   69000  ...    5710    5200   29800    3060
# 2021-07-14   40100    6340   30800   69500  ...    5950    5290   28850    3035
# 2021-07-15   37600    6470   30850   66900  ...    7200    5450   28600    3945
# 2021-07-16   38050    6790   30900   64200  ...    6680    6870   28500    4240
# 2021-07-19   38100    6790   31500   64000  ...    6750    7460   28900    4240
#
# [740 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 740 entries, 2018-07-19 to 2021-07-19
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   136510  740 non-null    int64
#  1   065440  740 non-null    int64
#  2   007390  740 non-null    int64
#  3   102460  740 non-null    int64
#  4   291230  701 non-null    float64
#  5   130660  740 non-null    int64
#  6   151860  740 non-null    int64
#  7   011000  740 non-null    int64
#  8   043100  740 non-null    int64
#  9   069640  740 non-null    int64
#  10  196700  740 non-null    int64
#  11  024740  740 non-null    int64
#  12  185490  740 non-null    int64
#  13  003925  740 non-null    int64
#  14  215090  740 non-null    int64
#  15  189860  740 non-null    int64
#  16  049480  740 non-null    int64
#  17  048550  740 non-null    int64
#  18  001440  740 non-null    int64
#  19  289220  82 non-null     float64
#  20  006660  740 non-null    int64
#  21  002410  740 non-null    int64
#  22  104620  610 non-null    float64
#  23  016920  740 non-null    int64
#  24  189330  740 non-null    int64
#  25  041510  740 non-null    int64
#  26  205500  740 non-null    int64
#  27  090150  740 non-null    int64
#  28  171090  740 non-null    int64
#  29  011700  740 non-null    int64
# dtypes: float64(3), int64(27)
# memory usage: 179.2 KB

# %%
df.isnull().sum()
# Out:
# 136510      0
# 065440      0
# 007390      0
# 102460      0
# 291230     39
# 130660      0
# 151860      0
# 011000      0
# 043100      0
# 069640      0
# 196700      0
# 024740      0
# 185490      0
# 003925      0
# 215090      0
# 189860      0
# 049480      0
# 048550      0
# 001440      0
# 289220    658
# 006660      0
# 002410      0
# 104620    130
# 016920      0
# 189330      0
# 041510      0
# 205500      0
# 090150      0
# 171090      0
# 011700      0
# dtype: int64

# %%
# 결측값 있는 열 삭제 
df2 = df.dropna(axis = 1)
df2
# Out:
#             136510  065440  007390  102460  ...  205500  090150  171090  011700
# Date                                        ...
# 2018-07-19   10550    1597    8097   20695  ...    6060    1954    9899    2590
# 2018-07-20   10500    1656    7381   20695  ...    5990    1926    9866    2520
# 2018-07-23   10450    1585    6273   19616  ...    5870    1860    9665    2250
# 2018-07-24   10900    1614    6541   19420  ...    5890    1883    9665    2300
# 2018-07-25   10850    1568    6025   19028  ...    5860    1801    9498    2285
# ...            ...     ...     ...     ...  ...     ...     ...     ...     ...
# 2021-07-13   39100    6060   29200   69000  ...    5710    5200   29800    3060
# 2021-07-14   40100    6340   30800   69500  ...    5950    5290   28850    3035
# 2021-07-15   37600    6470   30850   66900  ...    7200    5450   28600    3945
# 2021-07-16   38050    6790   30900   64200  ...    6680    6870   28500    4240
# 2021-07-19   38100    6790   31500   64000  ...    6750    7460   28900    4240
#
# [740 rows x 27 columns]

# %% [markdown]
# ### 종목별 연평균 기대수익률 & 일간수익률의 공분산

# %%
# !pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Downloading PyPortfolioOpt-1.4.2-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 4.3 MB/s
# Requirement already satisfied: numpy<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.1.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.4.1)
# Collecting cvxpy<2.0.0,>=1.1.10
#   Downloading cvxpy-1.1.14-cp37-cp37m-manylinux_2_24_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 13.5 MB/s
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.1.4)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.7.post1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Installing collected packages: cvxpy, PyPortfolioOpt
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.0.31
#     Uninstalling cvxpy-1.0.31:
#       Successfully uninstalled cvxpy-1.0.31
# Successfully installed PyPortfolioOpt-1.4.2 cvxpy-1.1.14

# %%
# Optimize the portfolio
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %% [markdown]
# #### ver01> 종가에 결측값이 있는 종목을 삭제하지 않은 df로 포트폴리오 구성 ( 30개 종목 )

# %%
# Calculate the expected annualized returns
# 복리 연평균 수익률
# return (1 + returns).prod() ** (frequency / returns.count()) - 1
mu = expected_returns.mean_historical_return(df)

# Calculate the annualized sample covariance matrix of the daily asset returns
S = risk_models.sample_cov(df)

# %%
mu
# Out:
# 136510     0.549413
# 065440     0.638104
# 007390     0.589228
# 102460     0.469596
# 291230     0.465929
# 130660     0.694829
# 151860     0.789651
# 011000     1.232125
# 043100    -0.115291
# 069640     0.154612
# 196700     0.365017
# 024740     0.498344
# 185490     0.365521
# 003925     0.226030
# 215090    -0.121315
# 189860     0.361153
# 049480     0.436163
# 048550     0.079680
# 001440     0.351069
# 289220    40.879485
# 006660     0.367212
# 002410     0.697577
# 104620    -0.032231
# 016920     0.472299
# 189330     0.422897
# 041510     0.163103
# 205500     0.037456
# 090150     0.579063
# 171090     0.441020
# 011700     0.183033
# dtype: float64

# %%
len(mu)
# Out:
# 30

# %%
S
# Out:
#           136510    065440    007390  ...    090150    171090    011700
# 136510  0.675205  0.106758  0.090744  ...  0.074828  0.106117  0.064143
# 065440  0.106758  0.480319  0.108589  ...  0.092534  0.119450  0.099805
# 007390  0.090744  0.108589  0.734352  ...  0.051091  0.086537  0.077099
# 102460  0.078838  0.157315  0.151970  ...  0.110294  0.076611  0.081934
# 291230  0.026346  0.048542 -0.006457  ...  0.007195  0.030776  0.010482
# 130660  0.072076  0.052769  0.021664  ...  0.098871  0.051155  0.051730
# 151860  0.092655  0.108229  0.074487  ...  0.055425  0.114379  0.065786
# 011000  0.029052  0.068350  0.106834  ...  0.063753  0.048507  0.038829
# 043100  0.038086  0.023303  0.020454  ...  0.017216  0.038472  0.022555
# 069640  0.060459  0.100820  0.084953  ...  0.046946  0.079596  0.045558
# 196700  0.190424  0.090799  0.048732  ...  0.089004  0.094448  0.086928
# 024740  0.035409  0.138331  0.021738  ...  0.030711  0.058524  0.048320
# 185490  0.086125  0.163619  0.204781  ...  0.092436  0.084353  0.081182
# 003925  0.054658  0.047990  0.039716  ...  0.036758  0.046001  0.037156
# 215090  0.100857  0.112748  0.066202  ...  0.076199  0.137480  0.087990
# 189860  0.127165  0.095615  0.044395  ...  0.104505  0.080535  0.088540
# 049480  0.122322  0.208405  0.096402  ...  0.090795  0.114651  0.086894
# 048550  0.102609  0.091899  0.063757  ...  0.069046  0.092993  0.082257
# 001440  0.128246  0.086336  0.081541  ...  0.062647  0.070053  0.071015
# 289220  0.012927 -0.104649  0.085509  ... -0.088360  0.309304 -0.111875
# 006660  0.023302  0.033877  0.032580  ...  0.026085  0.041368  0.029837
# 002410  0.085662  0.119627  0.089750  ...  0.033692  0.126261  0.092784
# 104620  0.090865  0.105221  0.056511  ...  0.085252  0.101860  0.069123
# 016920  0.076935  0.104069  0.094291  ...  0.044175  0.107129  0.070304
# 189330 -0.017147 -0.024787  0.057154  ...  0.019772  0.029828 -0.004043
# 041510  0.071345  0.085759  0.078426  ...  0.050046  0.091005  0.063060
# 205500  0.059663  0.068439  0.050354  ...  0.069092  0.113445  0.076244
# 090150  0.074828  0.092534  0.051091  ...  0.420480  0.070477  0.067587
# 171090  0.106117  0.119450  0.086537  ...  0.070477  0.486436  0.093271
# 011700  0.064143  0.099805  0.077099  ...  0.067587  0.093271  0.236239
#
# [30 rows x 30 columns]

# %%
len(S)
# Out:
# 30

# %%
S.shape
# Out:
# (30, 30)

# %%
# 수익률의 공분산
from pypfopt import plotting

plotting.plot_covariance(S)
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### ver02> 종가에 결측값이 있는 종목을 삭제한 df2로 포트폴리오 구성 ( 27개 종목 )

# %%
# Calculate the expected annualized returns
# 복리 연평균 수익률
# return (1 + returns).prod() ** (frequency / returns.count()) - 1
mu2 = expected_returns.mean_historical_return(df2) 

# Calculate the annualized sample covariance matrix of the daily asset returns
S2 = risk_models.sample_cov(df2)

# %%
mu2
# Out:
# 136510    0.549413
# 065440    0.638104
# 007390    0.589228
# 102460    0.469596
# 130660    0.694829
# 151860    0.789651
# 011000    1.232125
# 043100   -0.115291
# 069640    0.154612
# 196700    0.365017
# 024740    0.498344
# 185490    0.365521
# 003925    0.226030
# 215090   -0.121315
# 189860    0.361153
# 049480    0.436163
# 048550    0.079680
# 001440    0.351069
# 006660    0.367212
# 002410    0.697577
# 016920    0.472299
# 189330    0.422897
# 041510    0.163103
# 205500    0.037456
# 090150    0.579063
# 171090    0.441020
# 011700    0.183033
# dtype: float64

# %%
len(mu2)
# Out:
# 27

# %%
S2.shape
# Out:
# (27, 27)

# %%
len(S2)
# Out:
# 27

# %%
S2
# Out:
#           136510    065440    007390  ...    090150    171090    011700
# 136510  0.675205  0.106758  0.090744  ...  0.074828  0.106117  0.064143
# 065440  0.106758  0.480319  0.108589  ...  0.092534  0.119450  0.099805
# 007390  0.090744  0.108589  0.734352  ...  0.051091  0.086537  0.077099
# 102460  0.078838  0.157315  0.151970  ...  0.110294  0.076611  0.081934
# 130660  0.072076  0.052769  0.021664  ...  0.098871  0.051155  0.051730
# 151860  0.092655  0.108229  0.074487  ...  0.055425  0.114379  0.065786
# 011000  0.029052  0.068350  0.106834  ...  0.063753  0.048507  0.038829
# 043100  0.038086  0.023303  0.020454  ...  0.017216  0.038472  0.022555
# 069640  0.060459  0.100820  0.084953  ...  0.046946  0.079596  0.045558
# 196700  0.190424  0.090799  0.048732  ...  0.089004  0.094448  0.086928
# 024740  0.035409  0.138331  0.021738  ...  0.030711  0.058524  0.048320
# 185490  0.086125  0.163619  0.204781  ...  0.092436  0.084353  0.081182
# 003925  0.054658  0.047990  0.039716  ...  0.036758  0.046001  0.037156
# 215090  0.100857  0.112748  0.066202  ...  0.076199  0.137480  0.087990
# 189860  0.127165  0.095615  0.044395  ...  0.104505  0.080535  0.088540
# 049480  0.122322  0.208405  0.096402  ...  0.090795  0.114651  0.086894
# 048550  0.102609  0.091899  0.063757  ...  0.069046  0.092993  0.082257
# 001440  0.128246  0.086336  0.081541  ...  0.062647  0.070053  0.071015
# 006660  0.023302  0.033877  0.032580  ...  0.026085  0.041368  0.029837
# 002410  0.085662  0.119627  0.089750  ...  0.033692  0.126261  0.092784
# 016920  0.076935  0.104069  0.094291  ...  0.044175  0.107129  0.070304
# 189330 -0.017147 -0.024787  0.057154  ...  0.019772  0.029828 -0.004043
# 041510  0.071345  0.085759  0.078426  ...  0.050046  0.091005  0.063060
# 205500  0.059663  0.068439  0.050354  ...  0.069092  0.113445  0.076244
# 090150  0.074828  0.092534  0.051091  ...  0.420480  0.070477  0.067587
# 171090  0.106117  0.119450  0.086537  ...  0.070477  0.486436  0.093271
# 011700  0.064143  0.099805  0.077099  ...  0.067587  0.093271  0.236239
#
# [27 rows x 27 columns]

# %%
# 수익률의 공분산
from pypfopt import plotting

plotting.plot_covariance(S2)

# %% [markdown]
# # 포트폴리오 최적화 ( Efficient Risk )

# %% [markdown]
# #### ver01> 결측값 삭제하지 않음 / df / mu, S / ef, cleaned_weights ( 30개 종목 )

# %%
# !pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.1.5)
# Requirement already satisfied: numpy<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.19.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.1.14)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.7.post1)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.1.4)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)

# %%
import pypfopt
pypfopt.__version__
# Out:
# '1.4.2'

# %%
# Efficient_risk로 최적화 했을때의 결과 확인
vol_limit = 0.3
ef = EfficientFrontier(mu, S)
ef.efficient_risk(vol_limit)
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 1163.8%
# Annual volatility: 30.0%
# Sharpe Ratio: 38.73
# (11.637663274373745, 0.30000000000653254, 38.72554424706923)

# %%
# max_sharpe로 최적화 했을때의 결과 확인
ef = EfficientFrontier(mu, S)
ef.max_sharpe()
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 2040.6%
# Annual volatility: 47.7%
# Sharpe Ratio: 42.71
# (20.406046874608354, 0.4773192536786198, 42.709458538486544)

# %%
from pypfopt import risk_models, expected_returns
from pypfopt import EfficientFrontier, objective_functions
import cvxpy as cp

# Risk 범위 내에서 Return을 최대로 !
vol_limit = 0.3

ef = EfficientFrontier(mu, S)  # Create the Efficient Frontier Object

weights = ef.efficient_risk(vol_limit)

cleaned_weights = ef.clean_weights()
print(cleaned_weights)

# calculates the expected return, volatility and Sharpe ratio for the optimized portfolio.
ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('136510', 0.0), ('065440', 0.02325), ('007390', 0.0), ('102460', 0.0722), ('291230', 0.03326), ('130660', 0.06181), ('151860', 0.0), ('011000', 0.0644), ('043100', 0.10229), ('069640', 0.0), ('196700', 0.06019), ('024740', 0.00714), ('185490', 0.0), ('003925', 0.0), ('215090', 0.0), ('189860', 0.0), ('049480', 0.0), ('048550', 0.0), ('001440', 0.0), ('289220', 0.27795), ('006660', 0.01208), ('002410', 0.0), ('104620', 0.00936), ('016920', 0.0), ('189330', 0.03016), ('041510', 0.04644), ('205500', 0.01306), ('090150', 0.04027), ('171090', 0.0), ('011700', 0.14615)])
# Expected annual return: 1163.8%
# Annual volatility: 30.0%
# Sharpe Ratio: 38.73
# (11.637663274373745, 0.30000000000653254, 38.72554424706923)

# %%
weights
# Out:
# OrderedDict([('136510', 3.722215e-10),
#              ('065440', 0.023247504851403),
#              ('007390', 1.505712e-10),
#              ('102460', 0.0722023036261644),
#              ('291230', 0.0332634432895211),
#              ('130660', 0.0618137394006222),
#              ('151860', 2.018366e-10),
#              ('011000', 0.0644012567023894),
#              ('043100', 0.1022872365950554),
#              ('069640', 7.036336e-10),
#              ('196700', 0.0601904720545005),
#              ('024740', 0.0071394841976988),
#              ('185490', 7.508534e-09),
#              ('003925', 9.530701e-10),
#              ('215090', 5.53012e-11),
#              ('189860', 1.47934e-10),
#              ('049480', 3.141609e-10),
#              ('048550', 3.962617e-10),
#              ('001440', 1.566351e-10),
#              ('289220', 0.2779480249516074),
#              ('006660', 0.0120750450698903),
#              ('002410', 2.082489e-10),
#              ('104620', 0.0093608832225455),
#              ('016920', 7.056252e-10),
#              ('189330', 0.0301557709032653),
#              ('041510', 0.0464390383053694),
#              ('205500', 0.013060805163722),
#              ('090150', 0.0402684316371573),
#              ('171090', 7.0187e-11),
#              ('011700', 0.146146548084362)])

# %%
len(weights)
# Out:
# 30

# %%
cleaned_weights
# Out:
# OrderedDict([('136510', 0.0),
#              ('065440', 0.02325),
#              ('007390', 0.0),
#              ('102460', 0.0722),
#              ('291230', 0.03326),
#              ('130660', 0.06181),
#              ('151860', 0.0),
#              ('011000', 0.0644),
#              ('043100', 0.10229),
#              ('069640', 0.0),
#              ('196700', 0.06019),
#              ('024740', 0.00714),
#              ('185490', 0.0),
#              ('003925', 0.0),
#              ('215090', 0.0),
#              ('189860', 0.0),
#              ('049480', 0.0),
#              ('048550', 0.0),
#              ('001440', 0.0),
#              ('289220', 0.27795),
#              ('006660', 0.01208),
#              ('002410', 0.0),
#              ('104620', 0.00936),
#              ('016920', 0.0),
#              ('189330', 0.03016),
#              ('041510', 0.04644),
#              ('205500', 0.01306),
#              ('090150', 0.04027),
#              ('171090', 0.0),
#              ('011700', 0.14615)])

# %%
len(cleaned_weights)
# Out:
# 30

# %%
# 효율적 투자선와 각 종목의 수익률 & 변동성
import matplotlib.pyplot as plt

# ef = EfficientFrontier(mu, S, solver='SCS')

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=True)
plt.legend(loc='best')
plt.show()

# %%
# Show Efficient Frontier
fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=False)

# Find the tangency portfolio
vol_limit = 0.3
ef.efficient_risk(vol_limit)
ret_tangent, std_tangent, _ = ef.portfolio_performance()  # 기대수익률 , Risk(변동성)
ax.scatter(std_tangent, ret_tangent, marker="*", s=200, c="r", label="Efficient Risk")

# Generate random portfolios
n_samples = 20000
w = np.random.dirichlet(np.ones(len(mu)), n_samples) # 난수로 20000세트의 투자비중 만들기
rets = w.dot(mu)                                     # 기대수익률
stds = np.sqrt(np.diag(w @ S @ w.T))                 # Risk(변동성)
sharpes = rets / stds                                # 샤프비율

ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")

# Output
ax.set_title("Efficient Frontier with random portfolios")
ax.legend(loc='best')
plt.tight_layout()
plt.savefig("ef_scatter.png", dpi=200)
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# Max.Sharpe Ratio로 최적화한 포트폴리오의 수익률과 변동성, 샤프비율
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 1163.8%
# Annual volatility: 30.0%
# Sharpe Ratio: 38.73
# (11.637663287255238, 0.30000000000599136, 38.7255442900774)

# %%
# 종목별 투자비중
plotting.plot_weights(weights, ax=None)

# %% [markdown]
# #### ver02> 결측값 삭제 / df2 / mu2, S2 / ef2, cleaned_weights2 ( 27개 종목 )

# %%
# Efficient_risk로 최적화 했을때의 결과 확인
vol_limit2 = 0.3
ef2 = EfficientFrontier(mu2, S2)
ef2.efficient_risk(vol_limit2)
ef2.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 69.2%
# Annual volatility: 30.0%
# Sharpe Ratio: 2.24
# (0.6919015616615467, 0.299999999971376, 2.23967187241885)

# %%
# max_sharpe로 최적화 했을때의 결과 확인
ef2 = EfficientFrontier(mu2, S2)
ef2.max_sharpe()
ef2.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 65.2%
# Annual volatility: 28.0%
# Sharpe Ratio: 2.25
# (0.6516480657781353, 0.280280967562221, 2.253624537092097)

# %%
# Risk 범위 내에서 Return을 최대로 !
vol_limit2 = 0.3
ef2 = EfficientFrontier(mu2, S2)  # Create the Efficient Frontier Object

weights2 = ef2.efficient_risk(vol_limit2)

cleaned_weights2 = ef2.clean_weights()
print(cleaned_weights2)

# calculates the expected return, volatility and Sharpe ratio for the optimized portfolio.
ef2.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('136510', 0.01396), ('065440', 0.01925), ('007390', 0.02803), ('102460', 0.0), ('130660', 0.28437), ('151860', 0.15671), ('011000', 0.12509), ('043100', 0.0), ('069640', 0.0), ('196700', 0.0), ('024740', 0.08048), ('185490', 0.0), ('003925', 0.0), ('215090', 0.0), ('189860', 0.0), ('049480', 0.0), ('048550', 0.0), ('001440', 0.0), ('006660', 0.11845), ('002410', 0.06048), ('016920', 0.03035), ('189330', 0.05201), ('041510', 0.0), ('205500', 0.0), ('090150', 0.03081), ('171090', 0.0), ('011700', 0.0)])
# Expected annual return: 69.2%
# Annual volatility: 30.0%
# Sharpe Ratio: 2.24
# (0.6919015616615467, 0.299999999971376, 2.23967187241885)

# %%
weights2
# Out:
# OrderedDict([('136510', 0.0139633954272238),
#              ('065440', 0.0192491069900593),
#              ('007390', 0.0280276967861697),
#              ('102460', 5.38192e-11),
#              ('130660', 0.2843675383098298),
#              ('151860', 0.1567137089030465),
#              ('011000', 0.1250941736217034),
#              ('043100', 2.84441e-11),
#              ('069640', 4.51163e-11),
#              ('196700', 8.78538e-11),
#              ('024740', 0.0804784631769231),
#              ('185490', 4.51858e-11),
#              ('003925', 1.029736e-10),
#              ('215090', 1.77904e-11),
#              ('189860', 5.56352e-11),
#              ('049480', 8.58006e-11),
#              ('048550', 3.71765e-11),
#              ('001440', 1.540253e-10),
#              ('006660', 0.118449244766404),
#              ('002410', 0.0604810431816466),
#              ('016920', 0.0303542333910541),
#              ('189330', 0.0520123563098876),
#              ('041510', 6.55652e-11),
#              ('205500', 3.14623e-11),
#              ('090150', 0.0308090381521021),
#              ('171090', 1.284873e-10),
#              ('011700', 4.49309e-11)])

# %%
len(weights2)
# Out:
# 27

# %%
cleaned_weights2
# Out:
# OrderedDict([('136510', 0.01396),
#              ('065440', 0.01925),
#              ('007390', 0.02803),
#              ('102460', 0.0),
#              ('130660', 0.28437),
#              ('151860', 0.15671),
#              ('011000', 0.12509),
#              ('043100', 0.0),
#              ('069640', 0.0),
#              ('196700', 0.0),
#              ('024740', 0.08048),
#              ('185490', 0.0),
#              ('003925', 0.0),
#              ('215090', 0.0),
#              ('189860', 0.0),
#              ('049480', 0.0),
#              ('048550', 0.0),
#              ('001440', 0.0),
#              ('006660', 0.11845),
#              ('002410', 0.06048),
#              ('016920', 0.03035),
#              ('189330', 0.05201),
#              ('041510', 0.0),
#              ('205500', 0.0),
#              ('090150', 0.03081),
#              ('171090', 0.0),
#              ('011700', 0.0)])

# %%
len(cleaned_weights2)
# Out:
# 27

# %%
# 효율적 투자선와 각 종목의 수익률 & 변동성
import matplotlib.pyplot as plt

ef2 = EfficientFrontier(mu2, S2, solver='SCS')

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef2, ax=ax, show_assets=True)
plt.legend(loc='best')
plt.show()

# %%
# Show Efficient Frontier
fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef2, ax=ax, show_assets=False)

# Find the tangency portfolio
vol_limit2 = 0.3
ef2.efficient_risk(vol_limit2)
ret_tangent2, std_tangent2, _ = ef2.portfolio_performance()  # 기대수익률 , Risk(변동성)
ax.scatter(std_tangent2, ret_tangent2, marker="*", s=200, c="r", label="Efficient Risk")

# Generate random portfolios
n_samples = 20000
w2 = np.random.dirichlet(np.ones(len(mu2)), n_samples) # 난수로 20000세트의 투자비중 만들기
rets2 = w2.dot(mu2)                                     # 기대수익률
stds2 = np.sqrt(np.diag(w2 @ S2 @ w2.T))                 # Risk(변동성)
sharpes2 = rets2 / stds2                                # 샤프비율

ax.scatter(stds2, rets2, marker=".", c=sharpes, cmap="viridis_r")

# Output
ax.set_title("Efficient Frontier with random portfolios")
ax.legend(loc='best')
plt.tight_layout()
plt.savefig("ef_scatter.png", dpi=200)
plt.show()

# %%
# Efficient Risk로 최적화한 포트폴리오의 수익률과 변동성, 샤프비율
ef2.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 69.2%
# Annual volatility: 30.0%
# Sharpe Ratio: 2.24
# (0.6918220333323708, 0.29998427545988054, 2.239524162733054)

# %%
# 종목별 투자비중
plotting.plot_weights(weights2, ax=None)

# %% [markdown]
# ### 투자금액과 포트폴리오의 비중에 맞추어 수량 할당

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.4-py3-none-any.whl (40.6 MB)
#      |████████████████████████████████| 40.6 MB 33 kB/s
# Collecting amply>=0.1.2
#   Downloading amply-0.1.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (2.4.7)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (0.17.1)
# Installing collected packages: amply, pulp
# Successfully installed amply-0.1.4 pulp-2.4

# %% [markdown]
# #### ver01> 결측값 삭제하지 않음 / df / mu, S / ef, cleaned_weights ( 30개 종목 )

# %%
# Get the discrete allocation of each sharpe per stock
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

# 투자금액 (단위: KRW)
portfolio_val = 15000000

latest_prices = get_latest_prices(df)

weights = cleaned_weights

da = DiscreteAllocation(weights, latest_prices, total_portfolio_value=portfolio_val)

allocation, leftover = da.lp_portfolio(verbose=False)

print('Discrete Allocaion: ', allocation)
print('Funds Remaining: ', leftover, ' KRW')

rmse = da._allocation_rmse_error(verbose=False)
# Out:
# Discrete Allocaion:  {'065440': 51, '102460': 17, '291230': 62, '130660': 58, '011000': 19, '043100': 933, '196700': 152, '024740': 21, '215090': 1, '289220': 44, '006660': 7, '104620': 13, '189330': 5, '041510': 11, '205500': 29, '090150': 81, '011700': 517}
# Funds Remaining:  1439.0  KRW
# Allocation has RMSE: 0.000

# %%
allocation
# Out:
# {'006660': 7,
#  '011000': 19,
#  '011700': 517,
#  '024740': 21,
#  '041510': 11,
#  '043100': 933,
#  '065440': 51,
#  '090150': 81,
#  '102460': 17,
#  '104620': 13,
#  '130660': 58,
#  '189330': 5,
#  '196700': 152,
#  '205500': 29,
#  '215090': 1,
#  '289220': 44,
#  '291230': 62}

# %%
len(allocation)
# Out:
# 17

# %% [markdown]
# #### ver02> 결측값 삭제하지 않음 / df2 / mu2, S2 / ef2, cleaned_weights2 /  ( 27개 종목 )

# %%
# Get the discrete allocation of each sharpe per stock
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

# 투자금액 (단위: KRW)
portfolio_val = 15000000

latest_prices2 = get_latest_prices(df2)

weights2 = cleaned_weights2

da2 = DiscreteAllocation(weights2, latest_prices2, total_portfolio_value=portfolio_val)

allocation2, leftover2 = da2.lp_portfolio(verbose=False)

print('Discrete Allocaion: ', allocation2)
print('Funds Remaining: ', leftover2, ' KRW')

rmse2 = da2._allocation_rmse_error(verbose=False)
# Out:
# Discrete Allocaion:  {'136510': 6, '065440': 43, '007390': 13, '130660': 268, '151860': 113, '011000': 36, '024740': 238, '006660': 66, '002410': 111, '016920': 83, '189330': 9, '090150': 62}
# Funds Remaining:  1700.0  KRW
# Allocation has RMSE: 0.000

# %%
allocation2
# Out:
# {'002410': 111,
#  '006660': 66,
#  '007390': 13,
#  '011000': 36,
#  '016920': 83,
#  '024740': 238,
#  '065440': 43,
#  '090150': 62,
#  '130660': 268,
#  '136510': 6,
#  '151860': 113,
#  '189330': 9}

# %%
len(allocation2)
# Out:
# 12

# %% [markdown]
# ### 포트폴리오 결과로 보여줄 변수 저장

# %% [markdown]
# #### ver01> 결측값 삭제하지 않음 ( 30개 종목 )

# %%
# 각 종목별 실제 투자 금액
inv_total_price = {}

for i in allocation.keys():
  inv_total_price[i] = latest_prices.loc[i]*allocation[i]
inv_total_price
# Out:
# {'006660': 188300.0,
#  '011000': 980400.0,
#  '011700': 2192080.0,
#  '024740': 106890.0,
#  '041510': 685300.0,
#  '043100': 1534785.0,
#  '065440': 346290.0,
#  '090150': 604260.0,
#  '102460': 1088000.0,
#  '104620': 137111.0,
#  '130660': 925100.0,
#  '189330': 429000.0,
#  '196700': 902880.0,
#  '205500': 195750.0,
#  '215090': 2075.0,
#  '289220': 4180000.0,
#  '291230': 500340.0}

# %%
# 총 투자금액
investment = 0

for i in inv_total_price.values():
    investment += i
print(investment)
# Out:
# 14998561.0

# %%
portfolio_val-leftover
# Out:
# 14998561.0

# %%
# 각 종목별 실제 투자 비중
inv_total_weight = {}

for i in allocation.keys():
  inv_total_weight[i] = inv_total_price[i]/investment
inv_total_weight
# Out:
# {'006660': 0.012554537731986422,
#  '011000': 0.06536627080424583,
#  '011700': 0.14615268758116196,
#  '024740': 0.007126683686521661,
#  '041510': 0.04569104996139296,
#  '043100': 0.10232881674448635,
#  '065440': 0.023088214929418895,
#  '090150': 0.04028786494917746,
#  '102460': 0.07254029236538091,
#  '104620': 0.00914161031848322,
#  '130660': 0.06167925042942453,
#  '189330': 0.028602743956570233,
#  '196700': 0.06019777497321243,
#  '205500': 0.013051252050113342,
#  '215090': 0.0001383466053843432,
#  '289220': 0.27869340265376125,
#  '291230': 0.03335920025927821}

# %%
# 투자비중의 합계
investment_w = 0

for i in inv_total_weight.values():
    investment_w += i
print(investment_w)
# Out:
# 1.0

# %%
# 결과값으로 불러올 값을 리스트로 저장
name_list = []                    # 종목명(회사이름)
total_price_stock =[]             # 각 종목별 실제 투자 금액
total_weight_stock = []           # 각 종목별 실제 투자 비중

for i in allocation.keys(): # i = 포트폴리오에 할당된 종목의 종목코드
    name_list.append(code_name_dict.get(i))
    total_price_stock.append(inv_total_price.get(i))
    total_weight_stock.append(inv_total_weight.get(i))

# %%
name_list
# Out:
# ['이루온',
#  '이연제약',
#  '삼성스팩2호',
#  '한전산업',
#  '진원생명과학',
#  '솔고바이오',
#  '웹스',
#  '한일단조',
#  '이디티',
#  '자이언트스텝',
#  '삼성공조',
#  '노랑풍선',
#  '씨이랩',
#  '에스엠',
#  '액션스퀘어',
#  '광진윈텍',
#  '한신기계']

# %%
total_price_stock
# Out:
# [346290.0,
#  1088000.0,
#  500340.0,
#  925100.0,
#  980400.0,
#  1534785.0,
#  902880.0,
#  106890.0,
#  2075.0,
#  4180000.0,
#  188300.0,
#  137111.0,
#  429000.0,
#  685300.0,
#  195750.0,
#  604260.0,
#  2192080.0]

# %%
total_weight_stock
# Out:
# [0.023088214929418895,
#  0.07254029236538091,
#  0.03335920025927821,
#  0.06167925042942453,
#  0.06536627080424583,
#  0.10232881674448635,
#  0.06019777497321243,
#  0.007126683686521661,
#  0.0001383466053843432,
#  0.27869340265376125,
#  0.012554537731986422,
#  0.00914161031848322,
#  0.028602743956570233,
#  0.04569104996139296,
#  0.013051252050113342,
#  0.04028786494917746,
#  0.14615268758116196]

# %%
# Get the discrete allocation values
discrete_allocation_list = []
for symbol in allocation:
  discrete_allocation_list.append(allocation.get(symbol))

# %%
discrete_allocation_list
# Out:
# [51, 17, 62, 58, 19, 933, 152, 21, 1, 44, 7, 13, 5, 11, 29, 81, 517]

# %%
# Create a dataframe for the portfolio
portfolio_df = pd.DataFrame(columns = ['종목명','종목코드','수량(주)', '투자금액(원)','투자비중'])
portfolio_df
# Out:
# Empty DataFrame
# Columns: [종목명, 종목코드, 수량(주), 투자금액(원), 투자비중]
# Index: []

# %%
# portfolio_df['Company_name'] = company_name
portfolio_df['종목명'] = name_list
portfolio_df['종목코드'] = allocation
portfolio_df['수량(주)'] = discrete_allocation_list
portfolio_df['투자금액(원)'] = total_price_stock
portfolio_df['투자비중'] = total_weight_stock

# %%
portfolio_df
# Out:
#        종목명    종목코드  수량(주)    투자금액(원)      투자비중
# 0      이루온  065440     51   346290.0  0.023088
# 1     이연제약  102460     17  1088000.0  0.072540
# 2   삼성스팩2호  291230     62   500340.0  0.033359
# 3     한전산업  130660     58   925100.0  0.061679
# 4   진원생명과학  011000     19   980400.0  0.065366
# 5    솔고바이오  043100    933  1534785.0  0.102329
# 6       웹스  196700    152   902880.0  0.060198
# 7     한일단조  024740     21   106890.0  0.007127
# 8      이디티  215090      1     2075.0  0.000138
# 9   자이언트스텝  289220     44  4180000.0  0.278693
# 10    삼성공조  006660      7   188300.0  0.012555
# 11    노랑풍선  104620     13   137111.0  0.009142
# 12     씨이랩  189330      5   429000.0  0.028603
# 13     에스엠  041510     11   685300.0  0.045691
# 14   액션스퀘어  205500     29   195750.0  0.013051
# 15    광진윈텍  090150     81   604260.0  0.040288
# 16    한신기계  011700    517  2192080.0  0.146153

# %%
# Sort by allocation & Show the portfolio
portfolio_df_sorted = portfolio_df.sort_values('투자비중', ascending = False)
portfolio_df_sorted = portfolio_df_sorted.reset_index(drop=True)
portfolio_df_sorted
# Out:
#        종목명    종목코드  수량(주)    투자금액(원)      투자비중
# 0   자이언트스텝  289220     44  4180000.0  0.278693
# 1     한신기계  011700    517  2192080.0  0.146153
# 2    솔고바이오  043100    933  1534785.0  0.102329
# 3     이연제약  102460     17  1088000.0  0.072540
# 4   진원생명과학  011000     19   980400.0  0.065366
# 5     한전산업  130660     58   925100.0  0.061679
# 6       웹스  196700    152   902880.0  0.060198
# 7      에스엠  041510     11   685300.0  0.045691
# 8     광진윈텍  090150     81   604260.0  0.040288
# 9   삼성스팩2호  291230     62   500340.0  0.033359
# 10     씨이랩  189330      5   429000.0  0.028603
# 11     이루온  065440     51   346290.0  0.023088
# 12   액션스퀘어  205500     29   195750.0  0.013051
# 13    삼성공조  006660      7   188300.0  0.012555
# 14    노랑풍선  104620     13   137111.0  0.009142
# 15    한일단조  024740     21   106890.0  0.007127
# 16     이디티  215090      1     2075.0  0.000138

# %% [markdown]
# ### 투자 금액에 따라 최적화된 포트폴리오의 종목별 수량

# %%
portfolio_df_sorted.loc["합계",2:] = portfolio_df_sorted.sum()
portfolio_df_sorted
# Out:
#        종목명    종목코드   수량(주)     투자금액(원)      투자비중
# 0   자이언트스텝  289220    44.0   4180000.0  0.278693
# 1     한신기계  011700   517.0   2192080.0  0.146153
# 2    솔고바이오  043100   933.0   1534785.0  0.102329
# 3     이연제약  102460    17.0   1088000.0  0.072540
# 4   진원생명과학  011000    19.0    980400.0  0.065366
# 5     한전산업  130660    58.0    925100.0  0.061679
# 6       웹스  196700   152.0    902880.0  0.060198
# 7      에스엠  041510    11.0    685300.0  0.045691
# 8     광진윈텍  090150    81.0    604260.0  0.040288
# 9   삼성스팩2호  291230    62.0    500340.0  0.033359
# 10     씨이랩  189330     5.0    429000.0  0.028603
# 11     이루온  065440    51.0    346290.0  0.023088
# 12   액션스퀘어  205500    29.0    195750.0  0.013051
# 13    삼성공조  006660     7.0    188300.0  0.012555
# 14    노랑풍선  104620    13.0    137111.0  0.009142
# 15    한일단조  024740    21.0    106890.0  0.007127
# 16     이디티  215090     1.0      2075.0  0.000138
# 합계     NaN     NaN  2021.0  14998561.0  1.000000

# %% [markdown]
# #### ver02> 결측값 삭제 ( 27개 종목 )

# %%
# 각 종목별 실제 투자 금액
inv_total_price2 = {}

for i in allocation2.keys():
  inv_total_price2[i] = latest_prices2.loc[i]*allocation2[i]
inv_total_price2
# Out:
# {'002410': 909090,
#  '006660': 1775400,
#  '007390': 409500,
#  '011000': 1857600,
#  '016920': 460650,
#  '024740': 1211420,
#  '065440': 291970,
#  '090150': 462520,
#  '130660': 4274600,
#  '136510': 228600,
#  '151860': 2344750,
#  '189330': 772200}

# %%
# 총 투자금액
investment2 = 0

for i in inv_total_price2.values():
    investment2 += i
print(investment2)
# Out:
# 14998300

# %%
portfolio_val-leftover2
# Out:
# 14998300.0

# %%
# 각 종목별 실제 투자 비중
inv_total_weight2 = {}

for i in allocation2.keys():
  inv_total_weight2[i] = inv_total_price2[i]/investment2
inv_total_weight2
# Out:
# {'002410': 0.06061286945853864,
#  '006660': 0.1183734156537741,
#  '007390': 0.02730309435069308,
#  '011000': 0.1238540367908363,
#  '016920': 0.030713480861164266,
#  '024740': 0.08077048732189648,
#  '065440': 0.01946687291226339,
#  '090150': 0.030838161658321275,
#  '130660': 0.28500563397185014,
#  '136510': 0.015241727395771522,
#  '151860': 0.15633438456358387,
#  '189330': 0.051485835061306946}

# %%
# 투자비중의 합계
investment_w2 = 0

for i in inv_total_weight2.values():
    investment_w2 += i
print(investment_w2)
# Out:
# 1.0

# %%
# 결과값으로 불러올 값을 리스트로 저장
name_list2 = []                    # 종목명(회사이름)
total_price_stock2 =[]             # 각 종목별 실제 투자 금액
total_weight_stock2 = []           # 각 종목별 실제 투자 비중

for i in allocation2.keys(): # i = 포트폴리오에 할당된 종목의 종목코드
    name_list2.append(code_name_dict.get(i))
    total_price_stock2.append(inv_total_price2.get(i))
    total_weight_stock2.append(inv_total_weight2.get(i))

# %%
name_list2
# Out:
# ['쎄미시스코',
#  '이루온',
#  '네이처셀',
#  '한전산업',
#  'KG ETS',
#  '진원생명과학',
#  '한일단조',
#  '삼성공조',
#  '범양건영',
#  '카스',
#  '씨이랩',
#  '광진윈텍']

# %%
total_price_stock2
# Out:
# [228600,
#  291970,
#  409500,
#  4274600,
#  2344750,
#  1857600,
#  1211420,
#  1775400,
#  909090,
#  460650,
#  772200,
#  462520]

# %%
total_weight_stock2
# Out:
# [0.015241727395771522,
#  0.01946687291226339,
#  0.02730309435069308,
#  0.28500563397185014,
#  0.15633438456358387,
#  0.1238540367908363,
#  0.08077048732189648,
#  0.1183734156537741,
#  0.06061286945853864,
#  0.030713480861164266,
#  0.051485835061306946,
#  0.030838161658321275]

# %%
# Get the discrete allocation values
discrete_allocation_list2 = []
for symbol in allocation2:
  discrete_allocation_list2.append(allocation2.get(symbol))

# %%
discrete_allocation_list2
# Out:
# [6, 43, 13, 268, 113, 36, 238, 66, 111, 83, 9, 62]

# %%
# Create a dataframe for the portfolio
portfolio_df2 = pd.DataFrame(columns = ['종목명','종목코드','수량(주)', '투자금액(원)','투자비중'])
portfolio_df2
# Out:
# Empty DataFrame
# Columns: [종목명, 종목코드, 수량(주), 투자금액(원), 투자비중]
# Index: []

# %%
# portfolio_df['Company_name'] = company_name
portfolio_df2['종목명'] = name_list2
portfolio_df2['종목코드'] = allocation2
portfolio_df2['수량(주)'] = discrete_allocation_list2
portfolio_df2['투자금액(원)'] = total_price_stock2
portfolio_df2['투자비중'] = total_weight_stock2

# %%
portfolio_df2
# Out:
#        종목명    종목코드  수량(주)  투자금액(원)      투자비중
# 0    쎄미시스코  136510      6   228600  0.015242
# 1      이루온  065440     43   291970  0.019467
# 2     네이처셀  007390     13   409500  0.027303
# 3     한전산업  130660    268  4274600  0.285006
# 4   KG ETS  151860    113  2344750  0.156334
# 5   진원생명과학  011000     36  1857600  0.123854
# 6     한일단조  024740    238  1211420  0.080770
# 7     삼성공조  006660     66  1775400  0.118373
# 8     범양건영  002410    111   909090  0.060613
# 9       카스  016920     83   460650  0.030713
# 10     씨이랩  189330      9   772200  0.051486
# 11    광진윈텍  090150     62   462520  0.030838

# %%
# Sort by allocation & Show the portfolio
portfolio_df_sorted2 = portfolio_df2.sort_values('투자비중', ascending = False)
portfolio_df_sorted2 = portfolio_df_sorted2.reset_index(drop=True)
portfolio_df_sorted2
# Out:
#        종목명    종목코드  수량(주)  투자금액(원)      투자비중
# 0     한전산업  130660    268  4274600  0.285006
# 1   KG ETS  151860    113  2344750  0.156334
# 2   진원생명과학  011000     36  1857600  0.123854
# 3     삼성공조  006660     66  1775400  0.118373
# 4     한일단조  024740    238  1211420  0.080770
# 5     범양건영  002410    111   909090  0.060613
# 6      씨이랩  189330      9   772200  0.051486
# 7     광진윈텍  090150     62   462520  0.030838
# 8       카스  016920     83   460650  0.030713
# 9     네이처셀  007390     13   409500  0.027303
# 10     이루온  065440     43   291970  0.019467
# 11   쎄미시스코  136510      6   228600  0.015242

# %% [markdown]
# ### 투자 금액에 따라 최적화된 포트폴리오의 종목별 수량

# %%
portfolio_df_sorted2.loc["합계",2:] = portfolio_df_sorted2.sum()
portfolio_df_sorted2
# Out:
#        종목명    종목코드   수량(주)     투자금액(원)      투자비중
# 0     한전산업  130660   268.0   4274600.0  0.285006
# 1   KG ETS  151860   113.0   2344750.0  0.156334
# 2   진원생명과학  011000    36.0   1857600.0  0.123854
# 3     삼성공조  006660    66.0   1775400.0  0.118373
# 4     한일단조  024740   238.0   1211420.0  0.080770
# 5     범양건영  002410   111.0    909090.0  0.060613
# 6      씨이랩  189330     9.0    772200.0  0.051486
# 7     광진윈텍  090150    62.0    462520.0  0.030838
# 8       카스  016920    83.0    460650.0  0.030713
# 9     네이처셀  007390    13.0    409500.0  0.027303
# 10     이루온  065440    43.0    291970.0  0.019467
# 11   쎄미시스코  136510     6.0    228600.0  0.015242
# 합계     NaN     NaN  1048.0  14998300.0  1.000000

# %% [markdown]
# # 포트폴리오의 수익률과 변동성을 벤치마크지수(KOSPI)와 비교

# %% [markdown]
# #### ver01> 결측값 삭제 ( 30개 종목 )

# %%
df
# Out:
#             136510  065440  007390  102460  ...  205500  090150  171090  011700
# Date                                        ...
# 2018-07-19   10550    1597    8097   20695  ...    6060    1954    9899    2590
# 2018-07-20   10500    1656    7381   20695  ...    5990    1926    9866    2520
# 2018-07-23   10450    1585    6273   19616  ...    5870    1860    9665    2250
# 2018-07-24   10900    1614    6541   19420  ...    5890    1883    9665    2300
# 2018-07-25   10850    1568    6025   19028  ...    5860    1801    9498    2285
# ...            ...     ...     ...     ...  ...     ...     ...     ...     ...
# 2021-07-13   39100    6060   29200   69000  ...    5710    5200   29800    3060
# 2021-07-14   40100    6340   30800   69500  ...    5950    5290   28850    3035
# 2021-07-15   37600    6470   30850   66900  ...    7200    5450   28600    3945
# 2021-07-16   38050    6790   30900   64200  ...    6680    6870   28500    4240
# 2021-07-19   38100    6790   31500   64000  ...    6750    7460   28900    4240
#
# [740 rows x 30 columns]

# %%
cleaned_weights
# Out:
# OrderedDict([('136510', 0.0),
#              ('065440', 0.02325),
#              ('007390', 0.0),
#              ('102460', 0.0722),
#              ('291230', 0.03326),
#              ('130660', 0.06181),
#              ('151860', 0.0),
#              ('011000', 0.0644),
#              ('043100', 0.10229),
#              ('069640', 0.0),
#              ('196700', 0.06019),
#              ('024740', 0.00714),
#              ('185490', 0.0),
#              ('003925', 0.0),
#              ('215090', 0.0),
#              ('189860', 0.0),
#              ('049480', 0.0),
#              ('048550', 0.0),
#              ('001440', 0.0),
#              ('289220', 0.27795),
#              ('006660', 0.01208),
#              ('002410', 0.0),
#              ('104620', 0.00936),
#              ('016920', 0.0),
#              ('189330', 0.03016),
#              ('041510', 0.04644),
#              ('205500', 0.01306),
#              ('090150', 0.04027),
#              ('171090', 0.0),
#              ('011700', 0.14615)])

# %%
len(cleaned_weights)
# Out:
# 30

# %%
# 각 일자별, 종목별 종가에 해당 weights를 곱해주기
for i, weight in cleaned_weights.items():
    df[i] = df[i]*weight

# %%
df
# Out:
#             136510     065440  007390  ...     090150  171090     011700
# Date                                   ...
# 2018-07-19     0.0   37.13025     0.0  ...   78.68758     0.0  378.52850
# 2018-07-20     0.0   38.50200     0.0  ...   77.56002     0.0  368.29800
# 2018-07-23     0.0   36.85125     0.0  ...   74.90220     0.0  328.83750
# 2018-07-24     0.0   37.52550     0.0  ...   75.82841     0.0  336.14500
# 2018-07-25     0.0   36.45600     0.0  ...   72.52627     0.0  333.95275
# ...            ...        ...     ...  ...        ...     ...        ...
# 2021-07-13     0.0  140.89500     0.0  ...  209.40400     0.0  447.21900
# 2021-07-14     0.0  147.40500     0.0  ...  213.02830     0.0  443.56525
# 2021-07-15     0.0  150.42750     0.0  ...  219.47150     0.0  576.56175
# 2021-07-16     0.0  157.86750     0.0  ...  276.65490     0.0  619.67600
# 2021-07-19     0.0  157.86750     0.0  ...  300.41420     0.0  619.67600
#
# [740 rows x 30 columns]

# %%
# 일자별 종목의 (종가*비중) 합계를 Port열에 저장
df['Port'] = df.sum(axis = 1)
df
# Out:
#             136510     065440  007390  ...  171090     011700         Port
# Date                                   ...
# 2018-07-19     0.0   37.13025     0.0  ...     0.0  378.52850   5895.93617
# 2018-07-20     0.0   38.50200     0.0  ...     0.0  368.29800   5840.09906
# 2018-07-23     0.0   36.85125     0.0  ...     0.0  328.83750   5612.09329
# 2018-07-24     0.0   37.52550     0.0  ...     0.0  336.14500   5648.23111
# 2018-07-25     0.0   36.45600     0.0  ...     0.0  333.95275   5595.74430
# ...            ...        ...     ...  ...     ...        ...          ...
# 2021-07-13     0.0  140.89500     0.0  ...     0.0  447.21900  37649.47803
# 2021-07-14     0.0  147.40500     0.0  ...     0.0  443.56525  39676.02913
# 2021-07-15     0.0  150.42750     0.0  ...     0.0  576.56175  39871.17079
# 2021-07-16     0.0  157.86750     0.0  ...     0.0  619.67600  39865.31450
# 2021-07-19     0.0  157.86750     0.0  ...     0.0  619.67600  43236.23057
#
# [740 rows x 31 columns]

# %%
# 일자별 종가의 전일대비 변동률(수익률)을 portfolio라는 데이터프레임으로 저장
portfolio = df[['Port']].pct_change()
portfolio
# Out:
#                 Port
# Date
# 2018-07-19       NaN
# 2018-07-20 -0.009470
# 2018-07-23 -0.039041
# 2018-07-24  0.006439
# 2018-07-25 -0.009293
# ...              ...
# 2021-07-13  0.017657
# 2021-07-14  0.053827
# 2021-07-15  0.004918
# 2021-07-16 -0.000147
# 2021-07-19  0.084558
#
# [740 rows x 1 columns]

# %%
# 코스피지수 불러오기
kospi = fdr.DataReader('KS11', start_date, end_date)[['Close']]
kospi
# Out:
#               Close
# Date
# 2018-07-19  2282.29
# 2018-07-20  2289.19
# 2018-07-23  2269.31
# 2018-07-24  2280.20
# 2018-07-25  2273.03
# ...             ...
# 2021-07-13  3271.38
# 2021-07-14  3264.81
# 2021-07-15  3286.22
# 2021-07-16  3276.91
# 2021-07-19  3244.04
#
# [740 rows x 1 columns]

# %%
# 코스피지수의 변동률(수익률) 구하기
# 변동률(수익률) = (당일가격-전일가격) / 전일가격
# 7/20의 변동률(수익률) = (7/20 가격-7-19 가격) / 7/19 가격
kospi_pct = kospi.pct_change()
kospi_pct
# Out:
#                Close
# Date
# 2018-07-19       NaN
# 2018-07-20  0.003023
# 2018-07-23 -0.008684
# 2018-07-24  0.004799
# 2018-07-25 -0.003144
# ...              ...
# 2021-07-13  0.007673
# 2021-07-14 -0.002008
# 2021-07-15  0.006558
# 2021-07-16 -0.002833
# 2021-07-19 -0.010031
#
# [740 rows x 1 columns]

# %%
# 코스피와 포트폴리오 합치기
result = kospi_pct.join(portfolio)
result
# Out:
#                Close      Port
# Date
# 2018-07-19       NaN       NaN
# 2018-07-20  0.003023 -0.009470
# 2018-07-23 -0.008684 -0.039041
# 2018-07-24  0.004799  0.006439
# 2018-07-25 -0.003144 -0.009293
# ...              ...       ...
# 2021-07-13  0.007673  0.017657
# 2021-07-14 -0.002008  0.053827
# 2021-07-15  0.006558  0.004918
# 2021-07-16 -0.002833 -0.000147
# 2021-07-19 -0.010031  0.084558
#
# [740 rows x 2 columns]

# %%
# 1열을 0으로 
result.iloc[0] = 0
result
# Out:
#                Close      Port
# Date
# 2018-07-19  0.000000  0.000000
# 2018-07-20  0.003023 -0.009470
# 2018-07-23 -0.008684 -0.039041
# 2018-07-24  0.004799  0.006439
# 2018-07-25 -0.003144 -0.009293
# ...              ...       ...
# 2021-07-13  0.007673  0.017657
# 2021-07-14 -0.002008  0.053827
# 2021-07-15  0.006558  0.004918
# 2021-07-16 -0.002833 -0.000147
# 2021-07-19 -0.010031  0.084558
#
# [740 rows x 2 columns]

# %%
# 열 이름 변경
result.columns = ['KOSPI', 'PORTFOLIO']
result
# Out:
#                KOSPI  PORTFOLIO
# Date
# 2018-07-19  0.000000   0.000000
# 2018-07-20  0.003023  -0.009470
# 2018-07-23 -0.008684  -0.039041
# 2018-07-24  0.004799   0.006439
# 2018-07-25 -0.003144  -0.009293
# ...              ...        ...
# 2021-07-13  0.007673   0.017657
# 2021-07-14 -0.002008   0.053827
# 2021-07-15  0.006558   0.004918
# 2021-07-16 -0.002833  -0.000147
# 2021-07-19 -0.010031   0.084558
#
# [740 rows x 2 columns]

# %%
# 1에서 시작해서, 전일대비 변동률(수익률)을 적용하여 수치화하기
wealth = (1+result).cumprod()
wealth
# Out:
#                KOSPI  PORTFOLIO
# Date
# 2018-07-19  1.000000   1.000000
# 2018-07-20  1.003023   0.990530
# 2018-07-23  0.994313   0.951858
# 2018-07-24  0.999084   0.957987
# 2018-07-25  0.995943   0.949085
# ...              ...        ...
# 2021-07-13  1.433376   6.385666
# 2021-07-14  1.430497   6.729386
# 2021-07-15  1.439878   6.762483
# 2021-07-16  1.435799   6.761490
# 2021-07-19  1.421397   7.333226
#
# [740 rows x 2 columns]

# %% [markdown]
# ## 시각화

# %%
# 포트폴리오와 KOSPI 지수의 '누적 수익률 추이'를 시각화하여 비교

# matplotlib.pyplot 스타일시트 설정
plt.style.use('fivethirtyeight')

plt.figure(figsize=(18,5))
plt.plot(wealth.index, wealth.KOSPI , 'r', label='KOSPI')
plt.plot(wealth.index, wealth.PORTFOLIO ,'b', label="PORTFOLIO(Momentum 3month)")
plt.grid(True)
plt.title('Return Trend')
plt.xlabel('Date',fontsize=18, labelpad=7)
plt.ylabel('Return',fontsize=18, labelpad=7)
plt.legend(loc='best')
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# 변동률 비교
plt.figure(figsize=(18,10))

plt.subplot(2,1,1)
plt.title('Volatility Trend')

plt.plot(result.index, result.KOSPI , 'r', label='KOSPI')
plt.yticks([-0.15, -0.10, -0.05, 0.00, 0.05, 0.10, 0.15])
plt.grid(True)
plt.ylabel('Volatility',fontsize=18, labelpad=7)
plt.legend(loc='best')

plt.subplot(2,1,2)
plt.title('Volatility Trend')
plt.plot(result.index, result.PORTFOLIO ,'b', label="PORTFOLIO(Momentum 3month)")
# plt.yticks([-0.15, -0.10, -0.05, 0.00, 0.05, 0.10, 0.15])
plt.ylabel('Volatility',fontsize=18, labelpad=7)
plt.legend(loc='best')

plt.grid(True)
plt.show()

# %%
print('----- Momentum 3month portfolio performance -----')
# Show Risk Limit
print('Risk limit: ', vol_limit)

# Show Funds
print('Funds:', portfolio_val, 'KRW')

# Show Funds Remaining
print('Funds Remaining: ', leftover, ' KRW')

# Show Portfolio performance
ef.portfolio_performance(verbose=True)
rmse = da._allocation_rmse_error(verbose=False)
# Out:
# ----- Momentum 3month portfolio performance -----
# Risk limit:  0.3
# Funds: 15000000 KRW
# Funds Remaining:  1439.0  KRW
# Expected annual return: 1163.8%
# Annual volatility: 30.0%
# Sharpe Ratio: 38.73
# Allocation has RMSE: 0.000

# %% [markdown]
# #### ver02> 결측값 삭제 ( 27개 종목 )

# %%
df2
# Out:
#             136510  065440  007390  102460  ...  205500  090150  171090  011700
# Date                                        ...
# 2018-07-19   10550    1597    8097   20695  ...    6060    1954    9899    2590
# 2018-07-20   10500    1656    7381   20695  ...    5990    1926    9866    2520
# 2018-07-23   10450    1585    6273   19616  ...    5870    1860    9665    2250
# 2018-07-24   10900    1614    6541   19420  ...    5890    1883    9665    2300
# 2018-07-25   10850    1568    6025   19028  ...    5860    1801    9498    2285
# ...            ...     ...     ...     ...  ...     ...     ...     ...     ...
# 2021-07-13   39100    6060   29200   69000  ...    5710    5200   29800    3060
# 2021-07-14   40100    6340   30800   69500  ...    5950    5290   28850    3035
# 2021-07-15   37600    6470   30850   66900  ...    7200    5450   28600    3945
# 2021-07-16   38050    6790   30900   64200  ...    6680    6870   28500    4240
# 2021-07-19   38100    6790   31500   64000  ...    6750    7460   28900    4240
#
# [740 rows x 27 columns]

# %%
cleaned_weights2
# Out:
# OrderedDict([('136510', 0.01396),
#              ('065440', 0.01925),
#              ('007390', 0.02803),
#              ('102460', 0.0),
#              ('130660', 0.28437),
#              ('151860', 0.15671),
#              ('011000', 0.12509),
#              ('043100', 0.0),
#              ('069640', 0.0),
#              ('196700', 0.0),
#              ('024740', 0.08048),
#              ('185490', 0.0),
#              ('003925', 0.0),
#              ('215090', 0.0),
#              ('189860', 0.0),
#              ('049480', 0.0),
#              ('048550', 0.0),
#              ('001440', 0.0),
#              ('006660', 0.11845),
#              ('002410', 0.06048),
#              ('016920', 0.03035),
#              ('189330', 0.05201),
#              ('041510', 0.0),
#              ('205500', 0.0),
#              ('090150', 0.03081),
#              ('171090', 0.0),
#              ('011700', 0.0)])

# %%
len(cleaned_weights2)
# Out:
# 27

# %%
# 각 일자별, 종목별 종가에 해당 weights를 곱해주기
for i, weight in cleaned_weights2.items():
    df2[i] = df2[i]*weight

# %%
df2
# Out:
#              136510     065440     007390  ...     090150  171090  011700
# Date                                       ...
# 2018-07-19  147.278   30.74225  226.95891  ...   60.20274     0.0     0.0
# 2018-07-20  146.580   31.87800  206.88943  ...   59.34006     0.0     0.0
# 2018-07-23  145.882   30.51125  175.83219  ...   57.30660     0.0     0.0
# 2018-07-24  152.164   31.06950  183.34423  ...   58.01523     0.0     0.0
# 2018-07-25  151.466   30.18400  168.88075  ...   55.48881     0.0     0.0
# ...             ...        ...        ...  ...        ...     ...     ...
# 2021-07-13  545.836  116.65500  818.47600  ...  160.21200     0.0     0.0
# 2021-07-14  559.796  122.04500  863.32400  ...  162.98490     0.0     0.0
# 2021-07-15  524.896  124.54750  864.72550  ...  167.91450     0.0     0.0
# 2021-07-16  531.178  130.70750  866.12700  ...  211.66470     0.0     0.0
# 2021-07-19  531.876  130.70750  882.94500  ...  229.84260     0.0     0.0
#
# [740 rows x 27 columns]

# %%
# 일자별 종목의 (종가*비중) 합계를 Port열에 저장
df2['Port'] = df2.sum(axis = 1)
df2
# Out:
#              136510     065440     007390  ...  171090  011700         Port
# Date                                       ...
# 2018-07-19  147.278   30.74225  226.95891  ...     0.0     0.0   5777.21847
# 2018-07-20  146.580   31.87800  206.88943  ...     0.0     0.0   5698.14194
# 2018-07-23  145.882   30.51125  175.83219  ...     0.0     0.0   5583.71924
# 2018-07-24  152.164   31.06950  183.34423  ...     0.0     0.0   5672.25064
# 2018-07-25  151.466   30.18400  168.88075  ...     0.0     0.0   5615.91909
# ...             ...        ...        ...  ...     ...     ...          ...
# 2021-07-13  545.836  116.65500  818.47600  ...     0.0     0.0  23717.13790
# 2021-07-14  559.796  122.04500  863.32400  ...     0.0     0.0  23778.04190
# 2021-07-15  524.896  124.54750  864.72550  ...     0.0     0.0  24318.22930
# 2021-07-16  531.178  130.70750  866.12700  ...     0.0     0.0  24813.02700
# 2021-07-19  531.876  130.70750  882.94500  ...     0.0     0.0  24739.62900
#
# [740 rows x 28 columns]

# %%
# 일자별 종가의 전일대비 변동률(수익률)을 portfolio라는 데이터프레임으로 저장
portfolio2 = df2[['Port']].pct_change()
portfolio2
# Out:
#                 Port
# Date
# 2018-07-19       NaN
# 2018-07-20 -0.013688
# 2018-07-23 -0.020081
# 2018-07-24  0.015855
# 2018-07-25 -0.009931
# ...              ...
# 2021-07-13 -0.027049
# 2021-07-14  0.002568
# 2021-07-15  0.022718
# 2021-07-16  0.020347
# 2021-07-19 -0.002958
#
# [740 rows x 1 columns]

# %%
# 코스피지수 불러오기
kospi = fdr.DataReader('KS11', start_date, end_date)[['Close']]
kospi
# Out:
#               Close
# Date
# 2018-07-19  2282.29
# 2018-07-20  2289.19
# 2018-07-23  2269.31
# 2018-07-24  2280.20
# 2018-07-25  2273.03
# ...             ...
# 2021-07-13  3271.38
# 2021-07-14  3264.81
# 2021-07-15  3286.22
# 2021-07-16  3276.91
# 2021-07-19  3244.04
#
# [740 rows x 1 columns]

# %%
# 코스피지수의 변동률(수익률) 구하기
# 변동률(수익률) = (당일가격-전일가격) / 전일가격
# 7/20의 변동률(수익률) = (7/20 가격-7-19 가격) / 7/19 가격
kospi_pct = kospi.pct_change()
kospi_pct
# Out:
#                Close
# Date
# 2018-07-19       NaN
# 2018-07-20  0.003023
# 2018-07-23 -0.008684
# 2018-07-24  0.004799
# 2018-07-25 -0.003144
# ...              ...
# 2021-07-13  0.007673
# 2021-07-14 -0.002008
# 2021-07-15  0.006558
# 2021-07-16 -0.002833
# 2021-07-19 -0.010031
#
# [740 rows x 1 columns]

# %%
# 코스피와 포트폴리오 합치기
result2 = kospi_pct.join(portfolio2)
result2
# Out:
#                Close      Port
# Date
# 2018-07-19       NaN       NaN
# 2018-07-20  0.003023 -0.013688
# 2018-07-23 -0.008684 -0.020081
# 2018-07-24  0.004799  0.015855
# 2018-07-25 -0.003144 -0.009931
# ...              ...       ...
# 2021-07-13  0.007673 -0.027049
# 2021-07-14 -0.002008  0.002568
# 2021-07-15  0.006558  0.022718
# 2021-07-16 -0.002833  0.020347
# 2021-07-19 -0.010031 -0.002958
#
# [740 rows x 2 columns]

# %%
# 1열을 0으로 
result2.iloc[0] = 0
result2
# Out:
#                Close      Port
# Date
# 2018-07-19  0.000000  0.000000
# 2018-07-20  0.003023 -0.013688
# 2018-07-23 -0.008684 -0.020081
# 2018-07-24  0.004799  0.015855
# 2018-07-25 -0.003144 -0.009931
# ...              ...       ...
# 2021-07-13  0.007673 -0.027049
# 2021-07-14 -0.002008  0.002568
# 2021-07-15  0.006558  0.022718
# 2021-07-16 -0.002833  0.020347
# 2021-07-19 -0.010031 -0.002958
#
# [740 rows x 2 columns]

# %%
# 열 이름 변경
result2.columns = ['KOSPI', 'PORTFOLIO']
result2
# Out:
#                KOSPI  PORTFOLIO
# Date
# 2018-07-19  0.000000   0.000000
# 2018-07-20  0.003023  -0.013688
# 2018-07-23 -0.008684  -0.020081
# 2018-07-24  0.004799   0.015855
# 2018-07-25 -0.003144  -0.009931
# ...              ...        ...
# 2021-07-13  0.007673  -0.027049
# 2021-07-14 -0.002008   0.002568
# 2021-07-15  0.006558   0.022718
# 2021-07-16 -0.002833   0.020347
# 2021-07-19 -0.010031  -0.002958
#
# [740 rows x 2 columns]

# %%
# 1에서 시작해서, 전일대비 변동률(수익률)을 적용하여 수치화하기
wealth2 = (1+result2).cumprod()
wealth2
# Out:
#                KOSPI  PORTFOLIO
# Date
# 2018-07-19  1.000000   1.000000
# 2018-07-20  1.003023   0.986312
# 2018-07-23  0.994313   0.966507
# 2018-07-24  0.999084   0.981831
# 2018-07-25  0.995943   0.972080
# ...              ...        ...
# 2021-07-13  1.433376   4.105287
# 2021-07-14  1.430497   4.115829
# 2021-07-15  1.439878   4.209332
# 2021-07-16  1.435799   4.294978
# 2021-07-19  1.421397   4.282273
#
# [740 rows x 2 columns]

# %% [markdown]
# ## 시각화

# %%
# 포트폴리오와 KOSPI 지수의 '누적 수익률 추이'를 시각화하여 비교

# matplotlib.pyplot 스타일시트 설정
plt.style.use('fivethirtyeight')

plt.figure(figsize=(18,5))
plt.plot(wealth2.index, wealth2.KOSPI , 'r', label='KOSPI')
plt.plot(wealth2.index, wealth2.PORTFOLIO ,'b', label="PORTFOLIO(Momentum 3month)")
plt.grid(True)
plt.title('Return Trend')
plt.xlabel('Date',fontsize=18, labelpad=7)
plt.ylabel('Return',fontsize=18, labelpad=7)
plt.legend(loc='best')
plt.show()

# %%
# 변동률 비교
plt.figure(figsize=(18,10))

plt.subplot(2,1,1)
plt.title('Volatility Trend')

plt.plot(result2.index, result2.KOSPI , 'r', label='KOSPI')
plt.yticks([-0.15, -0.10, -0.05, 0.00, 0.05, 0.10, 0.15])
plt.grid(True)
plt.ylabel('Volatility',fontsize=18, labelpad=7)
plt.legend(loc='best')

plt.subplot(2,1,2)
plt.title('Volatility Trend')
plt.plot(result2.index, result2.PORTFOLIO ,'b', label="PORTFOLIO(Momentum 3month)")
plt.yticks([-0.15, -0.10, -0.05, 0.00, 0.05, 0.10, 0.15])
plt.ylabel('Volatility',fontsize=18, labelpad=7)
plt.legend(loc='best')

plt.grid(True)
plt.show()

# %%
print('-----  Momentum 3month portfolio performance -----')
# Show Risk Limit
print('Risk limit: ', vol_limit2)

# Show Funds
print('Funds:', portfolio_val, 'KRW')

# Show Funds Remaining
print('Funds Remaining: ', leftover2, ' KRW')

# Show Portfolio performance
ef2.portfolio_performance(verbose=True)
rmse2 = da2._allocation_rmse_error(verbose=False)
# Out:
# -----  Momentum 3month portfolio performance -----
# Risk limit:  0.3
# Funds: 15000000 KRW
# Funds Remaining:  1700.0  KRW
# Expected annual return: 69.2%
# Annual volatility: 30.0%
# Sharpe Ratio: 2.24
# Allocation has RMSE: 0.000
