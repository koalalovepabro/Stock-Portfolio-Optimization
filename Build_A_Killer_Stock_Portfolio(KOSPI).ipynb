# %% [markdown]
# <a href="https://colab.research.google.com/github/koalalovepabro/Stock-Portfolio-Optimization/blob/main/Build_A_Killer_Stock_Portfolio(KOSPI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 최적화된 주식 포트폴리오 만들기

# %% [markdown]
# ## 💘 KOSPI 상장종목

# %%
# !pip install -q install finance-datareader

# %%
import pandas as pd
import numpy as np
import requests

# %%
# Finance Datareader 불러오고, 버전 확인하기
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.31'

# %%
# KRX : KRX 종목 전체 (KOSPI + KOSDAQ + KONEX)
# KRX100	: KRX 100
# KOSPI : KOSPI 종목
# KS100	: KOSPI 100
# KS200	: KOSPI 200
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목

# KS11 : KOSPI 지수
# KQ11 : KOSDAQ 지수
# KS50 :	KOSPI 50 지수

# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목

# %% [markdown]
# 💥 **KRX 관리종목은 사전에 삭제되어야 함 !
# ( 거래가 일시중단된 경우가 있음 )**

# %%
# KRX stock delisting symbol list and names 관리종목 리스트
krx_adm = fdr.StockListing('KRX-ADMINISTRATIVE') # 관리종목
krx_adm
# Out:
#      Symbol  ...                                       Reason
# 0    002420  ...                              매출액 미달(50억원 미만)
# 1    002630  ...                            감사범위제한으로인한 감사의견한정
# 2    003280  ...                               기타,반기검토의견 의견거절
# 3    003620  ...                      반기검토의견 의견거절,회생절차개시신청,기타
# 4    007630  ...             기타,감사범위제한으로인한 감사의견한정,반기검토의견 의견거절
# ..      ...  ...                                          ...
# 111  299910  ...  최근3사업연도중 2사업연도 자기자본 50%초과 법인세비용차감전계속사업손실 발생
# 112  311270  ...                         SPAC 상장예비심사청구서 미제출 등
# 113  900290  ...    상장폐지사유 발생,반기검토(감사)의견 부적정, 의견거절 또는 범위제한 한정
# 114  900100  ...                             상장적격성 실질심사 대상 결정
# 115  950160  ...                   상장폐지사유 발생,상장적격성 실질심사 대상 결정
#
# [116 rows x 4 columns]

# %%
print(krx_adm.loc[krx_adm['Symbol'] == '010580'])
# Out:
#    Symbol Name DesignationDate                   Reason
# 5  010580   지코      2020-06-24  회생절차개시신청,반기검토의견 의견거절,기타

# %%
# KRX 관리종목 전체 가져오기
df_kospi = fdr.StockListing('KOSPI')
df_kospi
# Out:
#       Symbol Market  ...                       HomePage Region
# 1     095570  KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2     006840  KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 6     152100  KOSPI  ...                            NaN    NaN
# 7     295820  KOSPI  ...                            NaN    NaN
# 8     253150  KOSPI  ...                            NaN    NaN
# ...      ...    ...  ...                            ...    ...
# 6457  215620  KOSPI  ...                            NaN    NaN
# 6459  000540  KOSPI  ...     http://www.insurance.co.kr  서울특별시
# 6460  000547  KOSPI  ...                            NaN    NaN
# 6461  000545  KOSPI  ...                            NaN    NaN
# 6462  003280  KOSPI  ...         http://www.heung-a.com  서울특별시
#
# [4801 rows x 10 columns]

# %%
krx_adm['Symbol'].values
# Out:
# array(['002420', '002630', '003280', '003620', '007630', '010580',
#        '011300', '012600', '013000', '015540', '096760', '234080',
#        '291660', '296710', '006580', '009730', '014100', '016670',
#        '024830', '032790', '033110', '033340', '033430', '033600',
#        '033790', '035290', '038060', '038160', '038340', '039230',
#        '039310', '039670', '043200', '043590', '044490', '045890',
#        '046070', '050320', '050540', '052190', '052770', '053110',
#        '053660', '054220', '056000', '056730', '058220', '058420',
#        '058450', '058530', '060300', '060900', '064090', '064510',
#        '064520', '065150', '065420', '065560', '065620', '066110',
#        '069110', '069330', '069540', '078590', '079190', '080440',
#        '083470', '083660', '086250', '087730', '095270', '099410',
#        '099520', '101400', '101680', '101730', '102940', '103230',
#        '106080', '106520', '111820', '114120', '114190', '114570',
#        '115180', '115530', '115610', '121890', '122690', '126870',
#        '127160', '138360', '141020', '141070', '158310', '159910',
#        '160600', '168330', '175140', '176440', '178780', '180400',
#        '182690', '208640', '208860', '215600', '222810', '223310',
#        '257370', '263540', '263920', '299910', '311270', '900290',
#        '900100', '950160'], dtype=object)

# %%
# KOSPI 목록에 포함된 KRX 관리종목 찾기
for i in krx_adm['Symbol'].values:
  for k in df_kospi['Symbol'].values:
    if i == k:
      print(i)
# Out:
# 002420
# 002630
# 003280
# 003620
# 007630
# 010580
# 011300
# 012600
# 013000
# 015540
# 096760
# 234080

# %%
danger = []
# KOSPI 목록에 포함된 KRX 관리종목을 리스트로 저장
for i in krx_adm['Symbol'].values:
  for k in df_kospi['Symbol'].values:
    if i == k:
      danger.append(i)
danger
# Out:
# ['002420',
#  '002630',
#  '003280',
#  '003620',
#  '007630',
#  '010580',
#  '011300',
#  '012600',
#  '013000',
#  '015540',
#  '096760',
#  '234080']

# %%
# KOSPI 목록에 포함된 KRX 관리종목의 정보 확인
for d in danger:
  print(krx_adm.loc[krx_adm['Symbol'] == d])
  print('-'*100)
# Out:
#    Symbol  Name DesignationDate           Reason
# 0  002420  세기상사      2021-03-18  매출액 미달(50억원 미만)
# ----------------------------------------------------------------------------------------------------
#    Symbol     Name DesignationDate             Reason
# 1  002630  오리엔트바이오      2021-06-29  감사범위제한으로인한 감사의견한정
# ----------------------------------------------------------------------------------------------------
#    Symbol  Name DesignationDate          Reason
# 2  003280  흥아해운      2020-08-18  기타,반기검토의견 의견거절
# ----------------------------------------------------------------------------------------------------
#    Symbol Name DesignationDate                   Reason
# 3  003620  쌍용차      2021-04-16  반기검토의견 의견거절,회생절차개시신청,기타
# ----------------------------------------------------------------------------------------------------
#    Symbol     Name DesignationDate                            Reason
# 4  007630  폴루스바이오팜      2020-05-18  기타,감사범위제한으로인한 감사의견한정,반기검토의견 의견거절
# ----------------------------------------------------------------------------------------------------
#    Symbol Name DesignationDate                   Reason
# 5  010580   지코      2020-06-24  회생절차개시신청,반기검토의견 의견거절,기타
# ----------------------------------------------------------------------------------------------------
#    Symbol Name DesignationDate Reason
# 6  011300   성안      2021-04-16     기타
# ----------------------------------------------------------------------------------------------------
#    Symbol     Name DesignationDate                     Reason
# 7  012600  센트럴인사이트      2021-04-23  기타,자본잠식(자본금의 50/100이상 잠식)
# ----------------------------------------------------------------------------------------------------
#    Symbol   Name DesignationDate Reason
# 8  013000  세우글로벌      2021-04-16     기타
# ----------------------------------------------------------------------------------------------------
#    Symbol     Name DesignationDate Reason
# 9  015540  쎌마테라퓨틱스      2021-04-23     기타
# ----------------------------------------------------------------------------------------------------
#     Symbol   Name DesignationDate             Reason
# 10  096760  JW홀딩스      2021-03-26  감사범위제한으로인한 감사의견한정
# ----------------------------------------------------------------------------------------------------
#     Symbol    Name DesignationDate             Reason
# 11  234080  JW생명과학      2021-03-26  감사범위제한으로인한 감사의견한정
# ----------------------------------------------------------------------------------------------------

# %%
df_kospi
# Out:
#       Symbol Market  ...                       HomePage Region
# 1     095570  KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2     006840  KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 46    027410  KOSPI  ...           http://www.bgf.co.kr  서울특별시
# 47    282330  KOSPI  ...       http://www.bgfretail.com  서울특별시
# 48    138930  KOSPI  ...           http://www.bnkfg.com  부산광역시
# ...      ...    ...  ...                            ...    ...
# 6447  079980  KOSPI  ...           http://www.huvis.com  서울특별시
# 6449  005010  KOSPI  ...         http://www.husteel.com  서울특별시
# 6454  069260  KOSPI  ...         http://www.huchems.com  서울특별시
# 6459  000540  KOSPI  ...     http://www.insurance.co.kr  서울특별시
# 6462  003280  KOSPI  ...         http://www.heung-a.com  서울특별시
#
# [772 rows x 10 columns]

# %%
idx_nm = []
# KOSPI 목록에 포함된 KRX 관리종목의 인덱스 찾기
for d in danger:
  for k in df_kospi['Symbol'].values:
    if d == k:
      idx_nm.append(df_kospi[df_kospi['Symbol'] == d].index)
idx_nm
# Out:
# [Int64Index([3498], dtype='int64'),
#  Int64Index([4059], dtype='int64'),
#  Int64Index([6462], dtype='int64'),
#  Int64Index([3714], dtype='int64'),
#  Int64Index([4809], dtype='int64'),
#  Int64Index([4489], dtype='int64'),
#  Int64Index([3490], dtype='int64'),
#  Int64Index([3530], dtype='int64'),
#  Int64Index([3510], dtype='int64'),
#  Int64Index([3722], dtype='int64'),
#  Int64Index([161], dtype='int64'),
#  Int64Index([156], dtype='int64')]

# %%
len(idx_nm)
# Out:
# 12

# %%
idx_nm[0][0]
# Out:
# 3498

# %%
idx_nm[1][0]
# Out:
# 4059

# %%
idx_nm_list = []
for i in range (0,len(idx_nm)):
  idx_nm_list.append(idx_nm[i][0])
idx_nm_list
# Out:
# [3498, 4059, 6462, 3714, 4809, 4489, 3490, 3530, 3510, 3722, 161, 156]

# %%
len(idx_nm_list)
# Out:
# 12

# %%
# KOSPI 목록에 포함된 KRX 관리종목 삭제
df_kospi_new = df_kospi.drop(idx_nm_list)

# %%
df_kospi_new
# Out:
#       Symbol Market  ...                       HomePage Region
# 1     095570  KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2     006840  KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 46    027410  KOSPI  ...           http://www.bgf.co.kr  서울특별시
# 47    282330  KOSPI  ...       http://www.bgfretail.com  서울특별시
# 48    138930  KOSPI  ...           http://www.bnkfg.com  부산광역시
# ...      ...    ...  ...                            ...    ...
# 6438  005870  KOSPI  ...          http://www.huneed.com  인천광역시
# 6447  079980  KOSPI  ...           http://www.huvis.com  서울특별시
# 6449  005010  KOSPI  ...         http://www.husteel.com  서울특별시
# 6454  069260  KOSPI  ...         http://www.huchems.com  서울특별시
# 6459  000540  KOSPI  ...     http://www.insurance.co.kr  서울특별시
#
# [760 rows x 10 columns]

# %%
# 제대로 삭제 됐는지 확인
# KOSPI 목록에 포함된 KRX 관리종목 찾기
for i in krx_adm['Symbol'].values:
  for k in df_kospi_new['Symbol'].values:
    if i == k:
      print(i)

# %%
# 데이터 파악
# 데이터의 결측치 존재 여부, 데이터의 타입, 컬럼의 수, 데이터프레임의 메모리 사용량 등
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4801 entries, 1 to 6462
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          4801 non-null   object
#  1   Market          4801 non-null   object
#  2   Name            4801 non-null   object
#  3   Sector          810 non-null    object
#  4   Industry        797 non-null    object
#  5   ListingDate     810 non-null    datetime64[ns]
#  6   SettleMonth     810 non-null    object
#  7   Representative  810 non-null    object
#  8   HomePage        781 non-null    object
#  9   Region          810 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 412.6+ KB

# %%
# 데이터의 결측치 확인
df_kospi.isnull().sum()
# Out:
# Symbol               0
# Market               0
# Name                 0
# Sector            3991
# Industry          4004
# ListingDate       3991
# SettleMonth       3991
# Representative    3991
# HomePage          4020
# Region            3991
# dtype: int64

# %%
# 결측치 제거
df_kospi = df_kospi.dropna()
df_kospi.isnull().sum()
# Out:
# Symbol            0
# Market            0
# Name              0
# Sector            0
# Industry          0
# ListingDate       0
# SettleMonth       0
# Representative    0
# HomePage          0
# Region            0
# dtype: int64

# %%
# 데이터프레임의 통계정보
df_kospi.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#         Symbol Market Name  ... Representative                    HomePage Region
# count      772    772  772  ...            772                         772    772
# unique     772      1  772  ...            754                         760     19
# top     001800  KOSPI  카카오  ...            김형철  http://www.jeilpharm.co.kr  서울특별시
# freq         1    772    1  ...              3                           2    392
# first      NaN    NaN  NaN  ...            NaN                         NaN    NaN
# last       NaN    NaN  NaN  ...            NaN                         NaN    NaN
#
# [6 rows x 10 columns]

# %%
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 772 entries, 1 to 6462
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          772 non-null    object
#  1   Market          772 non-null    object
#  2   Name            772 non-null    object
#  3   Sector          772 non-null    object
#  4   Industry        772 non-null    object
#  5   ListingDate     772 non-null    datetime64[ns]
#  6   SettleMonth     772 non-null    object
#  7   Representative  772 non-null    object
#  8   HomePage        772 non-null    object
#  9   Region          772 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 66.3+ KB

# %%
# 종목코드 가져오기
assets = df_kospi['Symbol']
assets
# Out:
# 1       095570
# 2       006840
# 46      027410
# 47      282330
# 48      138930
#          ...
# 6447    079980
# 6449    005010
# 6454    069260
# 6459    000540
# 6462    003280
# Name: Symbol, Length: 772, dtype: object

# %%
assets = np.array(assets)
assets
# Out:
# array(['095570', '006840', '027410', '282330', '138930', '001460',
#        '001040', '079160', '000120', '011150', '097950', '000590',
#        '012030', '016610', '005830', '000990', '139130', '001530',
#        '000210', '001880', '004840', '155660', '069730', '017940',
#        '365550', '383220', '007700', '114090', '006360', '001250',
#        '007070', '012630', '039570', '089470', '294870', '011200',
#        '082740', '003560', '175330', '234080', '001060', '096760',
#        '105560', '002380', '344820', '009070', '009440', '119650',
#        '092220', '016380', '001390', '033180', '001940', '025000',
#        '092230', '000040', '030200', '033780', '030210', '058850',
#        '058860', '093050', '003550', '034220', '051900', '032640',
#        '011070', '066570', '037560', '051910', '079550', '006260',
#        '010120', '000680', '001120', '108670', '383800', '023150',
#        '035420', '181710', '005940', '338100', '034310', '008260',
#        '004250', '010060', '005490', '010950', '034120', '101060',
#        '005090', '001380', '004060', '002360', '009160', '025530',
#        '034730', '011790', '018670', '001740', '006120', '210980',
#        '068400', '302440', '361610', '096770', '001510', '285130',
#        '017670', '000660', '064960', '100840', '003570', '036530',
#        '005610', '011810', '077970', '071970', '002820', '002710',
#        '002900', '024070', '037270', '000500', '000860', '035250',
#        '011420', '002100', '009450', '267290', '012320', '000050',
#        '214390', '012610', '009140', '013580', '012200', '002140',
#        '010130', '002240', '009290', '017040', '017900', '037710',
#        '030610', '339770', '007690', '005320', '001140', '002720',
#        '083420', '014530', '014280', '008870', '001570', '002990',
#        '011780', '214330', '001210', '073240', '092440', '000270',
#        '024110', '013700', '004540', '001260', '008350', '004270',
#        '003920', '025860', '005720', '002350', '003580', '251270',
#        '000320', '006280', '005250', '004370', '072710', '058730',
#        '023590', '019680', '006370', '008060', '353200', '000490',
#        '008110', '005750', '006570', '001680', '128820', '117580',
#        '016710', '003540', '009190', '014160', '047040', '009320',
#        '042660', '003090', '069620', '000430', '006340', '003220',
#        '024890', '002880', '000300', '012800', '015230', '001070',
#        '006650', '001440', '084010', '001790', '001130', '003490',
#        '005880', '003830', '016090', '069460', '012510', '004830',
#        '024900', '145720', '002150', '001230', '023450', '004140',
#        '007590', '005960', '026960', '002210', '000640', '170900',
#        '028100', '282690', '001520', '084670', '082640', '008970',
#        '049770', '018500', '006040', '030720', '014820', '163560',
#        '004890', '002690', '000020', '000150', '241560', '042670',
#        '034020', '336260', '016740', '192650', '024090', '003160',
#        '092200', '013570', '210540', '007340', '026890', '032350',
#        '330590', '000400', '023530', '004000', '286940', '280360',
#        '004990', '005300', '011170', '002270', '071840', '027740',
#        '204320', '001080', '088980', '138040', '008560', '000060',
#        '090370', '017180', '009900', '012690', '005360', '204210',
#        '009680', '009580', '009200', '033920', '008420', '025560',
#        '007120', '357250', '085620', '006800', '002840', '268280',
#        '134380', '003650', '003610', '001340', '035150', '002410',
#        '007210', '002760', '003850', '000890', '003000', '001270',
#        '026940', '015350', '011390', '005030', '002070', '100220',
#        '030790', '005180', '003960', '008040', '007160', '014710',
#        '006090', '001470', '006400', '006660', '028260', '207940',
#        '032830', '018260', '028050', '009150', '005930', '001360',
#        '010140', '016360', '068290', '029780', '000810', '006110',
#        '145990', '003230', '002170', '272550', '000070', '002810',
#        '005680', '003720', '023000', '004380', '002450', '004440',
#        '000520', '009770', '005500', '004690', '010960', '004450',
#        '009470', '011230', '001820', '000390', '001290', '041650',
#        '075180', '007540', '248170', '007860', '200880', '017390',
#        '004410', '021050', '008490', '007610', '014910', '003080',
#        '004980', '011300', '000180', '002420', '004360', '004490',
#        '001430', '306200', '003030', '019440', '058650', '013000',
#        '091090', '021820', '067830', '033530', '075580', '027970',
#        '145210', '308170', '012600', '068270', '336370', '248070',
#        '004430', '017550', '053210', '134790', '016590', '029530',
#        '004970', '011930', '005390', '004170', '035510', '034300',
#        '031430', '031440', '006880', '005800', '001720', '009270',
#        '002700', '019170', '002870', '293940', '055550', '001770',
#        '004080', '003410', '003620', '004770', '015540', '004920',
#        '112610', '008700', '002790', '090430', '002030', '183190',
#        '002310', '012170', '267850', '020560', '122900', '010780',
#        '001780', '018250', '011090', '137310', '005850', '012750',
#        '023960', '298690', '078520', '015260', '007460', '003060',
#        '036570', '138250', '085310', '009810', '900140', '097520',
#        '014440', '003520', '000670', '006740', '012280', '015360',
#        '007310', '002630', '271560', '001800', '070960', '316140',
#        '033660', '010050', '006980', '017370', '105840', '010400',
#        '049800', '016880', '095720', '005820', '010600', '008600',
#        '033270', '014830', '000910', '047400', '011330', '077500',
#        '002920', '000700', '003470', '011690', '072130', '000220',
#        '001200', '000100', '003460', '008730', '008250', '025820',
#        '214320', '139480', '007660', '005950', '015020', '093230',
#        '074610', '102460', '084680', '350520', '334890', '000760',
#        '014990', '101140', '006490', '023800', '034590', '129260',
#        '023810', '249420', '000230', '013360', '003120', '003200',
#        '007110', '007570', '008500', '081000', '020760', '020150',
#        '015860', '226320', '317400', '033240', '000950', '348950',
#        '194370', '025620', '036420', '030000', '271980', '001560',
#        '002620', '006220', '089590', '004910', '004700', '001550',
#        '000480', '120030', '018470', '002600', '185750', '063160',
#        '001630', '044380', '013890', '013870', '071320', '010580',
#        '035000', '088790', '003780', '010640', '100250', '051630',
#        '272450', '011000', '002780', '009310', '000650', '033250',
#        '035720', '006380', '109070', '001620', '029460', '281820',
#        '145270', '357120', '007810', '003690', '192820', '044820',
#        '005070', '005420', '071950', '002020', '003070', '144620',
#        '138490', '021240', '031820', '192400', '284740', '015590',
#        '264900', '005740', '020120', '039490', '014580', '015890',
#        '006890', '003240', '011280', '004100', '009410', '001420',
#        '007980', '055490', '078000', '214420', '019180', '363280',
#        '091810', '004870', '005690', '036580', '004720', '028670',
#        '010820', '016800', '001020', '090080', '010770', '058430',
#        '047050', '003670', '007630', '017810', '005810', '950210',
#        '086790', '293480', '039130', '352820', '071090', '019490',
#        '000080', '000140', '036460', '005430', '071050', '010040',
#        '025540', '004090', '002200', '002960', '000240', '123890',
#        '015760', '006200', '009540', '023350', '025890', '000970',
#        '104700', '017960', '024720', '161390', '034830', '007280',
#        '010100', '047810', '123690', '003350', '011500', '002390',
#        '014790', '060980', '053690', '042700', '008930', '009240',
#        '020000', '003680', '105630', '069640', '016450', '010420',
#        '009180', '213500', '014680', '004710', '004150', '025750',
#        '004960', '011700', '001750', '018880', '009420', '014130',
#        '300720', '002220', '006390', '003300', '051600', '052690',
#        '130660', '002320', '097230', '003480', '180640', '005110',
#        '009460', '000880', '088350', '000370', '009830', '272210',
#        '012450', '003530', '195870', '101530', '143210', '000720',
#        '267270', '005440', '086280', '064350', '079430', '012330',
#        '010620', '069960', '004560', '004310', '322000', '017800',
#        '307950', '011210', '267260', '004020', '267250', '005380',
#        '001500', '011760', '227840', '126560', '001450', '057050',
#        '093240', '003010', '111110', '008770', '002460', '378850',
#        '006060', '013520', '010690', '133820', '010660', '000850',
#        '016580', '032560', '004800', '094280', '298040', '298050',
#        '298020', '298000', '093370', '081660', '005870', '079980',
#        '005010', '069260', '000540', '003280'], dtype=object)

# %%
len(assets)
# Out:
# 772

# %%
# 종목별 종가 가져오기
from datetime import datetime

# 주식 시작일은 2013년 1월 1일이고 종료일은 현재 날짜 (오늘)로 설정
#Get the stock starting date
start_date = '2013-01-01'
# today = datetime.today().strftime('%Y-%m-%d')
end_date = '2021-07-15'

# 각 주식의 일별 종가 데이터를 저장할 데이터 프레임을 생성
#Create a dataframe to store the adjusted close price of the stocks
df = pd.DataFrame()

# FinanceDataReader로 각 종목의 종가데이터 불러오기
for stock in assets:
  df[stock] = fdr.DataReader(stock, start_date, end_date)['Close']
df
# Out:
#             095570  006840  027410    282330  ...  005010  069260  000540  003280
# Date                                          ...
# 2015-08-21    7100   90400   47810       NaN  ...   16150   20900    3805   15163
# 2015-08-24    6480   88800   45620       NaN  ...   15650   20200    3650   15090
# 2015-08-25    6220   92200   47166       NaN  ...   16050   20350    3985   15726
# 2015-08-26    7090   91700   50001       NaN  ...   16450   21550    3905   15865
# 2015-08-27    7570   91000   49743       NaN  ...   17000   21350    3925   15514
# ...            ...     ...     ...       ...  ...     ...     ...     ...     ...
# 2021-07-09    5850   27650    6160  163000.0  ...   13800   22400    4340    1035
# 2021-07-12    5910   28550    6260  167000.0  ...   14050   24250    4395    1035
# 2021-07-13    5920   29050    6300  169000.0  ...   14250   24550    4420    1035
# 2021-07-14    6330   28500    6250  167500.0  ...   14000   24600    4425    1035
# 2021-07-15    6200   29100    6330  168500.0  ...   13950   23900    4415    1035
#
# [1451 rows x 772 columns]

# %%
# DataFrame을 csv 파일로 저장하기 ( 결측값 제거하지 않음 )
df.to_csv("kospi_code_close.csv", index=True)

# %%
# 칼럼명을 회사이름으로 변경
df.columns = df_kospi['Name'].values
df
# Out:
#             AJ네트웍스  AK홀딩스    BGF    BGF리테일  ...    휴스틸    휴켐스  흥국화재   흥아해운
# Date                                        ...
# 2015-08-21    7100  90400  47810       NaN  ...  16150  20900  3805  15163
# 2015-08-24    6480  88800  45620       NaN  ...  15650  20200  3650  15090
# 2015-08-25    6220  92200  47166       NaN  ...  16050  20350  3985  15726
# 2015-08-26    7090  91700  50001       NaN  ...  16450  21550  3905  15865
# 2015-08-27    7570  91000  49743       NaN  ...  17000  21350  3925  15514
# ...            ...    ...    ...       ...  ...    ...    ...   ...    ...
# 2021-07-09    5850  27650   6160  163000.0  ...  13800  22400  4340   1035
# 2021-07-12    5910  28550   6260  167000.0  ...  14050  24250  4395   1035
# 2021-07-13    5920  29050   6300  169000.0  ...  14250  24550  4420   1035
# 2021-07-14    6330  28500   6250  167500.0  ...  14000  24600  4425   1035
# 2021-07-15    6200  29100   6330  168500.0  ...  13950  23900  4415   1035
#
# [1451 rows x 772 columns]

# %%
# 결측값 있는 열 삭제  ( 종목 1451  -> 683으로 줄어 듦 )
df2 = df.dropna(axis = 1)
df2
# Out:
#             AJ네트웍스  AK홀딩스    BGF  BNK금융지주  ...    휴스틸    휴켐스  흥국화재   흥아해운
# Date                                       ...
# 2015-08-21    7100  90400  47810    14032  ...  16150  20900  3805  15163
# 2015-08-24    6480  88800  45620    13167  ...  15650  20200  3650  15090
# 2015-08-25    6220  92200  47166    13071  ...  16050  20350  3985  15726
# 2015-08-26    7090  91700  50001    13311  ...  16450  21550  3905  15865
# 2015-08-27    7570  91000  49743    13215  ...  17000  21350  3925  15514
# ...            ...    ...    ...      ...  ...    ...    ...   ...    ...
# 2021-07-09    5850  27650   6160     7350  ...  13800  22400  4340   1035
# 2021-07-12    5910  28550   6260     7520  ...  14050  24250  4395   1035
# 2021-07-13    5920  29050   6300     7590  ...  14250  24550  4420   1035
# 2021-07-14    6330  28500   6250     7520  ...  14000  24600  4425   1035
# 2021-07-15    6200  29100   6330     7560  ...  13950  23900  4415   1035
#
# [1451 rows x 683 columns]

# %%
df2.isnull().sum()
# Out:
# AJ네트웍스     0
# AK홀딩스      0
# BGF        0
# BNK금융지주    0
# BYC        0
#           ..
# 휴비스        0
# 휴스틸        0
# 휴켐스        0
# 흥국화재       0
# 흥아해운       0
# Length: 683, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1451 entries, 2015-08-21 to 2021-07-15
# Columns: 683 entries, AJ네트웍스 to 흥아해운
# dtypes: int64(683)
# memory usage: 7.6 MB

# %%
# 결측값을 가진 열을 제거한 DataFrame을 csv 파일로 저장하기
df2.to_csv("kospi_name_close_drop_columns.csv", index=True)

# %%
# Get the assets / tickers
assets = df2.columns
assets
# Out:
# Index(['AJ네트웍스', 'AK홀딩스', 'BGF', 'BNK금융지주', 'BYC', 'CJ', 'CJ CGV', 'CJ대한통운',
#        'CJ씨푸드', 'CJ제일제당',
#        ...
#        '효성', '효성ITX', '후성', '휠라홀딩스', '휴니드', '휴비스', '휴스틸', '휴켐스', '흥국화재',
#        '흥아해운'],
#       dtype='object', length=683)

# %%
len(assets)
# Out:
# 683

# %%
df2.isnull().sum()
# Out:
# AJ네트웍스     0
# AK홀딩스      0
# BGF        0
# BNK금융지주    0
# BYC        0
#           ..
# 휴비스        0
# 휴스틸        0
# 휴켐스        0
# 흥국화재       0
# 흥아해운       0
# Length: 683, dtype: int64

# %% [markdown]
# - Index : 날짜 (1,451  days)
# - column : 종목명 (683개 종목)
# - row : 날짜별 종목의 종가(Close Price)

# %%
# !pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Downloading https://files.pythonhosted.org/packages/12/dd/bbe51f36f323c4eee59ec94638b24de1daeda9537403c363cbfab8cd1d29/PyPortfolioOpt-1.4.2-py3-none-any.whl (60kB)
#      |████████████████████████████████| 61kB 3.8MB/s
# Collecting cvxpy<2.0.0,>=1.1.10
#   Downloading https://files.pythonhosted.org/packages/f0/95/e7eb169a7802fe0c5c50dd7f29c2e9d357b5f29c70adc3f5ca2ab684a04b/cvxpy-1.1.13.tar.gz (1.3MB)
#      |████████████████████████████████| 1.3MB 13.3MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.1.5)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post0)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.1.4)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.7.post1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Building wheels for collected packages: cvxpy
#   Building wheel for cvxpy (PEP 517) ... done
#   Created wheel for cvxpy: filename=cvxpy-1.1.13-cp37-cp37m-linux_x86_64.whl size=2736126 sha256=93826d796b74650097623471898b797d0e3b514d32ef1cf1f79c9a0cfb7d5293
#   Stored in directory: /root/.cache/pip/wheels/f9/78/00/f29636789ee83434953b5442f16ec3f9834a68e7fd0393c220
# Successfully built cvxpy
# Installing collected packages: cvxpy, PyPortfolioOpt
#   Found existing installation: cvxpy 1.0.31
#     Uninstalling cvxpy-1.0.31:
#       Successfully uninstalled cvxpy-1.0.31
# Successfully installed PyPortfolioOpt-1.4.2 cvxpy-1.1.13

# %%
# Optimize the portfolio
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
# Calculate the expected annualized returns and the annualized sample covariance matrix of the daily asset returns
mu = expected_returns.mean_historical_return(df2)
S = risk_models.sample_cov(df2)

# %%
mu
# Out:
# AJ네트웍스    -0.023282
# AK홀딩스     -0.178806
# BGF       -0.296297
# BNK금융지주   -0.101911
# BYC        0.030191
#              ...
# 휴비스        0.056159
# 휴스틸       -0.025129
# 휴켐스        0.023585
# 흥국화재       0.026178
# 흥아해운      -0.372832
# Length: 683, dtype: float64

# %%
S
# Out:
#            AJ네트웍스     AK홀딩스       BGF  ...       휴켐스      흥국화재      흥아해운
# AJ네트웍스   0.155143  0.044273  0.042450  ...  0.023941  0.031113  0.020337
# AK홀딩스    0.044273  0.179474  0.049956  ...  0.041755  0.050577  0.051392
# BGF      0.042450  0.049956  0.192153  ...  0.032319  0.035209  0.026673
# BNK금융지주  0.019653  0.034863  0.027324  ...  0.028361  0.028252  0.024506
# BYC      0.019138  0.018019  0.020161  ...  0.013618  0.022912  0.015801
# ...           ...       ...       ...  ...       ...       ...       ...
# 휴비스      0.030114  0.044285  0.030895  ...  0.031991  0.035142  0.030237
# 휴스틸      0.031413  0.035875  0.030397  ...  0.028378  0.034309  0.027763
# 휴켐스      0.023941  0.041755  0.032319  ...  0.126412  0.027209  0.017603
# 흥국화재     0.031113  0.050577  0.035209  ...  0.027209  0.151368  0.022283
# 흥아해운     0.020337  0.051392  0.026673  ...  0.017603  0.022283  0.374397
#
# [683 rows x 683 columns]

# %%
S.shape
# Out:
# (683, 683)

# %%
# Optimize for the maximal Sharpe ratio
# 💛데이터셋이 너무 많으면, ef.max_sharpe()에서 에러남 -> solver를 SCS로 바꿔줌
# Rober says: 100개 이하로 종목을 추린 후에 실행시키기를 추천함 !
ef = EfficientFrontier(mu, S, solver="SCS")  # Create the Efficient Frontier Object

# Maximize the Sharpe ratio, and get the raw weights
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
print(cleaned_weights)

ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('AJ네트웍스', 0.0), ('AK홀딩스', 0.0), ('BGF', 0.0), ('BNK금융지주', 0.0), ('BYC', 0.0), ('CJ', 0.0), ('CJ CGV', 0.0), ('CJ대한통운', 0.0), ('CJ씨푸드', 0.0), ('CJ제일제당', 0.0), ('CS홀딩스', 0.0), ('DB', 0.0), ('DB금융투자', 0.0), ('DB손해보험', 0.0), ('DB하이텍', 0.0), ('DGB금융지주', 0.0), ('DI동일', 0.0), ('DL', 0.0), ('DL건설', 0.0), ('DRB동일', 0.0), ('DSR', 0.0), ('DSR제강', 0.0), ('E1', 0.0), ('F&F홀딩스', 0.0), ('GKL', 0.0), ('GS건설', 0.0), ('GS글로벌', 0.0), ('GS리테일', 0.0), ('HDC', 0.0), ('HDC현대EP', 0.0), ('HMM', 0.0), ('HSD엔진', 0.0), ('IHQ', 0.0), ('JB금융지주', 0.0), ('JW중외제약', 0.0), ('JW홀딩스', 0.0), ('KB금융', 0.0), ('KCC', 0.0), ('KCTC', 0.0), ('KC그린홀딩스', 0.0), ('KC코트렐', 0.0), ('KEC', 0.0), ('KG동부제철', 0.0), ('KG케미칼', 0.0), ('KH 필룩스', 0.0), ('KISCO홀딩스', 0.0), ('KPX케미칼', 0.0), ('KPX홀딩스', 0.0), ('KR모터스', 0.0), ('KT', 0.0), ('KT&G', 0.0), ('KTB투자증권', 0.0), ('KTcs', 0.0), ('KTis', 0.0), ('LF', 0.0), ('LG', 0.0), ('LG디스플레이', 0.0), ('LG생활건강', 0.0), ('LG유플러스', 0.0), ('LG이노텍', 0.0), ('LG전자', 0.0), ('LG헬로비전', 0.0), ('LG화학', 0.0), ('LS', 0.0), ('LS ELECTRIC', 0.0), ('LS네트웍스', 0.0), ('LX인터내셔널', 0.0), ('LX하우시스', 0.0), ('MH에탄올', 0.0), ('NAVER', 0.03541), ('NHN', 0.0), ('NH투자증권', 0.0), ('NICE', 0.0), ('NI스틸', 0.0), ('NPC', 0.0), ('OCI', 0.0), ('POSCO', 0.0), ('S-Oil', 0.0), ('SBS', 0.0), ('SBS미디어홀딩스', 0.0), ('SGC에너지', 0.0), ('SG글로벌', 0.0), ('SG세계물산', 0.0), ('SH에너지화학', 0.0), ('SIMPAC', 0.0), ('SJM홀딩스', 0.0), ('SK', 0.0), ('SKC', 0.0), ('SK가스', 0.0), ('SK네트웍스', 0.0), ('SK디스커버리', 0.0), ('SK디앤디', 0.0), ('SK렌터카', 0.0), ('SK이노베이션', 0.0), ('SK증권', 0.0), ('SK텔레콤', 0.0), ('SK하이닉스', 0.0), ('SNT모티브', 0.0), ('SNT에너지', 0.0), ('SNT중공업', 0.0), ('SNT홀딩스', 0.0), ('SPC삼립', 0.0), ('STX', 0.0), ('STX엔진', 0.0), ('STX중공업', 0.0), ('SUN&L', 0.0), ('TCC스틸', 0.0), ('TYM', 0.0), ('WISCOM', 0.0), ('YG PLUS', 0.0), ('가온전선', 0.0), ('강남제비스코', 0.0), ('강원랜드', 0.0), ('갤럭시아에스엠', 0.0), ('경농', 0.0), ('경동나비엔', 0.0), ('경동인베스트', 0.0), ('경방', 0.0), ('경보제약', 0.0), ('경인양행', 0.0), ('경인전자', 0.0), ('계룡건설', 0.0), ('계양전기', 0.0), ('고려산업', 0.0), ('고려아연', 0.0), ('고려제강', 0.0), ('광동제약', 0.0), ('광명전기', 0.0), ('광전자', 0.0), ('광주신세계', 0.0), ('교보증권', 0.0), ('국도화학', 0.0), ('국동', 0.0), ('국보', 0.0), ('국제약품', 0.0), ('그린케미칼', 0.0097), ('극동유화', 0.0), ('금강공업', 0.0), ('금비', 0.0), ('금양', 0.0), ('금호건설', 0.0), ('금호석유', 0.0), ('금호전기', 0.0), ('금호타이어', 0.0), ('기신정기', 0.0), ('기아', 0.0), ('기업은행', 0.0), ('까뮤이앤씨', 0.0), ('깨끗한나라', 0.0), ('남광토건', 0.0), ('남선알미늄', 0.0), ('남성', 0.0), ('남양유업', 0.0), ('남해화학', 0.0), ('넥센', 0.0), ('넥센타이어', 0.0), ('넥스트사이언스', 0.01438), ('노루홀딩스', 0.0), ('녹십자', 0.0), ('녹십자홀딩스', 0.0), ('농심', 0.0), ('농심홀딩스', 0.0), ('다스코', 0.0), ('다우기술', 0.0), ('대교', 0.0), ('대구백화점', 0.0), ('대덕', 0.0), ('대동', 0.0), ('대동전자', 0.0), ('대림B&Co', 0.0), ('대림통상', 0.0), ('대상', 0.0), ('대성산업', 0.0), ('대성에너지', 0.0), ('대성홀딩스', 0.15563), ('대신증권', 0.0), ('대양금속', 0.0), ('대영포장', 0.0), ('대우건설', 0.0), ('대우부품', 0.0), ('대우조선해양', 0.0), ('대웅', 0.0), ('대웅제약', 0.0), ('대원강업', 0.0), ('대원전선', 0.0), ('대원제약', 0.0), ('대원화성', 0.0), ('대유에이텍', 0.0), ('대유플러스', 0.0), ('대창', 0.0), ('대창단조', 0.0), ('대한방직', 0.01914), ('대한유화', 0.0), ('대한전선', 0.0), ('대한제강', 0.0), ('대한제당', 0.0), ('대한제분', 0.0), ('대한항공', 0.0), ('대한해운', 0.0), ('대한화섬', 0.0), ('대현', 0.0), ('대호에이엘', 0.0), ('더존비즈온', 0.0), ('덕성', 0.0), ('덕양산업', 0.0), ('도화엔지니어링', 0.0), ('동국제강', 0.0), ('동남합성', 0.10591), ('동방', 0.00346), ('동방아그로', 0.0), ('동부건설', 0.0), ('동서', 0.0), ('동성제약', 0.0), ('동아쏘시오홀딩스', 0.0), ('동아에스티', 0.0), ('동아지질', 0.0), ('동양', 0.0), ('동양고속', 0.0), ('동양생명', 0.0), ('동양철관', 0.0), ('동원F&B', 0.0), ('동원금속', 0.0), ('동원산업', 0.0), ('동원수산', 0.0), ('동원시스템즈', 0.0), ('동일고무벨트', 0.0), ('동일산업', 0.0), ('동화약품', 0.0), ('두산', 0.0), ('두산인프라코어', 0.0), ('두산중공업', 0.0), ('디씨엠', 0.0), ('디아이', 0.0), ('디아이씨', 0.0), ('디와이', 0.0), ('디와이파워', 0.0), ('디티알오토모티브', 0.0), ('디피씨', 0.0), ('롯데관광개발', 0.0), ('롯데손해보험', 0.0), ('롯데쇼핑', 0.0), ('롯데정밀화학', 0.0), ('롯데지주', 0.0), ('롯데칠성', 0.0), ('롯데케미칼', 0.0), ('롯데푸드', 0.0), ('롯데하이마트', 0.0), ('마니커', 0.0), ('만도', 0.0), ('만호제강', 0.0), ('맥쿼리인프라', 0.1103), ('메리츠금융지주', 0.0), ('메리츠증권', 0.0), ('메리츠화재', 0.0), ('메타랩스', 0.0), ('명문제약', 0. ...
# Expected annual return: 35.3%
# Annual volatility: 13.8%
# Sharpe Ratio: 2.42
# (0.3533312241107406, 0.1378080803801316, 2.41880754155544)

# %%
weights
# Out:
# OrderedDict([('AJ네트웍스', 5.7706005e-09),
#              ('AK홀딩스', 9.066947321e-07),
#              ('BGF', 1.2159978845e-06),
#              ('BNK금융지주', 1.5289107793e-06),
#              ('BYC', 1.0449567279e-06),
#              ('CJ', 8.19760535e-07),
#              ('CJ CGV', 5.41351614e-08),
#              ('CJ대한통운', -1.9595536174e-06),
#              ('CJ씨푸드', 1.7164831988e-06),
#              ('CJ제일제당', -8.093907569e-07),
#              ('CS홀딩스', 4.02520657e-07),
#              ('DB', 6.812967535e-07),
#              ('DB금융투자', 1.1273534999e-06),
#              ('DB손해보험', 7.140640847e-07),
#              ('DB하이텍', 1.9964013494e-06),
#              ('DGB금융지주', -5.284110448e-07),
#              ('DI동일', 1.6613899174e-06),
#              ('DL', 7.910403514e-07),
#              ('DL건설', 1.2996573423e-06),
#              ('DRB동일', 2.209254977e-07),
#              ('DSR', 1.4418319315e-06),
#              ('DSR제강', 1.3487533858e-06),
#              ('E1', 6.630898136e-07),
#              ('F&F홀딩스', 1.3753685086e-06),
#              ('GKL', 1.3235483401e-06),
#              ('GS건설', 1.155776622e-07),
#              ('GS글로벌', 9.655261169e-07),
#              ('GS리테일', 3.840441e-07),
#              ('HDC', -3.248003466e-07),
#              ('HDC현대EP', -4.01155338e-08),
#              ('HMM', 8.132915081e-07),
#              ('HSD엔진', 6.446493908e-07),
#              ('IHQ', -1.3561820142e-06),
#              ('JB금융지주', 3.3217457195e-06),
#              ('JW중외제약', -1.892756523e-07),
#              ('JW홀딩스', -1.5338212586e-06),
#              ('KB금융', 3.0163810597e-06),
#              ('KCC', 3.662907998e-07),
#              ('KCTC', 1.043256019e-07),
#              ('KC그린홀딩스', 2.126388262e-07),
#              ('KC코트렐', -6.989360237e-07),
#              ('KEC', 9.920672757e-07),
#              ('KG동부제철', 5.34113557e-08),
#              ('KG케미칼', -1.11234176e-08),
#              ('KH 필룩스', 3.225146909e-07),
#              ('KISCO홀딩스', -3.757565477e-07),
#              ('KPX케미칼', 1.7904319959e-06),
#              ('KPX홀딩스', -1.275467579e-06),
#              ('KR모터스', -1.367194834e-07),
#              ('KT', 1.4220129764e-06),
#              ('KT&G', -7.391929486e-07),
#              ('KTB투자증권', 1.1255779999e-06),
#              ('KTcs', -1.3349716648e-06),
#              ('KTis', 1.5596328307e-06),
#              ('LF', -1.4630587536e-06),
#              ('LG', 1.1617603321e-06),
#              ('LG디스플레이', -1.1185908288e-06),
#              ('LG생활건강', 1.0698869501e-06),
#              ('LG유플러스', -1.734904956e-06),
#              ('LG이노텍', 8.706543209e-07),
#              ('LG전자', 2.0742400209e-06),
#              ('LG헬로비전', 1.3775521924e-06),
#              ('LG화학', -6.408149294e-07),
#              ('LS', 1.7536971037e-06),
#              ('LS ELECTRIC', 1.4028741722e-06),
#              ('LS네트웍스', 6.008828909e-07),
#              ('LX인터내셔널', 2.069171083e-06),
#              ('LX하우시스', -1.9032241124e-06),
#              ('MH에탄올', -9.681125393e-07),
#              ('NAVER', 0.0354119383669126),
#              ('NHN', -2.4633723033e-06),
#              ('NH투자증권', 1.8529881032e-06),
#              ('NICE', -5.04702923e-08),
#              ('NI스틸', 2.0427322222e-06),
#              ('NPC', -2.0113326794e-06),
#              ('OCI', 1.2583805192e-06),
#              ('POSCO', 2.5273214701e-06),
#              ('S-Oil', -1.8319848673e-06),
#              ('SBS', 1.0576521155e-06),
#              ('SBS미디어홀딩스', 2.188143319e-07),
#              ('SGC에너지', -1.2110527174e-06),
#              ('SG글로벌', 1.795168084e-07),
#              ('SG세계물산', 8.492128349e-07),
#              ('SH에너지화학', 1.283537111e-06),
#              ('SIMPAC', 9.255342419e-07),
#              ('SJM홀딩스', 1.8161434076e-06),
#              ('SK', 1.6756121205e-06),
#              ('SKC', -9.759037564e-07),
#              ('SK가스', 5.31755976e-07),
#              ('SK네트웍스', 1.3817186867e-06),
#              ('SK디스커버리', -5.403404898e-07),
#              ('SK디앤디', 2.87735708e-08),
#              ('SK렌터카', 4.033422837e-07),
#              ('SK이노베이션', 2.8040124156e-06),
#              ('SK증권', -6.15166251e-08),
#              ('SK텔레콤', 4.8953982e-08),
#              ('SK하이닉스', 1.055047667e-07),
#              ('SNT모티브', 1.7901573887e-06),
#              ('SNT에너지', -9.98015181e-08),
#              ('SNT중공업', -9.687783459e-07),
#              ('SNT홀딩스', 1.0597957657e-06),
#              ('SPC삼립', 1.3582392671e-06),
#              ('STX', -1.46154113e-07),
#              ('STX엔진', 1.073044239e-07),
#              ('STX중공업', -4.115013296e-07),
#              ('SUN&L', 2.688356689e-07),
#              ('TCC스틸', 1.832447284e-07),
#              ('TYM', 1.2763744296e-06),
#              ('WISCOM', -2.3394995844e-06),
#              ('YG PLUS', 2.589195957e-07),
#              ('가온전선', -6.809205412e-07),
#              ('강남제비스코', 2.1362776119e-06),
#              ('강원랜드', 8.321353884e-07),
#              ('갤럭시아에스엠', -1.5373791185e-06),
#              ('경농', 9.131420086e-07),
#              ('경동나비엔', 4.1488555e-07),
#              ('경동인베스트', -8.987183429e-07),
#              ('경방', -4.079223172e-07),
#              ('경보제약', 2.299305426e-07),
#              ('경인양행', 1.0719627578e-06),
#              ('경인전자', 1.336867574e-06),
#              ('계룡건설', 1.4475096867e-06),
#              ('계양전기', -7.17922097e-08),
#              ('고려산업', 2.906851274e-07),
#              ('고려아연', 9.207056522e-07),
#              ('고려제강', 2.922714613e-07),
#              ('광동제약', 1.605393417e-07),
#              ('광명전기', 1.0929105551e-06),
#              ('광전자', -5.971009e-10),
#              ('광주신세계', -2.0624934268e-06),
#              ('교보증권', 8.942005131e-07),
#              ('국도화학', -3.1674728253e-06),
#              ('국동', 1.792573152e-07),
#              ('국보', 7.000468024e-07),
#              ('국제약품', 3.98725383e-08),
#              ('그린케미칼', 0.0096993127648665),
#              ('극동유화', 2.881340195e-07),
#              ('금강공업', 5.97059704e-08),
#              ('금비', -6.101729459e-07),
#              ('금양', 2.079637802e-07),
#              ('금호건설', 1.5842189512e-06),
#              ('금호석유', 2.746259353e-07),
#              ('금호전기', 2.277079617e-07),
#              ('금호타이어', -1.4204206337e-06),
#              ('기신정기', -1.8621871458e-06),
#              ('기아', 7.0492557758e-06),
#              ('기업은행', -8.708170757e-07),
#              ('까뮤이앤씨', 2.0437448299e-06),
#              ('깨끗한나라', 1.2382330903e-06),
#              ('남광토건', 1.825172364e-07),
#              ('남선알미늄', 1.1096432959e-06),
#              ('남성', 9.685566138e-07),
#              ('남양유업', -7.26382866e-07),
#              ('남해화학', 2.0168949801e-06),
#              ('넥센', -2.248977629e-06),
#              ('넥센타이어', 1.0782514129e-06),
#              ('넥스트사이언스', 0.0143773489877207),
#              ('노루홀딩스', -8.781945377e-07),
#              ('녹십자', 8.74413779e-08),
#              ('녹십자홀딩스', 1.2967943312e-06),
#              ('농심', -2.3812707044e-06),
#              ('농심홀딩스', -7.0481694858e-06),
#              ('다스코', 1.234009539e-06),
#              ('다우기술', 6.540504902e-07),
#              ('대교', 9.158403448e-07),
#              ('대구백화점', -3.69731864e-07),
#              ('대덕', 3.911763224e-07),
#              ('대동', -3.38911854e-07),
#              ('대동전자', -1.5958593756e-06),
#              ('대림B&Co', 9.874548162e-07),
#              ('대림통상', 4.526891237e-07),
#              ('대상', 8.869237681e-07),
#              ('대성산업', 3.128450894e-07),
#              ('대성에너지', -8.63428904e-08),
#              ('대성홀딩스', 0.1556297937977629),
#              ('대신증권', -1.7342540579e-06),
#              ('대양금속', 7.479395559e-07),
#              ('대영포장', 2.1727615475e-06),
#              ('대우건설', 2.0403952817e-06),
#              ('대우부품', 4.380852954e-07),
#              ('대우조선해양', -1.2370104148e-06),
#              ('대웅', 1.0202230328e-06),
#              ('대웅제약', -2.043434386e-07),
#              ('대원강업', -2.477159047e-07),
#              ('대원전선', -3.518464287e-07),
#              ('대원제약', 6.328940483e-07),
#              ('대원화성', 9.66930591e-07),
#              ('대유에이텍', 1.5772729159e-06),
#              ('대유플러스', -1.31217182e-08),
#              ('대창', 1.08949112e-08),
#              ('대창단조', -2.8145797923e-06),
#              ('대한방직', 0.0191423481912734),
#              ('대한유화', 9.080952619e-07),
#              ('대한전선', 1.3841650921e-06),
#              ('대한제강', 1.6331673519e-06),
#              ('대한제당', -5.482375284e-07),
#              ('대한제분', 9.051639472e-07),
#              ('대한항공', 2.2300327966e-06),
#              ('대한해운', 2.582245562e-07),
#              ('대한화섬', 1.0227273228e-06),
#              ('대현', -1.080736017e-07),
#              ('대호에이엘', 1.2830576759e-06),
#              ('더존비즈온', 1.0565451497e-06),
#              ('덕성', -7.015053507e-07),
#              ('덕양산업', 1.2904391243e-06),
#              ('도화엔지니어링', 7.294567393e-07),
#              ('동국제강', 3.322893056e-07),
#              ('동남합성', 0.1059054836247052),
#              ('동방', 0.0034550782033849),
#              ('동방아그로', 1.9430268227e-06),
#              ('동부건설', 6.74399743e-08),
#              ('동서', -2.1262045467e-06),
#              ('동성제약', -4.756145665e-07),
#              ('동아쏘시오홀딩스', -2.0587140039e-06),
#              ('동아에스티', -5.755932742e-07),
#              ('동아지질', 4.94028501e-07),
#              ('동양', 5.882794907e-07),
#              ('동양고속', -2.7601104015e-06),
#              ('동양생명', 1.310111154e-07),
#              ('동양철관', -3.390544207e-07),
#              ('동원F&B', -1.4711534067e-06),
#              ('동원금속', -6.744967715e-07),
#              ('동원산업', 6.452311887e-07),
#              ('동원수산', 1.0941818217e-06),
#              ('동원시스템즈', 8.835315743e-07),
#              ('동일고무벨트', 1.2043203534e-06),
#              ('동일산업', -4.97670929e-08),
#              ('동화약품', 5.959257747e-07),
#              ('두산', 6.480885468e-07),
#              ('두산인프라코어', 8.422106789e-07),
#              ('두산중공업', 4.686924455e-07),
#              ('디씨엠', 9.359713201e-07),
#              ('디아이', -1.39567511e-08),
#              ('디아이씨', 2.27951535e-08),
#              ('디와이', 1.7253326405e-06),
#              ('디와이파워', 7.317643908e-07),
#              ('디티알오토모티브', -6.271221785e-07),
#              ('디피씨', 1.2772024194e-06),
#              ('롯데관광개발', 1.87425913e-07),
#              ('롯데손해보험', -6.491951925e-07),
#              ('롯데쇼핑', 7.647327574e-07),
#              ('롯데정밀화학', 1.5732509881e-06),
#              ('롯데지주', 1.6201797143e-06),
#              ('롯데칠성', -2.1057336016e-06),
#              ('롯데케미칼', 1.2715762111e-06),
#              ('롯데푸드', -2.64967691e-08),
#              ('롯데하이마트', 6.180155709e-07),
#              ('마니커', 1.3201614628e-06),
#              ('만도', 2.431682703e-06),
#              ('만호제강', -1.2648674099e-06),
#              ('맥쿼리인프라', 0.1102964834809236),
#              ('메리츠금융지주', -1.7537645095e-06),
#              ('메리츠증권', 1.6610135597e-06),
#              ('메리츠화재', 1.0372131395e-06),
#              ('메타랩스', 2.346165248e-07),
#              ('명문제약', -1.317698148e-06),
#              ('모나리자', -8.25818115e-07),
#              ('모나미', 1.2614705385e-06),
#              ('모토닉', 2.9268932774e-06),
#              ('무림P&P', -1.7188954801e-06),
#              ('무림페이퍼', 9.543722662e-07),
#              ('무학', 2.5874238017e-06),
#              ('문배철강', 2.2708644954e-06),
#              ('미래산업', -2.2402614774e-06),
#              ('미래아이앤지', 8.352387516e-07),
#              ('미래에셋생명', 1.6885595611e-06),
#              ('미래에셋증권', -3.0305763859e-06),
#              ('미원상사', 0.2268000785522261),
#              ('미원화학', -8.1587633858e-06),
#              ('미창석유', -3.963338513e-07),
#              ('방림', 1.7135383416e-06),
#              ('백광산업', 1.048470769e-07),
#              ('백산', 1.7713919798e-06),
#              ('범양건영', 1.4364842038e-06),
#              ('벽산', 1.2706383998e-06),
#              ('보락', 4.845157293e-07),
#              ('보령제약', 3.79864754e-07),
#              ('보해양조', -6.282497948e-07),
#              ('부광약품', -3.439438357e-07),
#              ('부국증권', 2.0317572697e-06),
#              ('부국철강', 1.9160208047e-06),
#              ('부산가스', -2.271644764e-06),
#              ('부산산업', 6.430210614e-07),
#              ('부산주공', 2.633220684e-07),
#              ('비비안', 2.546789392e-06),
#              ('비상교육', -1.0188665343e-06),
#              ('비케이탑스', -1.182696533e-07),
#              ('빙그레', -2.822078472e-07),
#              ('사조대림', 1.6898925785e-06),
#              ('사조동아원', 1.051210621e-07),
#              ('사조산업', -1.3154102976e-06),
#              ('사조씨푸드', -1.3621965449e-06),
#              ('사조오양', -2.916138204e-07),
#              ('삼부토건', 6.758323041e-07),
#              ('삼성SDI', 0.0377475190752925),
#              ('삼성공조', 0.0136734998962767),
#              ('삼성물산', 1.1970340954e-06),
#              ('삼성생명', -3.2885714503e-06),
#              ('삼성에스디에스', -2.913068668e-07),
#              ('삼성엔지니어링', 8.93370441e-07),
#              ('삼성전기', 7.241674736e-07),
#              ('삼성전자', 0.0187324038490327),
#              ('삼성제약', 1.8106768984e-06),
#              ('삼성중공업', 1.3193121535e-06),
#              ('삼성증권', 3.2988103377e-06),
#              ('삼성출판사', 9.302461206e-07),
#              ('삼성카드', 3.9981980372e-06),
#              ('삼성화재', -1.0190756843e-06),
#              ('삼아알미늄', 6.043477947e-07),
#              ('삼양사', 1.7204761397e-06),
#              ('삼양식품', 2.90630306e-07),
#              ('삼양통상', -1.2269816788e-06),
#              ('삼양홀딩스', 5.565400981e-07),
#              ('삼영무역', -1.7221069443e-06),
#              ('삼영전자', -1.9893677888e-06),
#              ('삼영화학', 9.69954797e-07),
#              ('삼원강재', 8.031668736e-07),
#              ('삼익THK', -1.2983293387e-06),
#              ('삼익악기', 1.1241116068e-06),
#              ('삼일제약', 1.014811523e-06),
#              ('삼정펄프', 3.92994171e-07),
#              ('삼진제약', -2.2317124422e-06),
#              ('삼천리', -4.163628823e-07),
#              ('삼호개발', 1.72024597e-08),
#              ('삼화왕관', -3.787826294e-07),
#              ('삼화전기', -4.762020183e-07),
#              ('삼화전자', -8.5206718e-09),
#              ('삼화콘덴서', 0.0166658787484518),
#              ('삼화페인트', 1.6236087341e-06),
#              ('상상인증권', -6.819827057e-07),
#              ('상신브레이크', -2.295202807e-07),
#              ('새론오토모티브', -9.478070941e-07),
#              ('샘표', 1.4115748083e-06),
#              ('서연', 8.803366393e-07),
#              ('서연이화', 1.8690047415e-06),
#              ('서울가스', -9.1384526719e-06),
#              ('서울식품', 2.623680477e-07),
#              ('서원', 3.927123357e-07),
#              ('서흥', -3.024848258e-06),
#              ('선도전기', -9.762949095e-07),
#              ('성문전자', 1.3541262583e-06),
#              ('성보화학', -4.277821581e-07),
#              ('성신양회', -2.667609644e-07),
#              ('성안', 1.1190159735e-06),
#              ('성창기업지주', 7.453376673e-07),
#              ('세기상사', 1.5459596959e-06),
#              ('세방', 7.629078166e-07),
#              ('세방전지', 2.317074643e-07),
#              ('세아베스틸', 1.6510059095e-06),
#              ('세아제강지주', 1.6433282606e-06),
#              ('세아특수강', -8.46976638e-07),
#              ('세아홀딩스', -3.128214267e-07),
#              ('세우글로벌', -2.43301965e-07),
#              ('세원이앤씨', 1.5887074005e-06),
#              ('세원정공', -1.86307317998e-05),
#              ('세이브존I&C', -3.6092173641e-06),
#              ('세종공업', 3.203569726e-07),
#              ('세하', 5.908249472e-07),
#              ('세화아이엠씨', -7.9227511368e-06),
#              ('센트럴인사이트', -2.618923648e-07),
#              ('셀트리온', -1.0994450933e-06),
#              ('송원산업', -7.616764212e-07),
#              ('수산중공업', 3.452325555e-07),
#              ('스카이라이프', -3.8382567298e-06),
#              ('시디즈', 0.0227822896568368),
#              ('신대양제지', 2.7472070643e-06),
#              ('신도리코', -3.24181122e-08),
#              ('신라교역', -6.545454719e-07),
#              ('신성이엔지', 8.95596365e-07),
#              ('신성통상', 1.5455260312e-06),
#              ('신세계', 2.340651121e-07),
#              ('신세계 I&C', -2.0528420539e-06),
#              ('신세계건설', -1.2414372736e-06),
#              ('신세계인터내셔날', 5.441354762e-07),
#              ('신세계푸드', 7.051569522e-07),
#              ('신송홀딩스', -9.596029235e-07),
#              ('신영와코루', -5.48877543e-06),
#              ('신영증권', 1.2190894897e-06),
#              ('신원', 1.1610188941e-06),
#              ('신일전자', 1.90343167e-06),
#              ('신풍제약', 0.0292261284877873),
#              ('신풍제지', 1.2129699434e-06),
#              ('신한지주', 4.216072379e-07),
#              ('신화실업', -1.620269289e-07),
#              ('신흥', -3.9246863864e-06),
#              ('쌍용C&E', 1.3557944192e-06),
#              ('쌍용차', 9.399872816e-07),
#              ('써니전자', 1.614052676e-06),
#              ('쎌마테라퓨틱스', -1.4819314682e-06),
#              ('씨아이테크', 2.320344257e-07),
#              ('씨에스윈드', 1.099237381e-07),
#              ('아남전자', 1.057706724e-07),
#              ('아모레G', -3.408817363e-07),
#              ('아모레퍼시픽', 7.09621746e-08),
#              ('아세아', 3.281190141e-06),
#              ('아세아시멘트', -2.405441687e-07),
#              ('아세아제지', -1.9052062062e-06),
#              ('아센디오', -2.2777540417e-06),
#              ('아시아나항공', -1.755360553e-07),
#              ('아이마켓코리아', -9.250084041e-07),
#              ('아이에스동서', 6.941842289e-07),
#              ('알루코', 3.689732347e-07),
#              ('에넥스', 1.0139178975e-06),
#              ('에스엘', 3.8713992282e-06),
#              ('에스원', -4.4066932534e-06),
#              ('에쓰씨엔지니어링', 1.748670024e-07),
#              ('에이블씨엔씨', 2.440105891e-07),
#              ('에이엔피', 5.682193078e-07),
#              ('에이프로젠 MED', 7.0603387e-09),
#              ('에이프로젠제약', -1.2669102e-06),
#              ('엔씨소프트', 0.0046942312832452),
#              ('엔에스쇼핑', 1.1435448725e-06),
#              ('엔케이', -4.438065658e-07),
#              ('엔케이물산', 6.259573389e-07),
#              ('엘브이엠씨홀딩스', 1.966543002e-07),
#              ('엠씨넥스', 1.4281916288e-06),
#              ('영보화학', 2.454187341e-06),
#              ('영진약품', 7.953445545e-07),
#              ('영풍', -7.297478364e-07),
#              ('영풍제지', 5.588377635e-07),
#              ('영화금속', 2.524504096e-07),
#              ('예스코홀딩스', 1.0813319777e-06),
#              ('오뚜기', 1.08960229e-07),
#              ('오리엔트바이오', -7.692645414e-07),
#              ('오리온홀딩스', -1.3825599839e-06),
#              ('우리금융캐피탈', 2.2030258656e-06),
#              ('우리종금', 3.539893743e-07),
#              ('우성사료', 9.424039843e-07),
#              ('우신시스템', 1.761860346e-06),
#              ('우진', 1.0000996534e-06),
#              ('우진플라임', 1.4565523297e-06),
#              ('웅진', 2.1254728573e-06),
#              ('웅진씽크빅', -2.1220033275e-06),
#              ('원림', 3.020387533e-07),
#              ('웰바이오텍', 2.745287011e-07),
#              ('윌비스', 2.140377325e-07),
#              ('유나이티드제약', -3.46863997e-08),
#              ('유니드', -1.0344247522e-06),
#              ('유니온', 4.532249345e-07),
#              ('유니온머티리얼', 1.3055995085e-06),
#              ('유니켐', 3.891346042e-07),
#              ('유니퀘스트', 2.360348233e-07),
#              ('유성기업', -2.3508591117e-06),
#              ('유수홀딩스', -1.5920573635e-06),
#              ('유안타증권', -2.7684854028e-06),
#              ('유양디앤유', 7.571730802e-07),
#              ('유엔젤', 6.202281735e-07),
#              ('유유제약', 1.270960856e-07),
#              ('유진투자증권', 2.3704245352e-06),
#              ('유한양행', -1.8324707411e-06),
#              ('유화증권', -7.4790795575e-06),
#              ('율촌화학', 8.995690511e-07),
#              ('이건산업', 5.881549994e-07),
#              ('이구산업', 8.93707341e-08),
#              ('이노션', -2.896057687e-07),
#              ('이마트', 8.575480373e-07),
#              ('이수페타시스', -6.667937865e-07),
#              ('이수화학', 6.46122764e-07),
#              ('이스타코', 9.709418569e-07),
#              ('이아이디', 4.434867053e-07),
#              ('이엔플러스', 9.421083063e-07),
#              ('이연제약', 4.222282143e-07),
#              ('이월드', 9.992647533e-07),
#              ('이화산업', 1.7418873042e-06),
#              ('인디에프', 3.778250214e-07),
#              ('인바이오젠', -2.355882287e-07),
#              ('인스코비', 4.680170346e-07),
#              ('인지컨트롤스', 4.156045623e-07),
#              ('인천도시가스', -8.0952265946e-06),
#              ('인터지스', 2.0137796963e-06),
#              ('인팩', 1.6502490004e-06),
#              ('일동홀딩스', -1.6281706326e-06),
#              ('일성건설', 2.109811006e-07),
#              ('일성신약', -1.05608125922e-05),
#              ('일신방직', -3.6626766532e-06),
#              ('일신석재', 5.907633956e-07),
#              ('일양약품', -5.075414306e-07),
#              ('일정실업', -1.222319752e-06),
#              ('일진다이아', 6.451197655e-07),
#              ('일진디스플', -2.478723089e-07),
#              ('일진머티리얼즈', 0.0057435025867141),
#              ('일진홀딩스', 1.1725455332e-06),
#              ('자화전자', 1.36179292e-07),
#              ('전방', 1.0146171564e-06),
#              ('제이준코스메틱', -1.3667217279e-06),
#              ('제이콘텐트리', -2.023621035e-07),
#              ('제일기획', -3.508602728e-07),
#              ('제일연마', 6.367398794e-07),
#              ('제일파마홀딩스', 3.96431309e-07),
#              ('제주은행', 7.26832874e-08),
#              ('조광페인트', -1.2740278415e-06),
#              ('조광피혁', -1.35733525e-08),
#              ('조비', 9.443808592e-07),
#              ('조선내화', -4.6165175483e-06),
#              ('조선선재', 8.44945389e-07),
#              ('조일알미늄', -3.628902155e-07),
#              ('조흥', -2.3091694612e-06),
#              ('종근당', 3.729748189e-07),
#              ('종근당바이오', 4.25392953e-08),
#              ('종근당홀딩스', 1.8621890778e-06),
#              ('주연테크', -1.07396899e-08),
#              ('지엠비코리아', 1.9656249811e-06),
#              ('지역난방공사', -1.3693537042e-06),
#              ('지코', -4.174336751e-07),
#              ('지투알', 5.183591845e-07),
#              ('진도', 1.9605448138e-06),
#              ('진양산업', 2.2701641569e-06),
#              ('진양폴리', -3.483837556e-07),
#              ('진양홀딩스', -2.3653661737e-06),
#              ('진양화학', 8.501355999e-07),
#              ('진원생명과학', 0.0011265138078907),
#              ('진흥기업', 2.7063747376e-06),
#              ('참엔지니어링', -2.242999535e-07),
#              ('천일고속', -1.2140120363e-06),
#              ('체시스', -2.541155593e-07),
#              ('카카오', 0.0488189406394464),
#              ('카프로', 2.942273926e-07),
#              ('컨버즈', -8.145039792e-07),
#              ('케이비아이동국실업', 8.091845315e-07),
#              ('케이씨', 3.733382542e-07),
#              ('케이탑리츠', 1.158077645e-07),
#              ('코리아써키트', 8.388456224e-07),
#              ('코리안리', -4.7386275274e-06),
#              ('코스맥스', -1.1139644723e-06),
#              ('코스맥스비티아이', 7.768914964e-07),
#              ('코스모신소재', 0.0207855170908353),
#              ('코스모화학', 2.53147497e-07),
#              ('코아스', 1.3376855881e-06),
#              ('코오롱', 2.3200992332e-06),
#              ('코오롱글로벌', 1.7750700431e-06),
#              ('코오롱머티리얼', -3.74288911e-08),
#              ('코오롱플라스틱', -9.013548487e-07),
#              ('코웨이', 1.0715795938e-06),
#              ('콤텍시스템', 1.3684307683e-06),
#              ('쿠쿠홀딩스', -4.753091941e-07),
#              ('큐로', 6.776670903e-07),
#              ('크라운해태홀딩스', 6.893629958e-07),
#              ('키다리스튜디오', 8.365179477e-07),
#              ('키움증권', 1.4696106034e-06),
#              ('태경비케이', 2.0126424093e-06),
#              ('태경산업', 2.33745922e-07),
#              ('태경케미컬', 6.376308204e-07),
#              ('태광산업', 5.452778206e-07),
#              ('태림포장', 5.739687115e-07),
#              ('태양금속', -9.56965367e-08),
#              ('태영건설', 2.31624063e-08),
#              ('태원물산', 1.510247195e-06),
#              ('태평양물산', 8.747819286e-07),
#              ('텔코웨어', 1.8587051869e-06),
#              ('토니모리', 1.8420765547e-06),
#              ('티에이치엔', 3.062362798e-07),
#              ('티웨이홀딩스', 6.643931795e-07),
#              ('파미셀', 1.7243231126e-06),
#              ('팜스코', -5.191618108e-07),
#              ('팜젠사이언스', -7.54858412e-08),
#              ('팬오션', 1.3970763358e-06),
#              ('퍼스텍', -1.1037718756e-06),
#              ('퍼시스', -1.27132364964e-05),
#              ('페이퍼코리아', -1.6077693957e-06),
#              ('평화산업', 2.894141011e-07),
#              ('평화홀딩스', 1.0769931844e-06),
#              ('포스코강판', 0.0313901133764819),
#              ('포스코인터내셔널', 7.999201756e-07),
#              ('포스코케미칼', 0.0519387021191786),
#              ('폴루스바이오팜', -7.33084448e-08),
#              ('풀무원', -1.99636846e-08),
#              ('풍산홀딩스', 8.5138692e-08),
#              ('하나금융지주', -2.722835693e-07),
#              ('하나투어', -1.5108414207e-06),
#              ('하이스틸', 1.0037125436e-06),
#              ('하이트론', -3.828139673e-07),
#              ('하이트진로', 2.1254951194e-06),
#              ('하이트진로홀딩스', -2.1195130478e-06),
#              ('한국가스공사', -6.308215865e-07),
#              ('한국공항', 6.126107672e-07),
#              ('한국금융지주', -6.6280298e-09),
#              ('한국내화', 8.141695923e-07),
#              ('한국단자', 1.387975734e-07),
#              ('한국석유', 6.21385377e-07),
#              ('한국수출포장', 4.846329917e-07),
#              ('한국쉘석유', 1.5652982464e-06),
#              ('한국앤컴퍼니', -1.3277863389e-06),
#              ('한국전력', -1.0648942615e-06),
#              ('한국전자홀딩스', 1.638039538e-07),
#              ('한국조선해양', 2.41930183e-06),
#              ('한국종합기술', 1.0596743403e-06),
#              ('한국주강', 1.2459590942e-06),
#              ('한국주철관', -2.677213621e-07),
#              ('한국철강', -8.521545919e-07),
#              ('한국카본', 1.9403480593e-06),
#              ('한국콜마홀딩스', 5.36581431e-08),
#              ('한국타이어앤테크놀로지', -1.06490039e-08),
#              ('한국토지신탁', 2.643299895e-07),
#              ('한국특강', 5.919470353e-07),
#              ('한국프랜지', -1.0474057995e-06),
#              ('한국항공우주', 3.820468759e-07),
#              ('한국화장품', 3.237895865e-07),
#              ('한국화장품제조', 9.431686235e-07),
#              ('한농화성', 1.3240199519e-06),
#              ('한독', 1.0564958855e-06),
#              ('한라', -1.708610277e-07),
#              ('한라홀딩스', 2.590575369e-07),
#              ('한미글로벌', -2.50022293e-07),
#              ('한미반도체', 0.0042612230539975),
#              ('한미사이언스', -9.182626644e-07),
#              ('한샘', -1.5504782052e-06),
#              ('한섬', 1.5614298106e-06),
#              ('한성기업', -1.51455794e-08),
#              ('한세실업', -3.301102909e-07),
#              ('한세엠케이', 6.634079704e-07),
#              ('한세예스24홀딩스', -9.242060463e-07),
#              ('한솔PNS', 1.2268143263e-06),
#              ('한솔로지스틱스', -8.049971669e-07),
#              ('한솔제지', 2.2040698335e-06),
#              ('한솔케미칼', 3.3022573e-08),
#              ('한솔테크닉스', 4.191074154e-07),
#              ('한솔홀딩스', -9.940225646e-07),
#              ('한솔홈데코', 2.2036354084e-06),
#              ('한신공영', 1.6272701195e-06),
#              ('한신기계', -1.713635406e-07),
#              ('한양증권', 9.517873858e-07),
#              ('한온시스템', 1.9924908776e-06),
#              ('한올바이오파마', -5.328385754e-07),
#              ('한익스프레스', -1.337360687e-07),
#              ('한일철강', 4.283451946e-07),
#              ('한일현대시멘트', 1.3614974539e-06),
#              ('한일홀딩스', -4.98990432e-07),
#              ('한전KPS', -2.0016968682e-06),
#              ('한전기술', 1.2921499981e-06),
#              ('한전산업', 0.0116186000959456),
#              ('한진', -2.97504533e-07),
#              ('한진중공업', 1.6453580647e-06),
#              ('한진중공업홀딩스', -2.3423270691e-06),
#              ('한진칼', 2.678954915e-07),
#              ('한창', 7.450146207e-07),
#              ('한창제지', 1.792861394e-07),
#              ('한화', 1.2417525214e-06),
#              ('한화생명', -3.84894779e-08),
#              ('한화손해보험', 7.829855823e-07),
#              ('한화솔루션', 5.25682661e-07),
#              ('한화에어로스페이스', 2.3797158668e-06),
#              ('한화투자증권', 8.901066697e-07),
#              ('현대건설', 2.071975083e-07),
#              ('현대그린푸드', -3.958226687e-07),
#              ('현대글로비스', -3.849410004e-07),
#              ('현대로템', -4.973931695e-07),
#              ('현대리바트', -6.613920043e-07),
#              ('현대모비스', -1.132456732e-07),
#              ('현대미포조선', 2.390580122e-06),
#              ('현대백화점', -2.9560869441e-06),
#              ('현대비앤지스틸', 3.4731930567e-06),
#              ('현대약품', 2.6966859065e-06),
#              ('현대엘리베이', 9.239391864e-07),
#              ('현대위아', -9.405936948e-07),
#              ('현대제철', 1.82508275e-08),
#              ('현대차', 1.998476371e-07),
#              ('현대차증권', -1.372006649e-07),
#              ('현대코퍼레이션', -7.01488368e-08),
#              ('현대퓨처넷', -4.822060471e-07),
#              ('현대해상', 3.74302209e-08),
#              ('현대홈쇼핑', -1.5929609512e-06),
#              ('형지엘리트', 5.798113814e-07),
#              ('혜인', 4.960408328e-07),
#              ('호텔신라', 1.0078995211e-06),
#              ('화성산업', -1.3142267795e-06),
#              ('화승인더', 1.0256446214e-06),
#              ('화승코퍼레이션', 4.378924556e-07),
#              ('화신', 8.559000013e-07),
#              ('화인베스틸', -2.289619855e-07),
#              ('화천기계', 6.204268423e-07),
#              ('화천기공', -3.4942925764e-06),
#              ('환인제약', 2.495927223e-07),
#              ('황금에스티', 4.143167119e-07),
#              ('효성', 4.079188102e-07),
#              ('효성ITX', 1.694405535e-07),
#              ('후성', -5.16406873e-08),
#              ('휠라홀딩스', 3.555590184e-07),
#              ('휴니드', 2.0797054889e-06),
#              ('휴비스', 2.0350507438e-06),
#              ('휴스틸', -6.312574899e-07),
#              ('휴켐스', 9.95820234e-08),
#              ('흥국화재', 5.100049537e-07),
#              ('흥아해운', -1.3611006883e-06)])

# %%
cleaned_weights
# Out:
# OrderedDict([('AJ네트웍스', 0.0),
#              ('AK홀딩스', 0.0),
#              ('BGF', 0.0),
#              ('BNK금융지주', 0.0),
#              ('BYC', 0.0),
#              ('CJ', 0.0),
#              ('CJ CGV', 0.0),
#              ('CJ대한통운', 0.0),
#              ('CJ씨푸드', 0.0),
#              ('CJ제일제당', 0.0),
#              ('CS홀딩스', 0.0),
#              ('DB', 0.0),
#              ('DB금융투자', 0.0),
#              ('DB손해보험', 0.0),
#              ('DB하이텍', 0.0),
#              ('DGB금융지주', 0.0),
#              ('DI동일', 0.0),
#              ('DL', 0.0),
#              ('DL건설', 0.0),
#              ('DRB동일', 0.0),
#              ('DSR', 0.0),
#              ('DSR제강', 0.0),
#              ('E1', 0.0),
#              ('F&F홀딩스', 0.0),
#              ('GKL', 0.0),
#              ('GS건설', 0.0),
#              ('GS글로벌', 0.0),
#              ('GS리테일', 0.0),
#              ('HDC', 0.0),
#              ('HDC현대EP', 0.0),
#              ('HMM', 0.0),
#              ('HSD엔진', 0.0),
#              ('IHQ', 0.0),
#              ('JB금융지주', 0.0),
#              ('JW중외제약', 0.0),
#              ('JW홀딩스', 0.0),
#              ('KB금융', 0.0),
#              ('KCC', 0.0),
#              ('KCTC', 0.0),
#              ('KC그린홀딩스', 0.0),
#              ('KC코트렐', 0.0),
#              ('KEC', 0.0),
#              ('KG동부제철', 0.0),
#              ('KG케미칼', 0.0),
#              ('KH 필룩스', 0.0),
#              ('KISCO홀딩스', 0.0),
#              ('KPX케미칼', 0.0),
#              ('KPX홀딩스', 0.0),
#              ('KR모터스', 0.0),
#              ('KT', 0.0),
#              ('KT&G', 0.0),
#              ('KTB투자증권', 0.0),
#              ('KTcs', 0.0),
#              ('KTis', 0.0),
#              ('LF', 0.0),
#              ('LG', 0.0),
#              ('LG디스플레이', 0.0),
#              ('LG생활건강', 0.0),
#              ('LG유플러스', 0.0),
#              ('LG이노텍', 0.0),
#              ('LG전자', 0.0),
#              ('LG헬로비전', 0.0),
#              ('LG화학', 0.0),
#              ('LS', 0.0),
#              ('LS ELECTRIC', 0.0),
#              ('LS네트웍스', 0.0),
#              ('LX인터내셔널', 0.0),
#              ('LX하우시스', 0.0),
#              ('MH에탄올', 0.0),
#              ('NAVER', 0.03541),
#              ('NHN', 0.0),
#              ('NH투자증권', 0.0),
#              ('NICE', 0.0),
#              ('NI스틸', 0.0),
#              ('NPC', 0.0),
#              ('OCI', 0.0),
#              ('POSCO', 0.0),
#              ('S-Oil', 0.0),
#              ('SBS', 0.0),
#              ('SBS미디어홀딩스', 0.0),
#              ('SGC에너지', 0.0),
#              ('SG글로벌', 0.0),
#              ('SG세계물산', 0.0),
#              ('SH에너지화학', 0.0),
#              ('SIMPAC', 0.0),
#              ('SJM홀딩스', 0.0),
#              ('SK', 0.0),
#              ('SKC', 0.0),
#              ('SK가스', 0.0),
#              ('SK네트웍스', 0.0),
#              ('SK디스커버리', 0.0),
#              ('SK디앤디', 0.0),
#              ('SK렌터카', 0.0),
#              ('SK이노베이션', 0.0),
#              ('SK증권', 0.0),
#              ('SK텔레콤', 0.0),
#              ('SK하이닉스', 0.0),
#              ('SNT모티브', 0.0),
#              ('SNT에너지', 0.0),
#              ('SNT중공업', 0.0),
#              ('SNT홀딩스', 0.0),
#              ('SPC삼립', 0.0),
#              ('STX', 0.0),
#              ('STX엔진', 0.0),
#              ('STX중공업', 0.0),
#              ('SUN&L', 0.0),
#              ('TCC스틸', 0.0),
#              ('TYM', 0.0),
#              ('WISCOM', 0.0),
#              ('YG PLUS', 0.0),
#              ('가온전선', 0.0),
#              ('강남제비스코', 0.0),
#              ('강원랜드', 0.0),
#              ('갤럭시아에스엠', 0.0),
#              ('경농', 0.0),
#              ('경동나비엔', 0.0),
#              ('경동인베스트', 0.0),
#              ('경방', 0.0),
#              ('경보제약', 0.0),
#              ('경인양행', 0.0),
#              ('경인전자', 0.0),
#              ('계룡건설', 0.0),
#              ('계양전기', 0.0),
#              ('고려산업', 0.0),
#              ('고려아연', 0.0),
#              ('고려제강', 0.0),
#              ('광동제약', 0.0),
#              ('광명전기', 0.0),
#              ('광전자', 0.0),
#              ('광주신세계', 0.0),
#              ('교보증권', 0.0),
#              ('국도화학', 0.0),
#              ('국동', 0.0),
#              ('국보', 0.0),
#              ('국제약품', 0.0),
#              ('그린케미칼', 0.0097),
#              ('극동유화', 0.0),
#              ('금강공업', 0.0),
#              ('금비', 0.0),
#              ('금양', 0.0),
#              ('금호건설', 0.0),
#              ('금호석유', 0.0),
#              ('금호전기', 0.0),
#              ('금호타이어', 0.0),
#              ('기신정기', 0.0),
#              ('기아', 0.0),
#              ('기업은행', 0.0),
#              ('까뮤이앤씨', 0.0),
#              ('깨끗한나라', 0.0),
#              ('남광토건', 0.0),
#              ('남선알미늄', 0.0),
#              ('남성', 0.0),
#              ('남양유업', 0.0),
#              ('남해화학', 0.0),
#              ('넥센', 0.0),
#              ('넥센타이어', 0.0),
#              ('넥스트사이언스', 0.01438),
#              ('노루홀딩스', 0.0),
#              ('녹십자', 0.0),
#              ('녹십자홀딩스', 0.0),
#              ('농심', 0.0),
#              ('농심홀딩스', 0.0),
#              ('다스코', 0.0),
#              ('다우기술', 0.0),
#              ('대교', 0.0),
#              ('대구백화점', 0.0),
#              ('대덕', 0.0),
#              ('대동', 0.0),
#              ('대동전자', 0.0),
#              ('대림B&Co', 0.0),
#              ('대림통상', 0.0),
#              ('대상', 0.0),
#              ('대성산업', 0.0),
#              ('대성에너지', 0.0),
#              ('대성홀딩스', 0.15563),
#              ('대신증권', 0.0),
#              ('대양금속', 0.0),
#              ('대영포장', 0.0),
#              ('대우건설', 0.0),
#              ('대우부품', 0.0),
#              ('대우조선해양', 0.0),
#              ('대웅', 0.0),
#              ('대웅제약', 0.0),
#              ('대원강업', 0.0),
#              ('대원전선', 0.0),
#              ('대원제약', 0.0),
#              ('대원화성', 0.0),
#              ('대유에이텍', 0.0),
#              ('대유플러스', 0.0),
#              ('대창', 0.0),
#              ('대창단조', 0.0),
#              ('대한방직', 0.01914),
#              ('대한유화', 0.0),
#              ('대한전선', 0.0),
#              ('대한제강', 0.0),
#              ('대한제당', 0.0),
#              ('대한제분', 0.0),
#              ('대한항공', 0.0),
#              ('대한해운', 0.0),
#              ('대한화섬', 0.0),
#              ('대현', 0.0),
#              ('대호에이엘', 0.0),
#              ('더존비즈온', 0.0),
#              ('덕성', 0.0),
#              ('덕양산업', 0.0),
#              ('도화엔지니어링', 0.0),
#              ('동국제강', 0.0),
#              ('동남합성', 0.10591),
#              ('동방', 0.00346),
#              ('동방아그로', 0.0),
#              ('동부건설', 0.0),
#              ('동서', 0.0),
#              ('동성제약', 0.0),
#              ('동아쏘시오홀딩스', 0.0),
#              ('동아에스티', 0.0),
#              ('동아지질', 0.0),
#              ('동양', 0.0),
#              ('동양고속', 0.0),
#              ('동양생명', 0.0),
#              ('동양철관', 0.0),
#              ('동원F&B', 0.0),
#              ('동원금속', 0.0),
#              ('동원산업', 0.0),
#              ('동원수산', 0.0),
#              ('동원시스템즈', 0.0),
#              ('동일고무벨트', 0.0),
#              ('동일산업', 0.0),
#              ('동화약품', 0.0),
#              ('두산', 0.0),
#              ('두산인프라코어', 0.0),
#              ('두산중공업', 0.0),
#              ('디씨엠', 0.0),
#              ('디아이', 0.0),
#              ('디아이씨', 0.0),
#              ('디와이', 0.0),
#              ('디와이파워', 0.0),
#              ('디티알오토모티브', 0.0),
#              ('디피씨', 0.0),
#              ('롯데관광개발', 0.0),
#              ('롯데손해보험', 0.0),
#              ('롯데쇼핑', 0.0),
#              ('롯데정밀화학', 0.0),
#              ('롯데지주', 0.0),
#              ('롯데칠성', 0.0),
#              ('롯데케미칼', 0.0),
#              ('롯데푸드', 0.0),
#              ('롯데하이마트', 0.0),
#              ('마니커', 0.0),
#              ('만도', 0.0),
#              ('만호제강', 0.0),
#              ('맥쿼리인프라', 0.1103),
#              ('메리츠금융지주', 0.0),
#              ('메리츠증권', 0.0),
#              ('메리츠화재', 0.0),
#              ('메타랩스', 0.0),
#              ('명문제약', 0.0),
#              ('모나리자', 0.0),
#              ('모나미', 0.0),
#              ('모토닉', 0.0),
#              ('무림P&P', 0.0),
#              ('무림페이퍼', 0.0),
#              ('무학', 0.0),
#              ('문배철강', 0.0),
#              ('미래산업', 0.0),
#              ('미래아이앤지', 0.0),
#              ('미래에셋생명', 0.0),
#              ('미래에셋증권', 0.0),
#              ('미원상사', 0.2268),
#              ('미원화학', 0.0),
#              ('미창석유', 0.0),
#              ('방림', 0.0),
#              ('백광산업', 0.0),
#              ('백산', 0.0),
#              ('범양건영', 0.0),
#              ('벽산', 0.0),
#              ('보락', 0.0),
#              ('보령제약', 0.0),
#              ('보해양조', 0.0),
#              ('부광약품', 0.0),
#              ('부국증권', 0.0),
#              ('부국철강', 0.0),
#              ('부산가스', 0.0),
#              ('부산산업', 0.0),
#              ('부산주공', 0.0),
#              ('비비안', 0.0),
#              ('비상교육', 0.0),
#              ('비케이탑스', 0.0),
#              ('빙그레', 0.0),
#              ('사조대림', 0.0),
#              ('사조동아원', 0.0),
#              ('사조산업', 0.0),
#              ('사조씨푸드', 0.0),
#              ('사조오양', 0.0),
#              ('삼부토건', 0.0),
#              ('삼성SDI', 0.03775),
#              ('삼성공조', 0.01367),
#              ('삼성물산', 0.0),
#              ('삼성생명', 0.0),
#              ('삼성에스디에스', 0.0),
#              ('삼성엔지니어링', 0.0),
#              ('삼성전기', 0.0),
#              ('삼성전자', 0.01873),
#              ('삼성제약', 0.0),
#              ('삼성중공업', 0.0),
#              ('삼성증권', 0.0),
#              ('삼성출판사', 0.0),
#              ('삼성카드', 0.0),
#              ('삼성화재', 0.0),
#              ('삼아알미늄', 0.0),
#              ('삼양사', 0.0),
#              ('삼양식품', 0.0),
#              ('삼양통상', 0.0),
#              ('삼양홀딩스', 0.0),
#              ('삼영무역', 0.0),
#              ('삼영전자', 0.0),
#              ('삼영화학', 0.0),
#              ('삼원강재', 0.0),
#              ('삼익THK', 0.0),
#              ('삼익악기', 0.0),
#              ('삼일제약', 0.0),
#              ('삼정펄프', 0.0),
#              ('삼진제약', 0.0),
#              ('삼천리', 0.0),
#              ('삼호개발', 0.0),
#              ('삼화왕관', 0.0),
#              ('삼화전기', 0.0),
#              ('삼화전자', 0.0),
#              ('삼화콘덴서', 0.01667),
#              ('삼화페인트', 0.0),
#              ('상상인증권', 0.0),
#              ('상신브레이크', 0.0),
#              ('새론오토모티브', 0.0),
#              ('샘표', 0.0),
#              ('서연', 0.0),
#              ('서연이화', 0.0),
#              ('서울가스', 0.0),
#              ('서울식품', 0.0),
#              ('서원', 0.0),
#              ('서흥', 0.0),
#              ('선도전기', 0.0),
#              ('성문전자', 0.0),
#              ('성보화학', 0.0),
#              ('성신양회', 0.0),
#              ('성안', 0.0),
#              ('성창기업지주', 0.0),
#              ('세기상사', 0.0),
#              ('세방', 0.0),
#              ('세방전지', 0.0),
#              ('세아베스틸', 0.0),
#              ('세아제강지주', 0.0),
#              ('세아특수강', 0.0),
#              ('세아홀딩스', 0.0),
#              ('세우글로벌', 0.0),
#              ('세원이앤씨', 0.0),
#              ('세원정공', 0.0),
#              ('세이브존I&C', 0.0),
#              ('세종공업', 0.0),
#              ('세하', 0.0),
#              ('세화아이엠씨', 0.0),
#              ('센트럴인사이트', 0.0),
#              ('셀트리온', 0.0),
#              ('송원산업', 0.0),
#              ('수산중공업', 0.0),
#              ('스카이라이프', 0.0),
#              ('시디즈', 0.02278),
#              ('신대양제지', 0.0),
#              ('신도리코', 0.0),
#              ('신라교역', 0.0),
#              ('신성이엔지', 0.0),
#              ('신성통상', 0.0),
#              ('신세계', 0.0),
#              ('신세계 I&C', 0.0),
#              ('신세계건설', 0.0),
#              ('신세계인터내셔날', 0.0),
#              ('신세계푸드', 0.0),
#              ('신송홀딩스', 0.0),
#              ('신영와코루', 0.0),
#              ('신영증권', 0.0),
#              ('신원', 0.0),
#              ('신일전자', 0.0),
#              ('신풍제약', 0.02923),
#              ('신풍제지', 0.0),
#              ('신한지주', 0.0),
#              ('신화실업', 0.0),
#              ('신흥', 0.0),
#              ('쌍용C&E', 0.0),
#              ('쌍용차', 0.0),
#              ('써니전자', 0.0),
#              ('쎌마테라퓨틱스', 0.0),
#              ('씨아이테크', 0.0),
#              ('씨에스윈드', 0.0),
#              ('아남전자', 0.0),
#              ('아모레G', 0.0),
#              ('아모레퍼시픽', 0.0),
#              ('아세아', 0.0),
#              ('아세아시멘트', 0.0),
#              ('아세아제지', 0.0),
#              ('아센디오', 0.0),
#              ('아시아나항공', 0.0),
#              ('아이마켓코리아', 0.0),
#              ('아이에스동서', 0.0),
#              ('알루코', 0.0),
#              ('에넥스', 0.0),
#              ('에스엘', 0.0),
#              ('에스원', 0.0),
#              ('에쓰씨엔지니어링', 0.0),
#              ('에이블씨엔씨', 0.0),
#              ('에이엔피', 0.0),
#              ('에이프로젠 MED', 0.0),
#              ('에이프로젠제약', 0.0),
#              ('엔씨소프트', 0.00469),
#              ('엔에스쇼핑', 0.0),
#              ('엔케이', 0.0),
#              ('엔케이물산', 0.0),
#              ('엘브이엠씨홀딩스', 0.0),
#              ('엠씨넥스', 0.0),
#              ('영보화학', 0.0),
#              ('영진약품', 0.0),
#              ('영풍', 0.0),
#              ('영풍제지', 0.0),
#              ('영화금속', 0.0),
#              ('예스코홀딩스', 0.0),
#              ('오뚜기', 0.0),
#              ('오리엔트바이오', 0.0),
#              ('오리온홀딩스', 0.0),
#              ('우리금융캐피탈', 0.0),
#              ('우리종금', 0.0),
#              ('우성사료', 0.0),
#              ('우신시스템', 0.0),
#              ('우진', 0.0),
#              ('우진플라임', 0.0),
#              ('웅진', 0.0),
#              ('웅진씽크빅', 0.0),
#              ('원림', 0.0),
#              ('웰바이오텍', 0.0),
#              ('윌비스', 0.0),
#              ('유나이티드제약', 0.0),
#              ('유니드', 0.0),
#              ('유니온', 0.0),
#              ('유니온머티리얼', 0.0),
#              ('유니켐', 0.0),
#              ('유니퀘스트', 0.0),
#              ('유성기업', 0.0),
#              ('유수홀딩스', 0.0),
#              ('유안타증권', 0.0),
#              ('유양디앤유', 0.0),
#              ('유엔젤', 0.0),
#              ('유유제약', 0.0),
#              ('유진투자증권', 0.0),
#              ('유한양행', 0.0),
#              ('유화증권', 0.0),
#              ('율촌화학', 0.0),
#              ('이건산업', 0.0),
#              ('이구산업', 0.0),
#              ('이노션', 0.0),
#              ('이마트', 0.0),
#              ('이수페타시스', 0.0),
#              ('이수화학', 0.0),
#              ('이스타코', 0.0),
#              ('이아이디', 0.0),
#              ('이엔플러스', 0.0),
#              ('이연제약', 0.0),
#              ('이월드', 0.0),
#              ('이화산업', 0.0),
#              ('인디에프', 0.0),
#              ('인바이오젠', 0.0),
#              ('인스코비', 0.0),
#              ('인지컨트롤스', 0.0),
#              ('인천도시가스', 0.0),
#              ('인터지스', 0.0),
#              ('인팩', 0.0),
#              ('일동홀딩스', 0.0),
#              ('일성건설', 0.0),
#              ('일성신약', 0.0),
#              ('일신방직', 0.0),
#              ('일신석재', 0.0),
#              ('일양약품', 0.0),
#              ('일정실업', 0.0),
#              ('일진다이아', 0.0),
#              ('일진디스플', 0.0),
#              ('일진머티리얼즈', 0.00574),
#              ('일진홀딩스', 0.0),
#              ('자화전자', 0.0),
#              ('전방', 0.0),
#              ('제이준코스메틱', 0.0),
#              ('제이콘텐트리', 0.0),
#              ('제일기획', 0.0),
#              ('제일연마', 0.0),
#              ('제일파마홀딩스', 0.0),
#              ('제주은행', 0.0),
#              ('조광페인트', 0.0),
#              ('조광피혁', 0.0),
#              ('조비', 0.0),
#              ('조선내화', 0.0),
#              ('조선선재', 0.0),
#              ('조일알미늄', 0.0),
#              ('조흥', 0.0),
#              ('종근당', 0.0),
#              ('종근당바이오', 0.0),
#              ('종근당홀딩스', 0.0),
#              ('주연테크', 0.0),
#              ('지엠비코리아', 0.0),
#              ('지역난방공사', 0.0),
#              ('지코', 0.0),
#              ('지투알', 0.0),
#              ('진도', 0.0),
#              ('진양산업', 0.0),
#              ('진양폴리', 0.0),
#              ('진양홀딩스', 0.0),
#              ('진양화학', 0.0),
#              ('진원생명과학', 0.00113),
#              ('진흥기업', 0.0),
#              ('참엔지니어링', 0.0),
#              ('천일고속', 0.0),
#              ('체시스', 0.0),
#              ('카카오', 0.04882),
#              ('카프로', 0.0),
#              ('컨버즈', 0.0),
#              ('케이비아이동국실업', 0.0),
#              ('케이씨', 0.0),
#              ('케이탑리츠', 0.0),
#              ('코리아써키트', 0.0),
#              ('코리안리', 0.0),
#              ('코스맥스', 0.0),
#              ('코스맥스비티아이', 0.0),
#              ('코스모신소재', 0.02079),
#              ('코스모화학', 0.0),
#              ('코아스', 0.0),
#              ('코오롱', 0.0),
#              ('코오롱글로벌', 0.0),
#              ('코오롱머티리얼', 0.0),
#              ('코오롱플라스틱', 0.0),
#              ('코웨이', 0.0),
#              ('콤텍시스템', 0.0),
#              ('쿠쿠홀딩스', 0.0),
#              ('큐로', 0.0),
#              ('크라운해태홀딩스', 0.0),
#              ('키다리스튜디오', 0.0),
#              ('키움증권', 0.0),
#              ('태경비케이', 0.0),
#              ('태경산업', 0.0),
#              ('태경케미컬', 0.0),
#              ('태광산업', 0.0),
#              ('태림포장', 0.0),
#              ('태양금속', 0.0),
#              ('태영건설', 0.0),
#              ('태원물산', 0.0),
#              ('태평양물산', 0.0),
#              ('텔코웨어', 0.0),
#              ('토니모리', 0.0),
#              ('티에이치엔', 0.0),
#              ('티웨이홀딩스', 0.0),
#              ('파미셀', 0.0),
#              ('팜스코', 0.0),
#              ('팜젠사이언스', 0.0),
#              ('팬오션', 0.0),
#              ('퍼스텍', 0.0),
#              ('퍼시스', 0.0),
#              ('페이퍼코리아', 0.0),
#              ('평화산업', 0.0),
#              ('평화홀딩스', 0.0),
#              ('포스코강판', 0.03139),
#              ('포스코인터내셔널', 0.0),
#              ('포스코케미칼', 0.05194),
#              ('폴루스바이오팜', 0.0),
#              ('풀무원', 0.0),
#              ('풍산홀딩스', 0.0),
#              ('하나금융지주', 0.0),
#              ('하나투어', 0.0),
#              ('하이스틸', 0.0),
#              ('하이트론', 0.0),
#              ('하이트진로', 0.0),
#              ('하이트진로홀딩스', 0.0),
#              ('한국가스공사', 0.0),
#              ('한국공항', 0.0),
#              ('한국금융지주', 0.0),
#              ('한국내화', 0.0),
#              ('한국단자', 0.0),
#              ('한국석유', 0.0),
#              ('한국수출포장', 0.0),
#              ('한국쉘석유', 0.0),
#              ('한국앤컴퍼니', 0.0),
#              ('한국전력', 0.0),
#              ('한국전자홀딩스', 0.0),
#              ('한국조선해양', 0.0),
#              ('한국종합기술', 0.0),
#              ('한국주강', 0.0),
#              ('한국주철관', 0.0),
#              ('한국철강', 0.0),
#              ('한국카본', 0.0),
#              ('한국콜마홀딩스', 0.0),
#              ('한국타이어앤테크놀로지', 0.0),
#              ('한국토지신탁', 0.0),
#              ('한국특강', 0.0),
#              ('한국프랜지', 0.0),
#              ('한국항공우주', 0.0),
#              ('한국화장품', 0.0),
#              ('한국화장품제조', 0.0),
#              ('한농화성', 0.0),
#              ('한독', 0.0),
#              ('한라', 0.0),
#              ('한라홀딩스', 0.0),
#              ('한미글로벌', 0.0),
#              ('한미반도체', 0.00426),
#              ('한미사이언스', 0.0),
#              ('한샘', 0.0),
#              ('한섬', 0.0),
#              ('한성기업', 0.0),
#              ('한세실업', 0.0),
#              ('한세엠케이', 0.0),
#              ('한세예스24홀딩스', 0.0),
#              ('한솔PNS', 0.0),
#              ('한솔로지스틱스', 0.0),
#              ('한솔제지', 0.0),
#              ('한솔케미칼', 0.0),
#              ('한솔테크닉스', 0.0),
#              ('한솔홀딩스', 0.0),
#              ('한솔홈데코', 0.0),
#              ('한신공영', 0.0),
#              ('한신기계', 0.0),
#              ('한양증권', 0.0),
#              ('한온시스템', 0.0),
#              ('한올바이오파마', 0.0),
#              ('한익스프레스', 0.0),
#              ('한일철강', 0.0),
#              ('한일현대시멘트', 0.0),
#              ('한일홀딩스', 0.0),
#              ('한전KPS', 0.0),
#              ('한전기술', 0.0),
#              ('한전산업', 0.01162),
#              ('한진', 0.0),
#              ('한진중공업', 0.0),
#              ('한진중공업홀딩스', 0.0),
#              ('한진칼', 0.0),
#              ('한창', 0.0),
#              ('한창제지', 0.0),
#              ('한화', 0.0),
#              ('한화생명', 0.0),
#              ('한화손해보험', 0.0),
#              ('한화솔루션', 0.0),
#              ('한화에어로스페이스', 0.0),
#              ('한화투자증권', 0.0),
#              ('현대건설', 0.0),
#              ('현대그린푸드', 0.0),
#              ('현대글로비스', 0.0),
#              ('현대로템', 0.0),
#              ('현대리바트', 0.0),
#              ('현대모비스', 0.0),
#              ('현대미포조선', 0.0),
#              ('현대백화점', 0.0),
#              ('현대비앤지스틸', 0.0),
#              ('현대약품', 0.0),
#              ('현대엘리베이', 0.0),
#              ('현대위아', 0.0),
#              ('현대제철', 0.0),
#              ('현대차', 0.0),
#              ('현대차증권', 0.0),
#              ('현대코퍼레이션', 0.0),
#              ('현대퓨처넷', 0.0),
#              ('현대해상', 0.0),
#              ('현대홈쇼핑', 0.0),
#              ('형지엘리트', 0.0),
#              ('혜인', 0.0),
#              ('호텔신라', 0.0),
#              ('화성산업', 0.0),
#              ('화승인더', 0.0),
#              ('화승코퍼레이션', 0.0),
#              ('화신', 0.0),
#              ('화인베스틸', 0.0),
#              ('화천기계', 0.0),
#              ('화천기공', 0.0),
#              ('환인제약', 0.0),
#              ('황금에스티', 0.0),
#              ('효성', 0.0),
#              ('효성ITX', 0.0),
#              ('후성', 0.0),
#              ('휠라홀딩스', 0.0),
#              ('휴니드', 0.0),
#              ('휴비스', 0.0),
#              ('휴스틸', 0.0),
#              ('휴켐스', 0.0),
#              ('흥국화재', 0.0),
#              ('흥아해운', 0.0)])

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading https://files.pythonhosted.org/packages/14/c4/0eec14a0123209c261de6ff154ef3be5cad3fd557c084f468356662e0585/PuLP-2.4-py3-none-any.whl (40.6MB)
#      |████████████████████████████████| 40.6MB 76kB/s
# Collecting amply>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/f3/c5/dfa09dd2595a2ab2ab4e6fa7bebef9565812722e1980d04b0edce5032066/amply-0.1.4-py3-none-any.whl
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (2.4.7)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.7/dist-packages (from amply>=0.1.2->pulp) (0.17.1)
# Installing collected packages: amply, pulp
# Successfully installed amply-0.1.4 pulp-2.4

# %%
# Get the discrete allocation of each sharpe per stock
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

# 투자금액 (단위: KRW)
portfolio_val = 15000000

latest_prices = get_latest_prices(df2)

weights = cleaned_weights

da = DiscreteAllocation(weights, latest_prices, total_portfolio_value=portfolio_val)

allocation, leftover = da.lp_portfolio()

print('Discrete Allocaion: ', allocation)
print('Funds Remaining: ', leftover, ' KRW')
# Out:
# Discrete Allocaion:  {'NAVER': 1, '그린케미칼': 12, '넥스트사이언스': 12, '대성홀딩스': 63, '대한방직': 6, '동남합성': 24, '동방': 7, '맥쿼리인프라': 135, '미원상사': 16, '부산주공': 1, '삼성SDI': 1, '삼성공조': 8, '삼성전자': 3, '삼화콘덴서': 4, '상상인증권': 1, '시디즈': 5, '신풍제약': 7, '일진머티리얼즈': 1, '지코': 1, '카카오': 4, '코스모신소재': 8, '포스코강판': 6, '포스코케미칼': 5, '한미반도체': 2, '한전산업': 11}
# Funds Remaining:  103.0  KRW

# %%
allocation
# Out:
# {'NAVER': 1,
#  '그린케미칼': 12,
#  '넥스트사이언스': 12,
#  '대성홀딩스': 63,
#  '대한방직': 6,
#  '동남합성': 24,
#  '동방': 7,
#  '맥쿼리인프라': 135,
#  '미원상사': 16,
#  '부산주공': 1,
#  '삼성SDI': 1,
#  '삼성공조': 8,
#  '삼성전자': 3,
#  '삼화콘덴서': 4,
#  '상상인증권': 1,
#  '시디즈': 5,
#  '신풍제약': 7,
#  '일진머티리얼즈': 1,
#  '지코': 1,
#  '카카오': 4,
#  '코스모신소재': 8,
#  '포스코강판': 6,
#  '포스코케미칼': 5,
#  '한미반도체': 2,
#  '한전산업': 11}

# %%
len(allocation)
# Out:
# 25

# %%
# 포트폴리오에 포함된 종목을 리스트로 만들기
company_name = list(allocation)

# %%
company_name
# Out:
# ['NAVER',
#  '그린케미칼',
#  '넥스트사이언스',
#  '대성홀딩스',
#  '대한방직',
#  '동남합성',
#  '동방',
#  '맥쿼리인프라',
#  '미원상사',
#  '부산주공',
#  '삼성SDI',
#  '삼성공조',
#  '삼성전자',
#  '삼화콘덴서',
#  '상상인증권',
#  '시디즈',
#  '신풍제약',
#  '일진머티리얼즈',
#  '지코',
#  '카카오',
#  '코스모신소재',
#  '포스코강판',
#  '포스코케미칼',
#  '한미반도체',
#  '한전산업']

# %%
len(company_name)
# Out:
# 25

# %%
# Get the discrete allocation values
discrete_allocation_list = []
for symbol in allocation:
  discrete_allocation_list.append(allocation.get(symbol))

# %%
discrete_allocation_list
# Out:
# [1,
#  12,
#  12,
#  63,
#  6,
#  24,
#  7,
#  135,
#  16,
#  1,
#  1,
#  8,
#  3,
#  4,
#  1,
#  5,
#  7,
#  1,
#  1,
#  4,
#  8,
#  6,
#  5,
#  2,
#  11]

# %%
# Create a dataframe for the portfolio
portfolio_df = pd.DataFrame(columns = ['Company_name', 'company_Ticker', 'Discrete_val_'+str(portfolio_val)])
portfolio_df
# Out:
# Empty DataFrame
# Columns: [Company_name, company_Ticker, Discrete_val_15000000]
# Index: []

# %%
portfolio_df['Company_name'] = company_name
portfolio_df['company_Ticker'] = allocation
portfolio_df['Discrete_val_'+str(portfolio_val)] = discrete_allocation_list

# %%
portfolio_df
# Out:
#    Company_name company_Ticker  Discrete_val_15000000
# 0         NAVER          NAVER                      1
# 1         그린케미칼          그린케미칼                     12
# 2       넥스트사이언스        넥스트사이언스                     12
# 3         대성홀딩스          대성홀딩스                     63
# 4          대한방직           대한방직                      6
# 5          동남합성           동남합성                     24
# 6            동방             동방                      7
# 7        맥쿼리인프라         맥쿼리인프라                    135
# 8          미원상사           미원상사                     16
# 9          부산주공           부산주공                      1
# 10        삼성SDI          삼성SDI                      1
# 11         삼성공조           삼성공조                      8
# 12         삼성전자           삼성전자                      3
# 13        삼화콘덴서          삼화콘덴서                      4
# 14        상상인증권          상상인증권                      1
# 15          시디즈            시디즈                      5
# 16         신풍제약           신풍제약                      7
# 17      일진머티리얼즈        일진머티리얼즈                      1
# 18           지코             지코                      1
# 19          카카오            카카오                      4
# 20       코스모신소재         코스모신소재                      8
# 21        포스코강판          포스코강판                      6
# 22       포스코케미칼         포스코케미칼                      5
# 23        한미반도체          한미반도체                      2
# 24         한전산업           한전산업                     11

# %%
# Sort by allocation & Show the portfolio
portfolio_df_sorted = portfolio_df.sort_values('Discrete_val_'+str(portfolio_val), ascending = False)
portfolio_df_sorted = portfolio_df_sorted.reset_index(drop=True)
portfolio_df_sorted
# Out:
#    Company_name company_Ticker  Discrete_val_15000000
# 0        맥쿼리인프라         맥쿼리인프라                    135
# 1         대성홀딩스          대성홀딩스                     63
# 2          동남합성           동남합성                     24
# 3          미원상사           미원상사                     16
# 4       넥스트사이언스        넥스트사이언스                     12
# 5         그린케미칼          그린케미칼                     12
# 6          한전산업           한전산업                     11
# 7          삼성공조           삼성공조                      8
# 8        코스모신소재         코스모신소재                      8
# 9            동방             동방                      7
# 10         신풍제약           신풍제약                      7
# 11        포스코강판          포스코강판                      6
# 12         대한방직           대한방직                      6
# 13       포스코케미칼         포스코케미칼                      5
# 14          시디즈            시디즈                      5
# 15          카카오            카카오                      4
# 16        삼화콘덴서          삼화콘덴서                      4
# 17         삼성전자           삼성전자                      3
# 18        한미반도체          한미반도체                      2
# 19           지코             지코                      1
# 20      일진머티리얼즈        일진머티리얼즈                      1
# 21        상상인증권          상상인증권                      1
# 22        삼성SDI          삼성SDI                      1
# 23         부산주공           부산주공                      1
# 24        NAVER          NAVER                      1

# %%
# Show Funds Remaining
print('Funds Remaining: ', leftover, ' KRW')

# Show Portfolio performance
ef.portfolio_performance(verbose=True)
# Out:
# Funds Remaining:  103.0  KRW
# Expected annual return: 35.3%
# Annual volatility: 13.8%
# Sharpe Ratio: 2.42
# (0.3533312241107406, 0.1378080803801316, 2.41880754155544)
